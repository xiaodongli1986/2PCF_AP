# %%
execfile('/home/xiaodongli/software/pythonlib/stdA.py')
execfile('/home/xiaodongli/software/pythonlib/Tpcftools.py')
execfile('/home/xiaodongli/software/pythonlib/Tpcftools_ChisqContour.py')
# %pylab inline
figformat = 'pdf'
# Out:
# /home/xiaodongli/software/pythonlib/Tpcftools_smuintxi.py:536: SyntaxWarning: name 'oms' is assigned to before global declaration
#   global oms, ws, omws, scanname
# /home/xiaodongli/software/pythonlib/Tpcftools_smuintxi.py:536: SyntaxWarning: name 'ws' is assigned to before global declaration
#   global oms, ws, omws, scanname
# /home/xiaodongli/software/pythonlib/Tpcftools_smuintxi.py:536: SyntaxWarning: name 'omws' is assigned to before global declaration
#   global oms, ws, omws, scanname
# /home/xiaodongli/software/pythonlib/Tpcftools_smuintxi.py:536: SyntaxWarning: name 'scanname' is assigned to before global declaration
#   global oms, ws, omws, scanname
# WARNING:
# Populating the interactive namespace from numpy and matplotlib
# pylab import has clobbered these variables: ['copy']
# `%matplotlib` prevents importing * from pylab and numpy

# %% [markdown]
# # Draft Plot

# %%
ip1 = 3; ip2 = 4; maxip = max(ip1,ip2); minip = min(ip1,ip2)

ParNames = ['$\\Omega_m$', '$h$', '$w_0$', '$w_a$']
Par1 = ParNames[ip1-1]; Par2=ParNames[ip2-1]

cosmomcdir = '/home/xiaodongli/software/cosmomcs/12Oct_generic/'
suffix_label0 = ['__base1omws_om0.2600_w-1.0000','default']
suffix_label_list = [
                ['__base1omws_om0.2600_w-1.0000_NoSysCor','$\\rm Uncorrected$'],
                #['__base2omws_om0.2600_w-1.0000_om0.3100_w-1.0000','$\\rm fiducial:\\ \Omega_m = 0.26/0.31$'],
                #['cpl_union2p1_planck_bossdr11', '$\\rm Union2.1+Planck+BOSS DR11$'],
                ['__base1omws_om0.2600_w-1.0000_mumax0.99','$\\rm \mu_{\\rm max}=0.99$'],
                #['__base1omws_om0.2600_w-1.0000_mumax0.98','$\\rm \mu_{\\rm max}=0.98$'],
                #['__base1omws_om0.2600_w-1.0000_mumax0.95','$\\rm \mu_{\\rm max}=0.95$'],
                #['__base1omws_om0.2600_w-1.0000_mumax0.90','$\\rm \mu_{\\rm max}=0.90$'],
                ['__base1omws_om0.2600_w-1.0000_mumax0.85','$\\rm \mu_{\\rm max}=0.85$'],
                #['__base1omws_om0.2600_w-1.0000_mumax0.6','$\\rm \mu_{\\rm max}=0.60$'],
                #['__base1omws_om0.2600_w-1.0000_mumax0.70','$\\rm \mu_{\\rm max}=0.70$'],
                #['__base1omws_om0.2600_w-1.0000_mumax0.50','$\\rm \mu_{\\rm max}=0.50$'],
                #['__base1omws_om0.2600_w-1.0000_nbins10to15','$n_{\\rm bin}=10-15$'],
                #['__base1omws_om0.2600_w-1.0000_nbins15to20','$n_{\\mu}=15-20$'],
                #['__base1omws_om0.2600_w-1.0000_nbins20to22','$n_{\\rm bin}=20-22$'],
                #['__base1omws_om0.2600_w-1.0000_nbins23to25','$n_{\\rm bin}=23-25$'],
                #['__base1omws_om0.2600_w-1.0000_nbins25to30','$n_{\\rm bin}=25-30$'],
                ##['__base1omws_om0.2600_w-1.0000_nbins30to35','$n_{\\rm bin}=30-35$'],
                ##['__base1omws_om0.2600_w-1.0000_nbins35to40','$n_{\\rm bin}=35-40$'],
                #['__base1omws_om0.2600_w-1.0000_smax30','$s_{\\rm max}=30$'],
                #['__base1omws_om0.2600_w-1.0000_smax35','$s_{\\rm max}=35$'],
                #['__base1omws_om0.2600_w-1.0000_smax40','$s_{\\rm max}=40$'],
                #['__base1omws_om0.2600_w-1.0000_smax45','$s_{\\rm max}=45$'],
                #['__base1omws_om0.2600_w-1.0000_smax50','$s_{\\rm max}=50$'],
                #['__base1omws_om0.2600_w-1.0000_smin4_nbin15to20','$s_{\\rm min}=4,\ n_{\\rm bin}=15-20$'],
                #['__base1omws_om0.2600_w-1.0000_smin5_nbin15to20','$s_{\\rm min}=5,\ n_{\\rm bin}=15-20$'],
                #['__base1omws_om0.2600_w-1.0000_smin7_nbins20to25','$s_{\\rm min}=7,\ n_{\\rm bin}=20-25$'],
                #['__base1omws_om0.2600_w-1.0000_smin8_nbin15to20','$s_{\\rm min}=8,\ n_{\\rm bin}=15-20$'],
                #['__base1omws_om0.2600_w-1.0000_smin8_nbins20to25','$s_{\\rm min}=8$'],
                #['__base1omws_om0.2600_w-1.0000_r8to30','$s=8-30 \\rm Mpc/h$'],
                ['__base1omws_om0.2600_w-0.6000','$\\rm fiducial:\\ \Omega_m=0.26,\\ w=-0.6$'],
                ['__base1omws_om0.2600_w-1.0000_smax35','$s=6-35 \\rm Mpc/h$'],
                ['__base1omws_om0.2600_w-1.0000_smax45','$s=6-45 \\rm Mpc/h$'],
                #['__base1omws_om0.2600_w-1.0000_smin10_nbin15to20','$s_{\\rm min}=10,\ n_{\\rm bin}=15-20$'],
                #['__base1omws_om0.2600_w-1.0000_smin15_nbin15to20','$s_{\\rm min}=15,\ n_{\\rm bin}=15-20$'],
                #['__base1omws_om0.3100_w-1.0000','$\\rm fiducial:\\ \Omega_m=0.31,\\ w=-1.0$'],
                ##['__base1omws_om0.3100_w-1.0000_smax40','$\\rm fiducial:\\ \Omega_m=0.31,\\ w=-1.0, B$'],
                #['__base1omws_om0.2600_w-1.4000','$\\rm fiducial:\\ \Omega_m=0.26,\\ w=-1.4$'],
                #['__base1omws_om0.3100_w-1.4000','$\\rm fiducial:\\ \Omega_m=0.31,\\ w=-1.4$'],
                #['__base1omws_om0.3100_w-0.6000','$\\rm fiducial:\\ \Omega_m=0.31,\\ w=-0.6$'],
                #['__base1omws_om0.1100_w-2.0000','$\\rm fiducial:\\ \Omega_m=0.11,\\ w=-2.0$'],
                #['__base1omws_om0.2600_w-1.0000_nopolyfit','$\\rm No\\ Poly\\ Fit$'],
                ['__base1omws_om0.2600_w-1.0000_ExcludeLastBin','$\\rm Exclude\\ Last\\ Red\\ Bin$'],
                #['__base1omws_om0.2600_w-1.0000_ExcludeLastTwoBins','$\\rm Exclude\\ Last\\ 2\\ Red\\ Bin$'],
                #['__base1omws_om0.2600_w-1.0000_ExcludeLastThreeBins','$\\rm Exclude\\ Last\\ 3\\ Red\\ Bin$'],
                #['__base1omws_om0.2600_w-1.0000_ExcludeLastThreeBins_B','$\\rm Exclude\\ Last\\ 3\\ Red\\ Bin,B$'],
                #['__base1omws_om0.2600_w-1.0000_RedBins23','$\\rm 2,3th\\ Red\\ Bins$'],
                #['__base1omws_om0.2600_w-1.0000_RedBins2','$\\rm Red\\ Bin\\ 1,2$'],
                #['__base1omws_om0.2600_w-1.0000_RedBins3','$\\rm Red\\ Bin\\ 1,3$'],
                #['__base1omws_om0.2600_w-1.0000_RedBins4','$\\rm Red\\ Bin\\ 1,4$'],
                #['__base1omws_om0.2600_w-1.0000_RedBins5','$\\rm Red\\ Bin\\ 1,5$'],
                #['__base1omws_om0.2600_w-1.0000_RedBins6','$\\rm Red\\ Bin\\ 1,6$'],
                #['__base1omws_om0.2600_w-1.0000_NoSysCor','$\\rm With\\ Systematics$'],
                ['__base1omws_om0.2600_w-1.0000_nmock1000','$\\rm 1000\ mocks$\n$\\rm for\\ covariance$'],
                #['__base1omws_om0.2600_w-1.0000_nmock200','$\\rm 200\ mocks$'],
                ]
plot_single = False
nplot = len(suffix_label_list);
ncol = 4; nrow = int(nplot/(ncol+0.0)+0.99)
fig0 = plt.figure(figsize=(ncol*5,nrow*4));
iplot = 1
for suffix_label in suffix_label_list:    
    suffix, label = suffix_label
    ax0 = fig0.add_subplot(nrow,ncol,iplot); 
    if plot_single: 
        fig1, ax1 = figax()
        axlist = [ax0, ax1]
    else:
        axlist = [ax0]
    
    if False:
        file1 = cosmomcdir+'plot_data/base_w_wa_plikHM_TTTEEE_lowTEB_BAO_H070p6_JLA_simple'
        pts = np.loadtxt(file1+'_2D_'+str(ip2)+'_'+str(ip1)+'')
        X = Xfromdata(np.loadtxt(file1+'_p'+str(ip1)+'.dat'))
        Y = Xfromdata(np.loadtxt(file1+'_p'+str(ip2)+'.dat'))
        cnt = np.loadtxt(file1+'_2D_'+str(ip2)+'_'+str(ip1)+'_cont')
        cnt = array([cnt[1], cnt[0],cnt[0]/2,] )
        for ax in axlist:
            rlt = ax.contourf(X,Y,pts,cnt, colors=[[0,0.7,1],[0,0.4,1]], alpha=0.87, label='Approximate 2pCF', linewidths=2,)
        #w0waCont_1sig, w0waCont_2sig = rlt.Cntr.trace(0), rlt.Cntr.trace(1)

    suffix0, label0 = suffix_label0
    file1 = cosmomcdir+'plot_data/base_w_wa_plikHM_TTTEEE_lowTEB_BAO_H070p6_JLA_'+suffix0
    pts = np.loadtxt(file1+'_2D_'+str(ip2)+'_'+str(ip1)+'')
    X = Xfromdata(np.loadtxt(file1+'_p'+str(ip1)+'.dat'))
    Y = Xfromdata(np.loadtxt(file1+'_p'+str(ip2)+'.dat'))
    cnt = np.loadtxt(file1+'_2D_'+str(ip2)+'_'+str(ip1)+'_cont')
    cnt = array([cnt[1], cnt[0],cnt[0]/2,] )
    for ax in axlist:
        rlt = ax.contourf(X,Y,pts,cnt,  colors=[[1,0.7,1],[1,0.4,1]],  alpha=0.87, labels=['Approximate 2pCF','Approximate 2pCF'], 
                      linewidths=2, linestyles='-')
        #rlt = ax.contour(X,Y,pts,array([cnt[1], cnt[0]]),  colors=[[1,0,1],[1,0,1]],   
        #              linewidths=4, linestyles='--')
    
    file1 = cosmomcdir+'plot_data/base_w_wa_plikHM_TTTEEE_lowTEB_BAO_H070p6_JLA_'+suffix
    if suffix in ['cpl_union2p1_planck_bossdr11']:
        file1 = cosmomcdir+'plot_data/'+suffix
    pts = np.loadtxt(file1+'_2D_'+str(ip2)+'_'+str(ip1)+'')
    X = Xfromdata(np.loadtxt(file1+'_p'+str(ip1)+'.dat'))
    Y = Xfromdata(np.loadtxt(file1+'_p'+str(ip2)+'.dat'))
    cnt = np.loadtxt(file1+'_2D_'+str(ip2)+'_'+str(ip1)+'_cont')
    cnt = array([cnt[1], cnt[0]] )
    for ax in axlist:
        rlt = ax.contour(X,Y,pts,cnt,  colors=['k','k'], # alpha=0.87, labels=['Approximate 2pCF','Approximate 2pCF'], 
                      linewidths=2, linestyles='-')

    for ax in axlist:
        #ax.plot([-100,-100],[-100,-100], c= [0,0.7,1], label='CMB+BAO+SN+$H_0$', lw=10)
        #ax.plot([-100,-100],[-100,-100], c= [1,0.7,1], label='CMB+BAO+SN+$H_0$+AP,\n'+label0, lw=10)
        #ax.plot([-100,-100],[-100,-100], c= 'k', label='CMB+BAO+SN+$H_0$+AP,\n'+label, lw=2)
        if iplot == 1: ax.plot([-100,-100],[-100,-100], c= [1,0.7,1], label='$\\rm'+label0+'$', lw=10)
        #if iplot == 1: ax.plot([-100,-100],[-100,-100], c= [1,0,1], label='$\\rm'+label0+'$', lw=3, ls='--')
        ax.plot([-100,-100],[-100,-100], c= 'k', label=label, lw=2)
        ax.legend(frameon=False, fontsize=20)
        #ax.scatter([-1],[0], marker='+', linewidth=3, s=150, c='g')
        ax.plot([-2,2],[0,0], linewidth=0.5, ls='--', c='g')
        ax.plot([-1,-1],[-5,5], linewidth=0.5, ls='--', c='g')
        #ax.grid();
        ax.set_xlabel(Par1, fontsize=24)
        ax.set_ylabel(Par2, fontsize=24)
        #if ip1 ==3 and ip2 == 4: ax.set_xlim(-1.33, -0.55); ax.set_ylim(-1.6,0.7)
        if ip1 ==3 and ip2 == 4: ax.set_xlim(-1.35, -0.75); ax.set_ylim(-1.10,1.15)
        if ip1 ==1 and ip2 == 3: ax.set_xlim(0.21, 0.41); ax.set_ylim(-1.33,-0.55)
        if ip1 ==1 and ip2 == 2: ax.set_xlim(0.21, 0.41); ax.set_ylim(0.655,0.723)
        if iplot in [1,2,3,4]:
            ax.set_xlabel('x',visible=False)
            for xtick in ax.get_xticklabels():
                xtick.set_visible(False)
        if iplot in [2,3,4,6,7,8]:
            ax.set_ylabel('y',visible=False)
            for ytick in ax.get_yticklabels():
                ytick.set_visible(False)
    iplot += 1
    if plot_single:
        # !mkdir -p ./Draft/fig_contours
        fig.savefig('./Draft/fig_contours/figCPL_b'+suffix+'.png', format='png')
    #fig.savefig('./Draft/fig_contours/figCPL_b'+suffix+'.'+figformat, format=figformat)
fig0.tight_layout(h_pad=0, w_pad=0 )
#fig0.savefig('./Draft/fig_con_tests_Par_'+str(ip1)+'_'+str(ip2)+'.png', format='png')
fig0.savefig('./Draft/fig_con_tests.pdf', format='pdf')
#fig0.savefig('./Draft/fig_con_tests_Par_'+str(ip1)+'_'+str(ip2)+'_simple.png', format='png')
# Out:
# /home/xiaodongli/anaconda/lib/python2.7/site-packages/matplotlib/contour.py:930: UserWarning: linewidths is ignored by contourf
#   warnings.warn('linewidths is ignored by contourf')

# %%
print get_z(0.26, -1, 0.7, 100)
print comov_r_CPL(0.26, -1, 0, 0.7, 0.5)
print comov_r_CPL(0.26, -1, -2, 0.7, 0.5)
# Out:
# 0.033578257671
# 1340.89715902
# 1394.37195878

# %%
x, y, z = -682.437504,   -184.083601,    -13.115710
r = (x*x+y*y+z*z) ** 0.5
red = get_z(0.26, -1, 0.7, r)
r2 = comov_r_CPL(0.26, -1, -2, 0.7, red)
rat = r2/r
print x*rat, y*rat, z*rat
# Out:
# -692.748707252 -186.864988913 -13.3138801633

# %% [markdown]
# # More Tests

# %%
ip1 = 3; ip2 = 4; maxip = max(ip1,ip2); minip = min(ip1,ip2)

ParNames = ['$\\Omega_m$', '$h$', '$w_0$', '$w_a$']
Par1 = ParNames[ip1-1]; Par2=ParNames[ip2-1]

cosmomcdir = '/home/xiaodongli/software/cosmomcs/12Oct_generic/'
suffix_label0 = ['__base1omws_om0.2600_w-1.0000','default']
suffix_label_list = [
                #['__base2omws_om0.2600_w-1.0000_om0.3100_w-1.0000','$\\rm fiducial:\\ \Omega_m = 0.26/0.31$'],
                #['cpl_union2p1_planck_bossdr11', '$\\rm Union2.1+Planck+BOSS DR11$'],
                ['__base1omws_om0.2600_w-1.0000_mumax0.99','$\\rm \mu_{\\rm max}=0.99$'],
                ['__base1omws_om0.2600_w-1.0000_mumax0.98','$\\rm \mu_{\\rm max}=0.98$'],
                ['__base1omws_om0.2600_w-1.0000_mumax0.95','$\\rm \mu_{\\rm max}=0.95$'],
                ['__base1omws_om0.2600_w-1.0000_mumax0.90','$\\rm \mu_{\\rm max}=0.90$'],
                ['__base1omws_om0.2600_w-1.0000_mumax0.85','$\\rm \mu_{\\rm max}=0.85$'],
                ['__base1omws_om0.2600_w-1.0000_mumax0.6','$\\rm \mu_{\\rm max}=0.60$'],
                ['__base1omws_om0.2600_w-1.0000_mumax0.70','$\\rm \mu_{\\rm max}=0.70$'],
                ['__base1omws_om0.2600_w-1.0000_mumax0.50','$\\rm \mu_{\\rm max}=0.50$'],
                ['__base1omws_om0.2600_w-1.0000_nbins10to15','$n_{\\rm bin}=10-15$'],
                ['__base1omws_om0.2600_w-1.0000_nbins15to20','$n_{\\rm bin}=15-20$'],
                ['__base1omws_om0.2600_w-1.0000_nbins20to22','$n_{\\rm bin}=20-22$'],
                ['__base1omws_om0.2600_w-1.0000_nbins23to25','$n_{\\rm bin}=23-25$'],
                ['__base1omws_om0.2600_w-1.0000_nbins25to30','$n_{\\rm bin}=25-30$'],
                ['__base1omws_om0.2600_w-1.0000_nbins26to27','$n_{\\rm bin}=26-27$'],
                ['__base1omws_om0.2600_w-1.0000_nbins30to35','$n_{\\rm bin}=30-35$'],
                ['__base1omws_om0.2600_w-1.0000_nbins35to40','$n_{\\rm bin}=35-40$'],
                ['__base1omws_om0.2600_w-1.0000_smax30','$s_{\\rm max}=30$'],
                ['__base1omws_om0.2600_w-1.0000_smax35','$s_{\\rm max}=35$'],
                ['__base1omws_om0.2600_w-1.0000_smax40','$s_{\\rm max}=40$'],
                ['__base1omws_om0.2600_w-1.0000_smax45','$s_{\\rm max}=45$'],
                ['__base1omws_om0.2600_w-1.0000_smax50','$s_{\\rm max}=50$'],
                ['__base1omws_om0.2600_w-1.0000_smin4_nbin15to20','$s_{\\rm min}=4,\ n_{\\rm bin}=15-20$'],
                ['__base1omws_om0.2600_w-1.0000_smin5_nbin15to20','$s_{\\rm min}=5,\ n_{\\rm bin}=15-20$'],
                ['__base1omws_om0.2600_w-1.0000_smin7_nbins20to25','$s_{\\rm min}=7,\ n_{\\rm bin}=20-25$'],
                ['__base1omws_om0.2600_w-1.0000_smin8_nbin15to20','$s_{\\rm min}=8,\ n_{\\rm bin}=15-20$'],
                ['__base1omws_om0.2600_w-1.0000_smin8_nbins20to25','$s_{\\rm min}=8$'],
                ['__base1omws_om0.2600_w-1.0000_smin10_nbin15to20','$s_{\\rm min}=10,\ n_{\\rm bin}=15-20$'],
                ['__base1omws_om0.2600_w-1.0000_smin15_nbin15to20','$s_{\\rm min}=15,\ n_{\\rm bin}=15-20$'],

                ['__base1omws_om0.2600_w-1.0000__r4to50','$s=4-50 \\rm Mpc/h$'],                
                ['__base1omws_om0.2600_w-1.0000_r8to30','$s=8-30 \\rm Mpc/h$'],                
                ['__base1omws_om0.2600_w-1.0000_r8to30_nosyscor','$s=8-30 \\rm Mpc/h,\\ No\\ Sys\\ Cor$'],                
                ['__base1omws_om0.2600_w-1.0000_r8to25','$s=8-25 \\rm Mpc/h$'],                
                ['__base1omws_om0.2600_w-1.0000_r8to25_nosyscor','$s=8-25 \\rm Mpc/h,\\ No\\ Sys\\ Cor$'],                
                ['__base1omws_om0.2600_w-1.0000_r8to20','$s=8-20 \\rm Mpc/h$'],                
                ['__base1omws_om0.2600_w-1.0000_r8to20_nosyscor','$s=8-20 \\rm Mpc/h,\\ No\\ Sys\\ Cor$'],                
                ['__base1omws_om0.2600_w-1.0000_r8to15','$s=8-15 \\rm Mpc/h$'],                
                ['__base1omws_om0.2600_w-1.0000_r8to15_nosyscor','$s=8-15 \\rm Mpc/h,\\ No\\ Sys\\ Cor$'],                

                ['__base1omws_om0.2600_w-1.0000__r4to6','$s=4-6 \\rm Mpc/h$'],    
                ['__base1omws_om0.2600_w-1.0000__r6to10','$s=6-10 \\rm Mpc/h$'],    
                ['__base1omws_om0.2600_w-1.0000__r10to15','$s=10-15 \\rm Mpc/h$'],   
                ['__base1omws_om0.2600_w-1.0000__UseH0_Crosscheck','$\\rm Cross-Check\\ (Precise\\ H_0)$'],   


                ['__base1omws_om0.3100_w-1.0000','$\\rm fiducial:\\ \Omega_m=0.31,\\ w=-1.0$'],
                ['__base1omws_om0.3100_w-1.0000_smax40','$\\rm fiducial:\\ \Omega_m=0.31,\\ w=-1.0, B$'],
                ['__base1omws_om0.2600_w-1.4000','$\\rm fiducial:\\ \Omega_m=0.26,\\ w=-1.4$'],
                ['__base1omws_om0.2600_w-0.6000','$\\rm fiducial:\\ \Omega_m=0.26,\\ w=-0.6$'],
                ['__base1omws_om0.3100_w-1.4000','$\\rm fiducial:\\ \Omega_m=0.31,\\ w=-1.4$'],
                ['__base1omws_om0.3100_w-0.6000','$\\rm fiducial:\\ \Omega_m=0.31,\\ w=-0.6$'],
                ['__base1omws_om0.1100_w-2.0000','$\\rm fiducial:\\ \Omega_m=0.11,\\ w=-2.0$'],
                ['__base1omws_om0.2600_w-1.0000_nopolyfit','$\\rm No\\ Poly\\ Fit$'],
                ['__base1omws_om0.2600_w-1.0000_ExcludeLastBin','$\\rm Exclude\\ Last\\ Red\\ Bin$'],
                ['__base1omws_om0.2600_w-1.0000_ExcludeLastTwoBins','$\\rm Exclude\\ Last\\ 2\\ Red\\ Bin$'],
                ['__base1omws_om0.2600_w-1.0000_ExcludeLastThreeBins','$\\rm Exclude\\ Last\\ 3\\ Red\\ Bin$'],
                #['__base1omws_om0.2600_w-1.0000_ExcludeLastThreeBins_B','$\\rm Exclude\\ Last\\ 3\\ Red\\ Bin,B$'],
                #['__base1omws_om0.2600_w-1.0000_RedBins23','$\\rm 2,3th\\ Red\\ Bins$'],
                ['__base1omws_om0.2600_w-1.0000_RedBins2','$\\rm Red\\ Bin\\ 1,2$'],
                ['__base1omws_om0.2600_w-1.0000_RedBins3','$\\rm Red\\ Bin\\ 1,3$'],
                ['__base1omws_om0.2600_w-1.0000_RedBins4','$\\rm Red\\ Bin\\ 1,4$'],
                ['__base1omws_om0.2600_w-1.0000_RedBins5','$\\rm Red\\ Bin\\ 1,5$'],
                ['__base1omws_om0.2600_w-1.0000_RedBins6','$\\rm Red\\ Bin\\ 1,6$'],
                ['__base1omws_om0.2600_w-1.0000_NoSysCor','$\\rm With\\ Systematics$'],
                ['__base1omws_om0.2600_w-1.0000_VolumeWeightedDAH','$\\rm Volume\\ weighted\\ DA/H$'],
                ['__base1omws_om0.2600_w-1.0000_NotVolumeWeightedDAH','$\\rm Not\\ Volume\\ weighted\\ DA/H$'],
                ['__base1omws_om0.2600_w-1.0000_nmock1000','$\\rm 1000\ mocks$'],
                ['__base1omws_om0.2600_w-1.0000_nmock200','$\\rm 200\ mocks$'],
                ]
plot_single = False
nplot = len(suffix_label_list);
ncol = 4; nrow = int(nplot/(ncol+0.0)+0.99)
fig0 = plt.figure(figsize=(ncol*7,nrow*6));
iplot = 1
for suffix_label in suffix_label_list:    
    suffix, label = suffix_label
    ax0 = fig0.add_subplot(nrow,ncol,iplot); iplot+=1
    if plot_single: 
        fig1, ax1 = figax()
        axlist = [ax0, ax1]
    else:
        axlist = [ax0]
    
    if False:
        file1 = cosmomcdir+'plot_data/base_w_wa_plikHM_TTTEEE_lowTEB_BAO_H070p6_JLA_simple'
        pts = np.loadtxt(file1+'_2D_'+str(ip2)+'_'+str(ip1)+'')
        X = Xfromdata(np.loadtxt(file1+'_p'+str(ip1)+'.dat'))
        Y = Xfromdata(np.loadtxt(file1+'_p'+str(ip2)+'.dat'))
        cnt = np.loadtxt(file1+'_2D_'+str(ip2)+'_'+str(ip1)+'_cont')
        cnt = array([cnt[1], cnt[0],cnt[0]/2,] )
        for ax in axlist:
            rlt = ax.contourf(X,Y,pts,cnt, colors=[[0,0.7,1],[0,0.4,1]], alpha=0.87, label='Approximate 2pCF', linewidths=2,)
        #w0waCont_1sig, w0waCont_2sig = rlt.Cntr.trace(0), rlt.Cntr.trace(1)

    suffix0, label0 = suffix_label0
    file1 = cosmomcdir+'plot_data/base_w_wa_plikHM_TTTEEE_lowTEB_BAO_H070p6_JLA_'+suffix0
    pts = np.loadtxt(file1+'_2D_'+str(ip2)+'_'+str(ip1)+'')
    X = Xfromdata(np.loadtxt(file1+'_p'+str(ip1)+'.dat'))
    Y = Xfromdata(np.loadtxt(file1+'_p'+str(ip2)+'.dat'))
    cnt = np.loadtxt(file1+'_2D_'+str(ip2)+'_'+str(ip1)+'_cont')
    cnt = array([cnt[1], cnt[0],cnt[0]/2,] )
    for ax in axlist:
        rlt = ax.contourf(X,Y,pts,cnt,  colors=[[1,0.7,1],[1,0.4,1]],  alpha=0.87, labels=['Approximate 2pCF','Approximate 2pCF'], 
                      linewidths=2, linestyles='-')
    
    file1 = cosmomcdir+'plot_data/base_w_wa_plikHM_TTTEEE_lowTEB_BAO_H070p6_JLA_'+suffix
    if suffix in ['cpl_union2p1_planck_bossdr11']:
        file1 = cosmomcdir+'plot_data/'+suffix
    pts = np.loadtxt(file1+'_2D_'+str(ip2)+'_'+str(ip1)+'')
    X = Xfromdata(np.loadtxt(file1+'_p'+str(ip1)+'.dat'))
    Y = Xfromdata(np.loadtxt(file1+'_p'+str(ip2)+'.dat'))
    cnt = np.loadtxt(file1+'_2D_'+str(ip2)+'_'+str(ip1)+'_cont')
    cnt = array([cnt[1], cnt[0]] )
    for ax in axlist:
        rlt = ax.contour(X,Y,pts,cnt,  colors=['k','k'], # alpha=0.87, labels=['Approximate 2pCF','Approximate 2pCF'], 
                      linewidths=2, linestyles='-')

    for ax in axlist:
        if iplot == 2: ax.plot([-100,-100],[-100,-100], c= [1,0.7,1], label='$\\rm'+label0+'$', lw=10)
        ax.plot([-100,-100],[-100,-100], c= 'k', label=label, lw=2)
        ax.legend(frameon=False, fontsize=24)
        #ax.scatter([-1],[0], marker='+', linewidth=3, s=150, c='g')
        ax.plot([-2,2],[0,0], linewidth=0.5, ls='--', c='g')
        ax.plot([-1,-1],[-5,5], linewidth=0.5, ls='--', c='g')
        #ax.grid();
        ax.set_xlabel(Par1, fontsize=24)
        ax.set_ylabel(Par2, fontsize=24)
        #if ip1 ==3 and ip2 == 4: ax.set_xlim(-1.33, -0.55); ax.set_ylim(-1.6,0.7)
        if ip1 ==3 and ip2 == 4: ax.set_xlim(-1.33, -0.7); ax.set_ylim(-1.03,0.85)
        if ip1 ==1 and ip2 == 3: ax.set_xlim(0.21, 0.41); ax.set_ylim(-1.33,-0.55)
        if ip1 ==1 and ip2 == 2: ax.set_xlim(0.21, 0.41); ax.set_ylim(0.655,0.723)
    if plot_single:
        # !mkdir -p ./Draft/fig_contours
        fig.savefig('./Draft/fig_contours/figCPL_b'+suffix+'.png', format='png')
    #fig.savefig('./Draft/fig_contours/figCPL_b'+suffix+'.'+figformat, format=figformat)
fig0.tight_layout()
#fig0.savefig('./Draft/fig_con_tests_Par_'+str(ip1)+'_'+str(ip2)+'_simple.png', format='png')

# %% [markdown]
# # More Models

# %% [raw]
# ###################
#
# ### Almost no improvement on Omega_k constraints
#
# ###################
#
# $ head base_omegak_plikHM_TTTEEE_lowTEB_BAO_H070p6_JLA_simple.margestats
# param  mean           sddev          lower1         upper1         lower2         upper2
#     1  0.3097957E+00  0.6465317E-02  0.3065917E+00  0.3127556E+00  0.2991222E+00  0.3210354E+00   \Omega_m
#     2  0.6777558E+00  0.6536968E-02  0.6711390E+00  0.6843120E+00  0.6647342E+00  0.6909454E+00   h
#     5  0.5481268E-03  0.1969945E-02 -0.1451070E-02  0.2532272E-02 -0.3372235E-02  0.4478392E-02   \Omega_k
#
# $ head base_omegak_plikHM_TTTEEE_lowTEB_BAO_H070p6_JLA___base1omws_om0.2600_w-1.0000__UseH0_Crosscheck.margestats
# param  mean           sddev          lower1         upper1         lower2         upper2
#     1  0.3089972E+00  0.6421336E-02  0.3060690E+00  0.3118984E+00  0.2980170E+00  0.3199396E+00   \Omega_m
#     2  0.6783694E+00  0.6520229E-02  0.6718658E+00  0.6848395E+00  0.6655550E+00  0.6917251E+00   h
#     5  0.5629236E-03  0.1964431E-02 -0.1426659E-02  0.2539779E-02 -0.3346995E-02  0.4471430E-02   \Omega_k

# %% [raw]
# #############
#
# # wCDM improved
#
# #############
#
# $ head base_w_plikHM_TTTEEE_lowTEB_BAO_H070p6_JLA_simple.margestats
# param  mean           sddev          lower1         upper1         lower2         upper2
#     1  0.3056907E+00  0.8929687E-02  0.3014196E+00  0.3098490E+00  0.2907785E+00  0.3207733E+00   \Omega_m
#     2  0.6828894E+00  0.9993926E-02  0.6728378E+00  0.6929980E+00  0.6635016E+00  0.7032982E+00   h
#     3 -0.1030080E+01  0.4057821E-01 -0.1070207E+01 -0.9893347E+00 -0.1113759E+01 -0.9518051E+00   w
#
# $head base_w_plikHM_TTTEEE_lowTEB_BAO_H070p6_JLA___base1omws_om0.2600_w-1.0000.margestats
# param  mean           sddev          lower1         upper1         lower2         upper2
#     1  0.3010870E+00  0.7818566E-02  0.2973030E+00  0.3044991E+00  0.2883365E+00  0.3150324E+00   \Omega_m
#     2  0.6886452E+00  0.8507105E-02  0.6802503E+00  0.6975845E+00  0.6708260E+00  0.7047683E+00   h
#     3 -0.1053344E+01  0.3395240E-01 -0.1087465E+01 -0.1020397E+01 -0.1121887E+01 -0.9819531E+00   w
#
# $ head base_w_plikHM_TTTEEE_lowTEB_BAO_H070p6_JLA___base1omws_om0.2600_w-1.0000_nosyscor.margestats
# param  mean           sddev          lower1         upper1         lower2         upper2
#     1  0.3033200E+00  0.8043119E-02  0.2994418E+00  0.3067182E+00  0.2900841E+00  0.3175346E+00   \Omega_m
#     2  0.6862228E+00  0.8745641E-02  0.6770809E+00  0.6948114E+00  0.6680484E+00  0.7034038E+00   h
#     3 -0.1046119E+01  0.3503583E-01 -0.1079163E+01 -0.1011545E+01 -0.1116900E+01 -0.9716147E+00   w

# %% [markdown]
# ### Omegam-w contours

# %%
cosmomcdir = '/home/xiaodongli/software/cosmomcs/12Oct_generic/'

fig, ax = figax(10,8)

file1 = cosmomcdir+'plot_data/base_w_wa_plikHM_TTTEEE_lowTEB_BAO_H070p6_JLA_simple'
pts = np.loadtxt(file1+'_2D_3_1')
X = Xfromdata(np.loadtxt(file1+'_p1.dat'))
Y = Xfromdata(np.loadtxt(file1+'_p3.dat'))
cnt = np.loadtxt(file1+'_2D_3_1_cont')
cnt = array([cnt[1], cnt[0],cnt[0]/2,] )
rlt = ax.contourf(X,Y,pts,cnt, colors=[[0,0.7,1],[0,0.4,1]], alpha=0.87, label='Approximate 2pCF', linewidths=2,)
#w0waCont_1sig, w0waCont_2sig = rlt.Cntr.trace(0), rlt.Cnt`r.trace(1)
ax.plot([-100,-100],[-100,-100], c= [0,0.7,1], label='CMB+BAO+SNIa+$H_0$, CPL', lw=10)

file1 = cosmomcdir+'plot_data/base_w_wa_plikHM_TTTEEE_lowTEB_BAO_H070p6_JLA___base1omws_om0.2600_w-1.0000'
pts = np.loadtxt(file1+'_2D_3_1')
X = Xfromdata(np.loadtxt(file1+'_p1.dat'))
Y = Xfromdata(np.loadtxt(file1+'_p3.dat'))
cnt = np.loadtxt(file1+'_2D_3_1_cont')
cnt = array([cnt[1], cnt[0],cnt[0]/2,] )
rlt = ax.contourf(X,Y,pts,cnt,  colors=[[1,0.7,1],[1,0.4,1]], alpha=0.87, label='Approximate 2pCF', linewidths=2, linestyles='-')
ax.plot([-100,-100],[-100,-100], c= [1,0.7,1], label='CMB+BAO+SNIa+$H_0$+AP, CPL', lw=10)

file1 = cosmomcdir+'plot_data/base_w_plikHM_TTTEEE_lowTEB_BAO_H070p6_JLA_simple'
pts = np.loadtxt(file1+'_2D_3_1')
X = Xfromdata(np.loadtxt(file1+'_p1.dat'))
Y = Xfromdata(np.loadtxt(file1+'_p3.dat'))
cnt = np.loadtxt(file1+'_2D_3_1_cont')
cnt = array([cnt[1], cnt[0],cnt[0]/2,] )
rlt = ax.contourf(X,Y,pts,cnt,  colors=[[1,0.7,0],[1,0.4,0]], alpha=0.87, label='Approximate 2pCF', linewidths=2, linestyles='-')
ax.plot([-100,-100],[-100,-100], c= [1,0.7,0], label='CMB+BAO+SNIa+$H_0$, wCDM', lw=10)

file1 = cosmomcdir+'plot_data/base_w_plikHM_TTTEEE_lowTEB_BAO_H070p6_JLA___base1omws_om0.2600_w-1.0000'
pts = np.loadtxt(file1+'_2D_3_1')
X = Xfromdata(np.loadtxt(file1+'_p1.dat'))
Y = Xfromdata(np.loadtxt(file1+'_p3.dat'))
cnt = np.loadtxt(file1+'_2D_3_1_cont')
cnt = array([cnt[1], cnt[0],cnt[0]/2,] )
rlt = ax.contourf(X,Y,pts,cnt,  colors=[[0,0.7,0],[0,0.4,0]], alpha=0.87, label='Approximate 2pCF', linewidths=2, linestyles='-')
ax.plot([-100,-100],[-100,-100], c= [0,0.7,0], label='CMB+BAO+SNIa+$H_0$+AP, wCDM', lw=10)

file1 = cosmomcdir+'plot_data/base_w_plikHM_TTTEEE_lowTEB_BAO_H070p6_JLA___base1omws_om0.2600_w-1.0000_nosyscor'
pts = np.loadtxt(file1+'_2D_3_1')
X = Xfromdata(np.loadtxt(file1+'_p1.dat'))
Y = Xfromdata(np.loadtxt(file1+'_p3.dat'))
cnt = np.loadtxt(file1+'_2D_3_1_cont')
cnt = array([cnt[1], cnt[0]] )
rlt = ax.contour(X,Y,pts,cnt,  colors='k', alpha=0.87, label='Approximate 2pCF', linewidths=2, linestyles='-')
ax.plot([-100,-100],[-100,-100], c= 'k', label='CMB+BAO+SNIa+$H_0$+AP, wCDM, No Sys Cor', lw=2)

if False:
    file1 = cosmomcdir+'plot_data/base_w_AP___base1omws_om0.2600_w-1.0000'
    pts = np.loadtxt(file1+'_2D_3_1')
    X = Xfromdata(np.loadtxt(file1+'_p1.dat'))
    Y = Xfromdata(np.loadtxt(file1+'_p3.dat'))
    cnt = np.loadtxt(file1+'_2D_3_1_cont')
    cnt = array([cnt[1], cnt[0],cnt[0]/2,] )
    rlt = ax.contourf(X,Y,pts,cnt,  colors=[[0.5,0.7,0.5],[0.5,0.4,0.5]], alpha=0.87, label='Approximate 2pCF', linewidths=2, linestyles='-')
    ax.plot([-100,-100],[-100,-100], c= [0.5,0.7,0.5], label='AP alone, wCDM', lw=10)

file1 = cosmomcdir+'plot_data/base_w_wa_AP___om0.2600_w-1.0000'
pts = np.loadtxt(file1+'_2D_3_1')
X = Xfromdata(np.loadtxt(file1+'_p1.dat'))
Y = Xfromdata(np.loadtxt(file1+'_p3.dat'))
cnt = np.loadtxt(file1+'_2D_3_1_cont')
cnt = array([cnt[1], cnt[0],cnt[0]/2,] )
rlt = ax.contourf(X,Y,pts,cnt,  colors=[[0.7,0.7,0.5],[0.7,0.6,0.5]], alpha=0.87, label='Approximate 2pCF', linewidths=2, linestyles='-')
ax.plot([-100,-100],[-100,-100], c= 'k', linestyle= '--', label='AP alone, CPL', lw=2)
ax.plot([-100,-100],[-100,-100], c= [0.7,0.7,0.5], label='AP alone, CPL', lw=10)

file1 = cosmomcdir+'plot_data/base_w_wa_AP___base1omws_om0.2600_w-1.0000_nosyscor_2'
pts = np.loadtxt(file1+'_2D_3_1')
X = Xfromdata(np.loadtxt(file1+'_p1.dat'))
Y = Xfromdata(np.loadtxt(file1+'_p3.dat'))
cnt = np.loadtxt(file1+'_2D_3_1_cont')
cnt = array([cnt[1], cnt[0]] )
rlt = ax.contour(X,Y,pts,cnt,  colors='k', alpha=0.87, label='Approximate 2pCF', linewidths=2, linestyles='--')
ax.plot([-100,-100],[-100,-100], c= 'k', linestyle= '--', label='AP alone, CPL (with sys)', lw=2)


ax.legend(frameon=False, fontsize=15)
ax.plot([0,1],[-1,-1], linewidth=0.5, ls='--', c='g')

#ax.grid()
ax.set_xlabel('$\\Omega_m$', fontsize=28)
ax.set_ylabel('$w_0$', fontsize=28)
ax.set_xlim(0.1,0.41)
ax.set_ylim(-1.4, -0.3)
#fig.savefig('./Draft/figCPL_a.'+figformat, format=figformat)
fig.savefig('./figCPL_effect_of_sys_omw0.'+figformat, format=figformat)

# %%
cosmomcdir = '/home/xiaodongli/software/cosmomcs/12Oct_generic/'

fig, ax = figax(12,6)

# AP alone
if False:
    file1 = cosmomcdir+'plot_data/base_w_wa_AP___base1omws_om0.2600_w-1.0000_fixom0.31'
    pts = np.loadtxt(file1+'_2D_4_3')
    X = Xfromdata(np.loadtxt(file1+'_p3.dat'))
    Y = Xfromdata(np.loadtxt(file1+'_p4.dat'))
    cnt = np.loadtxt(file1+'_2D_4_3_cont')
    cnt = array([cnt[1], cnt[0],cnt[0]/2,] )
    rlt1 = ax.contourf(X,Y,pts,cnt, colors=[[0.75,0.7,0.],[0.75,0.4,0.]], alpha=0.87, linewidths=2,)
    ax.plot([-100,-100],[-100,-100], c= [0.75,0.7,0.], label='AP alone (fix $\Omega_m=0.31$)', lw=10)
  
    
# CMB+BAO
if True:
    file1 = cosmomcdir+'plot_data/base_w_wa_plikHM_TTTEEE_lowTEB_BAO_simple'
    pts = np.loadtxt(file1+'_2D_4_3')
    X = Xfromdata(np.loadtxt(file1+'_p3.dat'))
    Y = Xfromdata(np.loadtxt(file1+'_p4.dat'))
    cnt = np.loadtxt(file1+'_2D_4_3_cont')
    cnt0 = array([cnt[1], cnt[0]])
    cnt = array([cnt[1], cnt[0],cnt[0]/2,] )
    if True:
        rlt1 = ax.contourf(X,Y,pts,cnt, colors=[[0,0.7,0.5],[0,0.4,0.5]], alpha=0.87,  linewidths=2,)
        ax.plot([-100,-100],[-100,-100], c= [0,0.7,0.5], label='CMB+BAO', lw=10)
    else:
        rlt1 = ax.contour(X,Y,pts,cnt0, colors=[[0,0.4,0.5],[0,0.4,0.5]],  alpha=0.5,linewidths=2,)
        ax.plot([-100,-100],[-100,-100], c= [0,0.4,0.5], label='CMB+BAO', alpha=0.5,lw=2,)

#CMB+BAO+H0
if False:
    file1 = cosmomcdir+'plot_data/base_w_wa_plikHM_TTTEEE_lowTEB_BAO_H0'
    pts = np.loadtxt(file1+'_2D_4_3')
    X = Xfromdata(np.loadtxt(file1+'_p3.dat'))
    Y = Xfromdata(np.loadtxt(file1+'_p4.dat'))
    cnt = np.loadtxt(file1+'_2D_4_3_cont')
    cnt = array([cnt[1], cnt[0],cnt[0]/2,] )
    rlt1 = ax.contourf(X,Y,pts,cnt, colors=[[0,0.7,0.5],[0,0.4,0.5]], alpha=0.87,  linewidths=2,)
    if True:
        rlt1 = ax.contourf(X,Y,pts,cnt, colors=[[0,0.7,0.5],[0,0.4,0.5]], alpha=0.87, linewidths=2,)
        ax.plot([-100,-100],[-100,-100], c= [0,0.7,0.5], label='CMB+BAO+$H_0$', lw=10)
    else:
        rlt1 = ax.contour(X,Y,pts,cnt0, colors=[[0,0.4,0.5],[0,0.4,0.5]], linewidths=2,)
        ax.plot([-100,-100],[-100,-100], c= [0,0.4,0.5], label='CMB+BAO+$H_0$', lw=2,)    
    #ax.plot([-100,-100],[-100,-100], c= [0,0.7,0.5], label='CMB+BAO+$H_0$', lw=10)
    
#CMB+BAO+SNIa+H0    
if True:
    file1 = cosmomcdir+'plot_data/base_w_wa_plikHM_TTTEEE_lowTEB_BAO_H070p6_JLA_simple'
    pts = np.loadtxt(file1+'_2D_4_3')
    X = Xfromdata(np.loadtxt(file1+'_p3.dat'))
    Y = Xfromdata(np.loadtxt(file1+'_p4.dat'))
    cnt = np.loadtxt(file1+'_2D_4_3_cont')
    cnt = array([cnt[1], cnt[0],cnt[0]/2,] )
    rlt1 = ax.contourf(X,Y,pts,cnt, colors=[[0,0.7,1],[0,0.4,1]], alpha=0.87,  linewidths=2,)
    #w0waCont_1sig, w0waCont_2sig = rlt.Cntr.trace(0), rlt.Cntr.trace(1)
    ax.plot([-100,-100],[-100,-100], c= [0,0.7,1], label='CMB+BAO+SNIa+$H_0$', lw=10)    

### CMB+BAO+AP    
if False:
    file1 = cosmomcdir+'plot_data/base_w_wa_plikHM_TTTEEE_lowTEB_BAO___base1omws_om0.2600_w-1.0000'
    pts = np.loadtxt(file1+'_2D_4_3')
    X = Xfromdata(np.loadtxt(file1+'_p3.dat'))
    Y = Xfromdata(np.loadtxt(file1+'_p4.dat'))
    cnt = np.loadtxt(file1+'_2D_4_3_cont')
    cnt = array([cnt[1], cnt[0],cnt[0]/2,] )
    rlt1 = ax.contourf(X,Y,pts,cnt, colors=[[1,0.7,0.5],[1,0.4,0.5]], alpha=0.87, linewidths=2,)
    ax.plot([-100,-100],[-100,-100], c= [1,0.7,0.5], label='CMB+BAO+AP', lw=10)

### CMB+BAO+AP+H0
if True:
    file1 = cosmomcdir+'plot_data/base_w_wa_plikHM_TTTEEE_lowTEB_BAO_H0____base1omws_om0.2600_w-1.0000'
    pts = np.loadtxt(file1+'_2D_4_3')
    X = Xfromdata(np.loadtxt(file1+'_p3.dat'))
    Y = Xfromdata(np.loadtxt(file1+'_p4.dat'))
    cnt = np.loadtxt(file1+'_2D_4_3_cont')
    cnt = array([cnt[1], cnt[0],cnt[0]/2,] )
    rlt1 = ax.contourf(X,Y,pts,cnt, colors=[[1,0.7,0.5],[1,0.4,0.5]], alpha=0.87, linewidths=2,)
    ax.plot([-100,-100],[-100,-100], c= [1,0.7,0.5], label='CMB+BAO+AP+$H_0$', lw=10)
 
## CMB+BAO+SNIa+AP+H0
if False:
    file1 = cosmomcdir+'plot_data/base_w_wa_plikHM_TTTEEE_lowTEB_BAO_H070p6_JLA___base1omws_om0.2600_w-1.0000'
    pts = np.loadtxt(file1+'_2D_4_3')
    X = Xfromdata(np.loadtxt(file1+'_p3.dat'))
    Y = Xfromdata(np.loadtxt(file1+'_p4.dat'))
    cnt = np.loadtxt(file1+'_2D_4_3_cont')
    cnt = array([cnt[1], cnt[0],cnt[0]/2,] )
    rlt2 = ax.contourf(X,Y,pts,cnt,  colors=[[1,0.7,1],[1,0.4,1]],  alpha=0.87,  
                      linewidths=2, linestyles='-')
    ax.plot([-100,-100],[-100,-100], c= [1,0.7,1], label='CMB+BAO+SNIa+AP+$H_0$', lw=10)

if True:
    file1 = cosmomcdir+'plot_data/base_w_wa_AP___om0.2600_w-1.0000'
    pts = np.loadtxt(file1+'_2D_4_3')
    X = Xfromdata(np.loadtxt(file1+'_p3.dat'))
    Y = Xfromdata(np.loadtxt(file1+'_p4.dat'))
    cnt = np.loadtxt(file1+'_2D_4_3_cont')
    cnt = array([cnt[1], cnt[0],cnt[0]/2,] )
    rlt1 = ax.contourf(X,Y,pts,cnt, colors=[[0.75,0.7,0.],[0.75,0.4,0.]], alpha=0.57, linewidths=2,)
    ax.plot([-100,-100],[-100,-100], c= [0.75,0.7,0.], alpha=0.57, label='AP alone', lw=10)

if True:
    file1 = cosmomcdir+'plot_data/base_w_wa_AP___base1omws_om0.2600_w-1.0000_nosyscor_2'
    pts = np.loadtxt(file1+'_2D_4_3')
    X = Xfromdata(np.loadtxt(file1+'_p3.dat'))
    Y = Xfromdata(np.loadtxt(file1+'_p4.dat'))
    cnt = np.loadtxt(file1+'_2D_4_3_cont')
    cnt = array([cnt[1], cnt[0],cnt[0]/2,] )
    rlt1 = ax.contourf(X,Y,pts,cnt, colors=[[0.25,0.7,0.75],[0.25,0.4,0.75]], alpha=0.57, linewidths=2,)
    ax.plot([-100,-100],[-100,-100], c= [0.25,0.4,0.75], alpha=0.57, label='AP alone (with sys)', lw=10)  

    
ax.legend(frameon=False, fontsize=15, loc='upper right')
#ax.scatter([-1],[0], marker='+', linewidth=3, s=150, c='g')
ax.plot([-2,2],[0,0], linewidth=0.5, ls='--', c='g')
ax.plot([-1,-1],[-5,5], linewidth=0.5, ls='--', c='g')
#ax.grid();
ax.set_xlabel('$w_0$', fontsize=28)
ax.set_ylabel('$w_a$', fontsize=28)
#ax.set_xlim(-1.35, -0.45); ax.set_ylim(-2.1,0.9)
#ax.set_xlim(-1.4, -0.3); ax.set_ylim(-2.5,0.9)
ax.set_xlim(-1.4,  0.3); ax.set_ylim(-2.4,0.9)
fig.tight_layout()
#fig.savefig('./Draft/figCPL_b_BAOSNIaAP.'+figformat, format=figformat)
#fig.savefig('./Draft/figCPL_b.'+figformat, format=figformat)

# %%
cosmomcdir = '/home/xiaodongli/software/cosmomcs/12Oct_generic/'

fig, ax = figax(12,6)


## CMB+BAO+SNIa+AP+H0
if True:
    file1 = cosmomcdir+'plot_data/base_w_wa_plikHM_TTTEEE_lowTEB_BAO_H070p6_JLA___base1omws_om0.2600_w-1.0000'
    pts = np.loadtxt(file1+'_2D_4_3')
    X = Xfromdata(np.loadtxt(file1+'_p3.dat'))
    Y = Xfromdata(np.loadtxt(file1+'_p4.dat'))
    cnt = np.loadtxt(file1+'_2D_4_3_cont')
    cnt = array([cnt[1], cnt[0],cnt[0]/2,] )
    rlt2 = ax.contourf(X,Y,pts,cnt,  colors=[[1,0.7,1],[1,0.4,1]],  alpha=0.87,  
                      linewidths=2, linestyles='-')
    ax.plot([-100,-100],[-100,-100], c= [1,0.7,1], label='CMB+BAO+SNIa+AP+$H_0$', lw=10)

## CMB+BAO+SNIa+AP+H0
if True:
    file1 = cosmomcdir+'plot_data/base_w_wa_plikHM_TTTEEE_lowTEB_BAO_H070p6_JLA___base1omws_om0.2600_w-1.0000_NoSysCor'
    pts = np.loadtxt(file1+'_2D_4_3')
    X = Xfromdata(np.loadtxt(file1+'_p3.dat'))
    Y = Xfromdata(np.loadtxt(file1+'_p4.dat'))
    cnt = np.loadtxt(file1+'_2D_4_3_cont')
    cnt = array([cnt[1], cnt[0]] )
    rlt2 = ax.contour(X,Y,pts,cnt,  colors='b',  alpha=1,  
                      linewidths=2, linestyles='--')
    ax.plot([-100,-100],[-100,-100], c= 'b', label='CMB+BAO+SNIa+AP+$H_0$ (with sys)', lw=2, ls='--',)
    
if True:
    file1 = cosmomcdir+'plot_data/base_w_wa_AP___om0.2600_w-1.0000'
    pts = np.loadtxt(file1+'_2D_4_3')
    X = Xfromdata(np.loadtxt(file1+'_p3.dat'))
    Y = Xfromdata(np.loadtxt(file1+'_p4.dat'))
    cnt = np.loadtxt(file1+'_2D_4_3_cont')
    cnt = array([cnt[1], cnt[0],cnt[0]/2,] )
    rlt1 = ax.contourf(X,Y,pts,cnt, colors=[[0.75,0.7,0.],[0.75,0.4,0.]], alpha=0.37, linewidths=2,)
    ax.plot([-100,-100],[-100,-100], c= [0.75,0.7,0.], alpha=0.37, label='AP alone', lw=10)

if True:
    file1 = cosmomcdir+'plot_data/base_w_wa_AP___base1omws_om0.2600_w-1.0000_nosyscor_2'
    pts = np.loadtxt(file1+'_2D_4_3')
    X = Xfromdata(np.loadtxt(file1+'_p3.dat'))
    Y = Xfromdata(np.loadtxt(file1+'_p4.dat'))
    cnt = np.loadtxt(file1+'_2D_4_3_cont')
    cnt = array([cnt[1], cnt[0],] )
    rlt1 = ax.contour(X,Y,pts,cnt, colors='k', alpha=1, linewidths=2, linestyles = '--')
    ax.plot([-100,-100],[-100,-100], c= 'k', alpha=1, label='AP alone (with sys)', lw=2, ls='--')  

    
ax.legend(frameon=False, fontsize=15, loc='upper right')
#ax.scatter([-1],[0], marker='+', linewidth=3, s=150, c='g')
ax.plot([-2,2],[0,0], linewidth=0.5, ls='--', c='g')
ax.plot([-1,-1],[-5,5], linewidth=0.5, ls='--', c='g')
#ax.grid();
ax.set_xlabel('$w_0$', fontsize=28)
ax.set_ylabel('$w_a$', fontsize=28)
#ax.set_xlim(-1.35, -0.45); ax.set_ylim(-2.1,0.9)
#ax.set_xlim(-1.4, -0.3); ax.set_ylim(-2.5,0.9)
ax.set_xlim(-1.4,  0.3); ax.set_ylim(-2.4,0.9)
fig.tight_layout()
fig.savefig('./figCPL_effect_of_sys.'+figformat, format=figformat)
#fig.savefig('./Draft/figCPL_b.'+figformat, format=figformat)

# %%
execfile('/home/xiaodongli/software/pythonlib/stdA.py')
execfile('/home/xiaodongli/software/pythonlib/Tpcftools.py')
execfile('/home/xiaodongli/software/pythonlib/Tpcftools_ChisqContour.py')
# %pylab inline
# Out:
# /home/xiaodongli/software/pythonlib/Tpcftools_smuintxi.py:536: SyntaxWarning: name 'oms' is assigned to before global declaration
#   global oms, ws, omws, scanname
# /home/xiaodongli/software/pythonlib/Tpcftools_smuintxi.py:536: SyntaxWarning: name 'ws' is assigned to before global declaration
#   global oms, ws, omws, scanname
# /home/xiaodongli/software/pythonlib/Tpcftools_smuintxi.py:536: SyntaxWarning: name 'omws' is assigned to before global declaration
#   global oms, ws, omws, scanname
# /home/xiaodongli/software/pythonlib/Tpcftools_smuintxi.py:536: SyntaxWarning: name 'scanname' is assigned to before global declaration
#   global oms, ws, omws, scanname
# WARNING:
# Populating the interactive namespace from numpy and matplotlib
# pylab import has clobbered these variables: ['copy']
# `%matplotlib` prevents importing * from pylab and numpy

# %% [markdown]
# #### Contours

# %%
figformat = 'pdf'
suffix_label_list0 = [
                ['__base2omws_om0.2600_w-1.0000_om0.3100_w-1.0000','default (new)'],
                #['cpl_union2p1_planck_bossdr11', '$\\rm Union2.1+Planck+BOSS DR11$'],
                ['__base2omws_om0.2600_w-1.0000_om0.3100_w-1.0000_mumax0.99','$\\rm \mu_{\\rm max}=0.99$'],
                #['__base2omws_om0.2600_w-1.0000_om0.3100_w-1.0000_mumax0.98','$\\rm \mu_{\\rm max}=0.98$'],
                ['__base2omws_om0.2600_w-1.0000_om0.3100_w-1.0000_mumax0.95','$\\rm \mu_{\\rm max}=0.95$'],
                #['__base2omws_om0.2600_w-1.0000_om0.3100_w-1.0000_mumax0.9','$\\rm \mu_{\\rm max}=0.9$'],
                #['__base2omws_om0.2600_w-1.0000_om0.3100_w-1.0000_mumax0.85','$\\rm \mu_{\\rm max}=0.85$'],
                #['__base2omws_om0.2600_w-1.0000_om0.3100_w-1.0000_smin5','$s_{\\rm min}=5$'],
                #['__base2omws_om0.2600_w-1.0000_om0.3100_w-1.0000_smin5_nbin10to20','$s_{\\rm min}=5,\ n_{\\rm bin}=10-20$'],
                #['__base2omws_om0.2600_w-1.0000_om0.3100_w-1.0000_smin7','$s_{\\rm min}=7$'],
                #['__base2omws_om0.2600_w-1.0000_om0.3100_w-1.0000_smin7_nbin15to20','$s_{\\rm min}=7,\ n_{\\rm bin}=15-20$'],
                #['__base2omws_om0.2600_w-1.0000_om0.3100_w-1.0000_smin7_nbin10to20','$s_{\\rm min}=7,\ n_{\\rm bin}=10-20$'],
                #['__base2omws_om0.2600_w-1.0000_om0.3100_w-1.0000_smin8','$s_{\\rm min}=8$'],
                ['__base2omws_om0.2600_w-1.0000_om0.3100_w-1.0000_smin8_nbin15to20','$s_{\\rm min}=8,\ n_{\\rm bin}=15-20$'],
                #['__base2omws_om0.2600_w-1.0000_om0.3100_w-1.0000_smin8_nbin10to20','$s_{\\rm min}=8,\ n_{\\rm bin}=10-20$'],
                #['__base1omws_om0.2600_w-1.0000_smin8_nbin10to20_mumax0.85','$s_{\\rm min}=8,\ n_{\\rm bin}=10-20,\ \\mu_{\\rm max}=0.85$'],
                #['__base2omws_om0.2600_w-1.0000_om0.3100_w-1.0000_smin9','$s_{\\rm min}=9$'],
                #['__base2omws_om0.2600_w-1.0000_om0.3100_w-1.0000_smin9_nbin10to20','$s_{\\rm min}=9,\ n_{\\rm bin}=10-20$'],
                #['__base2omws_om0.2600_w-1.0000_om0.3100_w-1.0000_smin10_B','$s_{\\rm min}=10$'],
                #['__base2omws_om0.2600_w-1.0000_om0.3100_w-1.0000_smin10_nbin10to20','$s_{\\rm min}=10,\ n_{\\rm bin}=10-20$'],
                #['__base2omws_om0.2600_w-1.0000_om0.3100_w-1.0000_smin15_B','$s_{\\rm min}=15$'],
                #['__base2omws_om0.2600_w-1.0000_om0.3100_w-1.0000_smin15_nbin10to20','$s_{\\rm min}=15,\ n_{\\rm bin}=10-20$'],
                #['__base2omws_om0.2600_w-1.0000_om0.3100_w-1.0000_smin20_B','$s_{\\rm min}=20$'],
                #['__base2omws_om0.2600_w-1.0000_om0.3100_w-1.0000_smin20_nbin10to20','$s_{\\rm min}=20,\ n_{\\rm bin}=10-20$'],
                #['__base2omws_om0.2600_w-1.0000_om0.3100_w-1.0000_smax30','$s_{\\rm max}=30$'],
                ['__base2omws_om0.2600_w-1.0000_om0.3100_w-1.0000_smax50','$s_{\\rm max}=50$'],
                ['__base1omws_om0.2600_w-1.0000','$\\rm fiducial:\\ \Omega_m=0.26,\\ w=-1.0$'],
                ['__base1omws_om0.3100_w-1.0000','$\\rm fiducial:\\ \Omega_m=0.31,\\ w=-1.0$'],
                #['__base1omws_om0.2600_w-1.4000','$\\rm fiducial:\\ \Omega_m=0.26,\\ w=-1.4$'],
                #['__base1omws_om0.2600_w-0.6000','$\\rm fiducial:\\ \Omega_m=0.26,\\ w=-0.6$'],
                #['__base1omws_om0.3100_w-1.4000','$\\rm fiducial:\\ \Omega_m=0.31,\\ w=-1.4$'],
                ['__base2omws_om0.2600_w-0.6000_om0.2600_w-1.4000','$\\rm fiducial:\\ \Omega_m=0.26,\\ w=-0.6/-1.4$'],
                ['__base2omws_om0.3100_w-0.6000_om0.3100_w-1.4000','$\\rm fiducial:\\ \Omega_m=0.31,\\ w=-0.6/-1.4$'],
                ['__base1omws_om0.3100_w-0.6000','$\\rm fiducial:\\ \Omega_m=0.31,\\ w=-0.6$'],
                ['__base1omws_om0.1100_w-2.0000','$\\rm fiducial:\\ \Omega_m=0.11,\\ w=-2.0$'],
                #['__base2omws_om0.2600_w-1.0000_om0.3100_w-1.0000_nbin25to30','$\\rm n_{\\rm bin}=25-30$'],
                ['__base2omws_om0.2600_w-1.0000_om0.3100_w-1.0000_nbin15to20','$\\rm n_{\\rm bin}=15-20$'],
                ['__base2omws_om0.2600_w-1.0000_om0.3100_w-1.0000_1000mocks','$\\rm n_{\\rm mock}=1000$'],
                #['__base2omws_om0.2600_w-1.0000_om0.3100_w-1.0000_nopolyfit','$\\rm No\ Poly\ Fit\ In\ Sys\ Cor$'],
                ['__base2omws_om0.2600_w-1.0000_om0.3100_w-1.0000_NoLastBin','$\\rm Exclude\ Last\ Redshift\ Bin$'],
                ['__base2omws_om0.2600_w-1.0000_om0.3100_w-1.0000_nosyscor','No sys-correction'],
                ]

# %%
ip1 = 3; ip2 = 4; maxip = max(ip1,ip2); minip = min(ip1,ip2)

ParNames = ['$\\Omega_m$', '$h$', '$w_0$', '$w_a$']
Par1 = ParNames[ip1-1]; Par2=ParNames[ip2-1]

cosmomcdir = '/home/xiaodongli/software/cosmomcs/12Oct_generic/'
suffix_label0 = ['__base1omws_om0.2600_w-1.0000','default']
suffix_label_list = [
                #['__base2omws_om0.2600_w-1.0000_om0.3100_w-1.0000','$\\rm fiducial:\\ \Omega_m = 0.26/0.31$'],
                #['cpl_union2p1_planck_bossdr11', '$\\rm Union2.1+Planck+BOSS DR11$'],
                ['__base1omws_om0.2600_w-1.0000_mumax0.99','$\\rm \mu_{\\rm max}=0.99$'],
                #['__base1omws_om0.2600_w-1.0000_mumax0.98','$\\rm \mu_{\\rm max}=0.98$'],
                #['__base1omws_om0.2600_w-1.0000_mumax0.95','$\\rm \mu_{\\rm max}=0.95$'],
                #['__base1omws_om0.2600_w-1.0000_mumax0.90','$\\rm \mu_{\\rm max}=0.90$'],
                #['__base1omws_om0.2600_w-1.0000_mumax0.85','$\\rm \mu_{\\rm max}=0.85$'],
                #['__base1omws_om0.2600_w-1.0000_mumax0.6','$\\rm \mu_{\\rm max}=0.60$'],
                #['__base1omws_om0.2600_w-1.0000_mumax0.70','$\\rm \mu_{\\rm max}=0.70$'],
                #['__base1omws_om0.2600_w-1.0000_mumax0.50','$\\rm \mu_{\\rm max}=0.50$'],
                #['__base1omws_om0.2600_w-1.0000_nbins10to15','$n_{\\rm bin}=10-15$'],
                ['__base1omws_om0.2600_w-1.0000_nbins15to20','$n_{\\rm bin}=15-20$'],
                #['__base1omws_om0.2600_w-1.0000_nbins20to22','$n_{\\rm bin}=20-22$'],
                #['__base1omws_om0.2600_w-1.0000_nbins23to25','$n_{\\rm bin}=23-25$'],
                #['__base1omws_om0.2600_w-1.0000_nbins25to30','$n_{\\rm bin}=25-30$'],
                ##['__base1omws_om0.2600_w-1.0000_nbins30to35','$n_{\\rm bin}=30-35$'],
                ##['__base1omws_om0.2600_w-1.0000_nbins35to40','$n_{\\rm bin}=35-40$'],
                #['__base1omws_om0.2600_w-1.0000_smax30','$s_{\\rm max}=30$'],
                ['__base1omws_om0.2600_w-1.0000_smax35','$s_{\\rm max}=35$'],
                #['__base1omws_om0.2600_w-1.0000_smax40','$s_{\\rm max}=40$'],
                ['__base1omws_om0.2600_w-1.0000_smax45','$s_{\\rm max}=45$'],
                #['__base1omws_om0.2600_w-1.0000_smax50','$s_{\\rm max}=50$'],
                #['__base1omws_om0.2600_w-1.0000_smin4_nbin15to20','$s_{\\rm min}=4,\ n_{\\rm bin}=15-20$'],
                #['__base1omws_om0.2600_w-1.0000_smin5_nbin15to20','$s_{\\rm min}=5,\ n_{\\rm bin}=15-20$'],
                #['__base1omws_om0.2600_w-1.0000_smin7_nbins20to25','$s_{\\rm min}=7,\ n_{\\rm bin}=20-25$'],
                #['__base1omws_om0.2600_w-1.0000_smin8_nbin15to20','$s_{\\rm min}=8,\ n_{\\rm bin}=15-20$'],
                ['__base1omws_om0.2600_w-1.0000_smin8_nbins20to25','$s_{\\rm min}=8$'],
                #['__base1omws_om0.2600_w-1.0000_smin10_nbin15to20','$s_{\\rm min}=10,\ n_{\\rm bin}=15-20$'],
                #['__base1omws_om0.2600_w-1.0000_smin15_nbin15to20','$s_{\\rm min}=15,\ n_{\\rm bin}=15-20$'],
                #['__base1omws_om0.3100_w-1.0000','$\\rm fiducial:\\ \Omega_m=0.31,\\ w=-1.0$'],
                ##['__base1omws_om0.3100_w-1.0000_smax40','$\\rm fiducial:\\ \Omega_m=0.31,\\ w=-1.0, B$'],
                #['__base1omws_om0.2600_w-1.4000','$\\rm fiducial:\\ \Omega_m=0.26,\\ w=-1.4$'],
                ['__base1omws_om0.2600_w-0.6000','$\\rm fiducial:\\ \Omega_m=0.26,\\ w=-0.6$'],
                #['__base1omws_om0.3100_w-1.4000','$\\rm fiducial:\\ \Omega_m=0.31,\\ w=-1.4$'],
                #['__base1omws_om0.3100_w-0.6000','$\\rm fiducial:\\ \Omega_m=0.31,\\ w=-0.6$'],
                ['__base1omws_om0.1100_w-2.0000','$\\rm fiducial:\\ \Omega_m=0.11,\\ w=-2.0$'],
                #['__base1omws_om0.2600_w-1.0000_nopolyfit','$\\rm No\\ Poly\\ Fit$'],
                ['__base1omws_om0.2600_w-1.0000_ExcludeLastBin','$\\rm Exclude\\ Last\\ Red\\ Bin$'],
                ['__base1omws_om0.2600_w-1.0000_ExcludeLastTwoBins','$\\rm Exclude\\ Last\\ 2\\ Red\\ Bin$'],
                #['__base1omws_om0.2600_w-1.0000_ExcludeLastThreeBins','$\\rm Exclude\\ Last\\ 3\\ Red\\ Bin$'],
                #['__base1omws_om0.2600_w-1.0000_ExcludeLastThreeBins_B','$\\rm Exclude\\ Last\\ 3\\ Red\\ Bin,B$'],
                #['__base1omws_om0.2600_w-1.0000_RedBins23','$\\rm 2,3th\\ Red\\ Bins$'],
                #['__base1omws_om0.2600_w-1.0000_RedBins2','$\\rm Red\\ Bin\\ 1,2$'],
                #['__base1omws_om0.2600_w-1.0000_RedBins3','$\\rm Red\\ Bin\\ 1,3$'],
                #['__base1omws_om0.2600_w-1.0000_RedBins4','$\\rm Red\\ Bin\\ 1,4$'],
                #['__base1omws_om0.2600_w-1.0000_RedBins5','$\\rm Red\\ Bin\\ 1,5$'],
                #['__base1omws_om0.2600_w-1.0000_RedBins6','$\\rm Red\\ Bin\\ 1,6$'],
                ['__base1omws_om0.2600_w-1.0000_NoSysCor','$\\rm With\\ Systematics$'],
                ['__base1omws_om0.2600_w-1.0000_nmock1000','$\\rm 1000\ mocks$'],
                #['__base1omws_om0.2600_w-1.0000_nmock200','$\\rm 200\ mocks$'],
                ]
plot_single = False
nplot = len(suffix_label_list);
ncol = 4; nrow = int(nplot/(ncol+0.0)+0.99)
fig0 = plt.figure(figsize=(ncol*7,nrow*6));
iplot = 1
for suffix_label in suffix_label_list:    
    suffix, label = suffix_label
    ax0 = fig0.add_subplot(nrow,ncol,iplot); iplot+=1
    if plot_single: 
        fig1, ax1 = figax()
        axlist = [ax0, ax1]
    else:
        axlist = [ax0]
    
    if False:
        file1 = cosmomcdir+'plot_data/base_w_wa_plikHM_TTTEEE_lowTEB_BAO_H070p6_JLA_simple'
        pts = np.loadtxt(file1+'_2D_'+str(ip2)+'_'+str(ip1)+'')
        X = Xfromdata(np.loadtxt(file1+'_p'+str(ip1)+'.dat'))
        Y = Xfromdata(np.loadtxt(file1+'_p'+str(ip2)+'.dat'))
        cnt = np.loadtxt(file1+'_2D_'+str(ip2)+'_'+str(ip1)+'_cont')
        cnt = array([cnt[1], cnt[0],cnt[0]/2,] )
        for ax in axlist:
            rlt = ax.contourf(X,Y,pts,cnt, colors=[[0,0.7,1],[0,0.4,1]], alpha=0.87, label='Approximate 2pCF', linewidths=2,)
        #w0waCont_1sig, w0waCont_2sig = rlt.Cntr.trace(0), rlt.Cntr.trace(1)

    suffix0, label0 = suffix_label0
    file1 = cosmomcdir+'plot_data/base_w_wa_plikHM_TTTEEE_lowTEB_BAO_H070p6_JLA_'+suffix0
    pts = np.loadtxt(file1+'_2D_'+str(ip2)+'_'+str(ip1)+'')
    X = Xfromdata(np.loadtxt(file1+'_p'+str(ip1)+'.dat'))
    Y = Xfromdata(np.loadtxt(file1+'_p'+str(ip2)+'.dat'))
    cnt = np.loadtxt(file1+'_2D_'+str(ip2)+'_'+str(ip1)+'_cont')
    cnt = array([cnt[1], cnt[0],cnt[0]/2,] )
    for ax in axlist:
        rlt = ax.contourf(X,Y,pts,cnt,  colors=[[1,0.7,1],[1,0.4,1]],  alpha=0.87, labels=['Approximate 2pCF','Approximate 2pCF'], 
                      linewidths=2, linestyles='-')
    
    file1 = cosmomcdir+'plot_data/base_w_wa_plikHM_TTTEEE_lowTEB_BAO_H070p6_JLA_'+suffix
    if suffix in ['cpl_union2p1_planck_bossdr11']:
        file1 = cosmomcdir+'plot_data/'+suffix
    pts = np.loadtxt(file1+'_2D_'+str(ip2)+'_'+str(ip1)+'')
    X = Xfromdata(np.loadtxt(file1+'_p'+str(ip1)+'.dat'))
    Y = Xfromdata(np.loadtxt(file1+'_p'+str(ip2)+'.dat'))
    cnt = np.loadtxt(file1+'_2D_'+str(ip2)+'_'+str(ip1)+'_cont')
    cnt = array([cnt[1], cnt[0]] )
    for ax in axlist:
        rlt = ax.contour(X,Y,pts,cnt,  colors=['k','k'], # alpha=0.87, labels=['Approximate 2pCF','Approximate 2pCF'], 
                      linewidths=2, linestyles='-')

    for ax in axlist:
        #ax.plot([-100,-100],[-100,-100], c= [0,0.7,1], label='CMB+BAO+SN+$H_0$', lw=10)
        #ax.plot([-100,-100],[-100,-100], c= [1,0.7,1], label='CMB+BAO+SN+$H_0$+AP,\n'+label0, lw=10)
        #ax.plot([-100,-100],[-100,-100], c= 'k', label='CMB+BAO+SN+$H_0$+AP,\n'+label, lw=2)
        if iplot == 2: ax.plot([-100,-100],[-100,-100], c= [1,0.7,1], label='$\\rm'+label0+'$', lw=10)
        ax.plot([-100,-100],[-100,-100], c= 'k', label=label, lw=2)
        ax.legend(frameon=False, fontsize=24)
        #ax.scatter([-1],[0], marker='+', linewidth=3, s=150, c='g')
        ax.plot([-2,2],[0,0], linewidth=0.5, ls='--', c='g')
        ax.plot([-1,-1],[-5,5], linewidth=0.5, ls='--', c='g')
        #ax.grid();
        ax.set_xlabel(Par1, fontsize=24)
        ax.set_ylabel(Par2, fontsize=24)
        #if ip1 ==3 and ip2 == 4: ax.set_xlim(-1.33, -0.55); ax.set_ylim(-1.6,0.7)
        if ip1 ==3 and ip2 == 4: ax.set_xlim(-1.33, -0.7); ax.set_ylim(-1.03,0.85)
        if ip1 ==1 and ip2 == 3: ax.set_xlim(0.21, 0.41); ax.set_ylim(-1.33,-0.55)
        if ip1 ==1 and ip2 == 2: ax.set_xlim(0.21, 0.41); ax.set_ylim(0.655,0.723)
    if plot_single:
        # !mkdir -p ./Draft/fig_contours
        fig.savefig('./Draft/fig_contours/figCPL_b'+suffix+'.png', format='png')
    #fig.savefig('./Draft/fig_contours/figCPL_b'+suffix+'.'+figformat, format=figformat)
fig0.tight_layout()
#fig0.savefig('./Draft/fig_con_tests_Par_'+str(ip1)+'_'+str(ip2)+'.png', format='png')
fig0.savefig('./Draft/fig_con_tests.pdf', format='pdf')
#fig0.savefig('./Draft/fig_con_tests_Par_'+str(ip1)+'_'+str(ip2)+'_simple.png', format='png')

# %%
cosmomcdir = '/home/xiaodongli/software/cosmomcs/12Oct_generic/'

fig, ax = figax()

file1 = cosmomcdir+'plot_data/base_w_wa_plikHM_TTTEEE_lowTEB_BAO_H070p6_JLA_simple'
pts = np.loadtxt(file1+'_2D_3_1')
X = Xfromdata(np.loadtxt(file1+'_p1.dat'))
Y = Xfromdata(np.loadtxt(file1+'_p3.dat'))
cnt = np.loadtxt(file1+'_2D_3_1_cont')
cnt = array([cnt[1], cnt[0],cnt[0]/2,] )
rlt = ax.contourf(X,Y,pts,cnt, colors=[[0,0.7,1],[0,0.4,1]], alpha=0.87, label='Approximate 2pCF', linewidths=2,)
#w0waCont_1sig, w0waCont_2sig = rlt.Cntr.trace(0), rlt.Cnt`r.trace(1)

file1 = cosmomcdir+'plot_data/base_w_wa_plikHM_TTTEEE_lowTEB_BAO_H070p6_JLA_base2omws_om0.2600_w-1.0000_om0.3100_w-1.0000'
pts = np.loadtxt(file1+'_2D_3_1')
X = Xfromdata(np.loadtxt(file1+'_p1.dat'))
Y = Xfromdata(np.loadtxt(file1+'_p3.dat'))
cnt = np.loadtxt(file1+'_2D_3_1_cont')
cnt = array([cnt[1], cnt[0],cnt[0]/2,] )
rlt = ax.contourf(X,Y,pts,cnt,  colors=[[1,0.7,1],[1,0.4,1]], alpha=0.87, label='Approximate 2pCF', linewidths=2, linestyles='-')

ax.plot([-100,-100],[-100,-100], c= [0,0.7,1], label='CMB+BAO+SNIa+$H_0$', lw=10)
ax.plot([-100,-100],[-100,-100], c= [1,0.7,1], label='CMB+BAO+SNIa+$H_0$+AP', lw=10)
ax.legend(frameon=False, fontsize=15)
ax.plot([0,1],[-1,-1], linewidth=0.5, ls='--', c='g')

#ax.grid()
ax.set_xlabel('$\\Omega_m$', fontsize=28)
ax.set_ylabel('$w_0$', fontsize=28)
ax.set_xlim(0.21,0.41)
ax.set_ylim(-1.25, -0.55)
fig.savefig('./Draft/figCPL_a.'+figformat, format=figformat)

# %%
cosmomcdir = '/home/xiaodongli/software/cosmomcs/12Oct_generic/'

fig, ax = figax()

file1 = cosmomcdir+'plot_data/base_w_wa_plikHM_TTTEEE_lowTEB_BAO_H070p6_JLA_simple'
pts = np.loadtxt(file1+'_2D_4_3')
X = Xfromdata(np.loadtxt(file1+'_p3.dat'))
Y = Xfromdata(np.loadtxt(file1+'_p4.dat'))
cnt = np.loadtxt(file1+'_2D_4_3_cont')
cnt = array([cnt[1], cnt[0],cnt[0]/2,] )
rlt = ax.contourf(X,Y,pts,cnt, colors=[[0,0.7,1],[0,0.4,1]], alpha=0.87, label='Approximate 2pCF', linewidths=2,)
#w0waCont_1sig, w0waCont_2sig = rlt.Cntr.trace(0), rlt.Cntr.trace(1)

file1 = cosmomcdir+'plot_data/base_w_wa_plikHM_TTTEEE_lowTEB_BAO_H070p6_JLA_base2omws_om0.2600_w-1.0000_om0.3100_w-1.0000'
pts = np.loadtxt(file1+'_2D_4_3')
X = Xfromdata(np.loadtxt(file1+'_p3.dat'))
Y = Xfromdata(np.loadtxt(file1+'_p4.dat'))
cnt = np.loadtxt(file1+'_2D_4_3_cont')
cnt = array([cnt[1], cnt[0],cnt[0]/2,] )
rlt = ax.contourf(X,Y,pts,cnt,  colors=[[1,0.7,1],[1,0.4,1]],  alpha=0.87, labels=['Approximate 2pCF','Approximate 2pCF'], 
                  linewidths=2, linestyles='-')

ax.plot([-100,-100],[-100,-100], c= [0,0.7,1], label='CMB+BAO+SNIa+$H_0$', lw=10)
ax.plot([-100,-100],[-100,-100], c= [1,0.7,1], label='CMB+BAO+SNIa+$H_0$+AP', lw=10)
ax.legend(frameon=False, fontsize=15)
#ax.scatter([-1],[0], marker='+', linewidth=3, s=150, c='g')
ax.plot([-2,2],[0,0], linewidth=0.5, ls='--', c='g')
ax.plot([-1,-1],[-5,5], linewidth=0.5, ls='--', c='g')
#ax.grid();
ax.set_xlabel('$w_0$', fontsize=28)
ax.set_ylabel('$w_a$', fontsize=28)
ax.set_xlim(-1.33, -0.55)
ax.set_ylim(-1.6,0.7)
fig.savefig('./Draft/figCPL_b.'+figformat, format=figformat)

# %%
cosmomcdir = '/home/xiaodongli/software/cosmomcs/12Oct_generic/'

fig, ax = figax()

file1 = cosmomcdir+'plot_data/base_w_wa_plikHM_TTTEEE_lowTEB_BAO_H070p6_JLA_simple'
pts = np.loadtxt(file1+'_2D_2_1')
X = Xfromdata(np.loadtxt(file1+'_p1.dat'))
Y = Xfromdata(np.loadtxt(file1+'_p2.dat'))
cnt = np.loadtxt(file1+'_2D_2_1_cont')
cnt = array([cnt[1], cnt[0],cnt[0]/2,] )
rlt = ax.contourf(X,Y,pts,cnt, colors=[[0,0.7,1],[0,0.4,1]], alpha=0.87, label='Approximate 2pCF', linewidths=2,)
#w0waCont_1sig, w0waCont_2sig = rlt.Cntr.trace(0), rlt.Cntr.trace(1)


file1 = cosmomcdir+'plot_data/base_w_wa_plikHM_TTTEEE_lowTEB_BAO_H070p6_JLA_base2omws_om0.2600_w-1.0000_om0.3100_w-1.0000'
pts = np.loadtxt(file1+'_2D_2_1')
X = Xfromdata(np.loadtxt(file1+'_p1.dat'))
Y = Xfromdata(np.loadtxt(file1+'_p2.dat'))
cnt = np.loadtxt(file1+'_2D_2_1_cont')
cnt = array([cnt[1], cnt[0],cnt[0]/2,] )
rlt = ax.contourf(X,Y,pts,cnt,  colors=[[1,0.7,1],[1,0.4,1]],  alpha=0.87, labels=['Approximate 2pCF','Approximate 2pCF'], 
                  linewidths=2, linestyles='-')

ax.plot([-100,-100],[-100,-100], c= [0,0.7,1], label='CMB+BAO+SNIa+$H_0$', lw=10)
ax.plot([-100,-100],[-100,-100], c= [1,0.7,1], label='CMB+BAO+SNIa+$H_0$+AP', lw=10)
ax.legend(frameon=False, fontsize=15)
#ax.grid();
ax.set_xlabel('$\Omega_m$', fontsize=28)
ax.set_ylabel('$h$', fontsize=28)
ax.set_xlim(0.23, 0.41)
ax.set_ylim(0.655,0.723)
fig.savefig('./Draft/figCPL_c.'+figformat, format=figformat,  )

# %%
zs = np.linspace(0.0001, 2.5001, 251)
fig, ax = figax()
iplot = 0
for basename in [
  'base_w_wa_plikHM_TTTEEE_lowTEB_BAO_H070p6_JLA_simple',
  'base_w_wa_plikHM_TTTEEE_lowTEB_BAO_H070p6_JLA_base2omws_om0.2600_w-1.0000_om0.3100_w-1.0000',
    ]:
    
        if False:
            for numchain in [1,2,3,4]:
                chaindir = '/home/xiaodongli/software/cosmomcs/12Oct_generic/chains/wcdm/plikHM_TTTEEE_lowTEB_BAO_H070p6_JLA/'
                nowfile1 = chaindir + basename + '_'+str(numchain)+'.txt'
                nowfile2 = chaindir + basename + '_wz_'+str(numchain)+'.txt'
                print  'Reading  :', nowfile1
                print  'Write to :', nowfile2
                nowf1 = open(nowfile1, 'r'); nowf2 = open(nowfile2, 'w')
                while True:
                    nowstr = nowf1.readline()
                    if nowstr == '': break
                    weight, lnlike, omegam, h, w0, wa, omk = str_to_numbers(nowstr)
                    wzs = [w0+wa*z/(1.0+z) for z in zs]
                    nowf2.write(array_to_str_fmtted([float(weight),float(lnlike)]+wzs, fmt='%.4f')+'\n')
                nowf1.close(); nowf2.close()
        if True:
            margfile = '/home/xiaodongli/software/cosmomcs/12Oct_generic/'+basename + '_wz.margestats'
            nowf = open(basename+'.wz.txt', 'w');  margf = open(margfile,'r')
            print 'Write to ', basename+'.wz.txt'
            margf.readline();
            for iz in range(len(zs)):
                nowz = zs[iz]; 
                words = [float(xx) for xx in margf.readline().split()[0:7]];
                w, w1s_low, w1s_up, w2s_low, w2s_up = words[1], words[3],words[4],words[5],words[6]
                nowf.write(str(nowz)+' '+array_to_str_fmtted([w, w1s_low, w1s_up, w2s_low, w2s_up])+'\n')
            nowf.close(); margf.close()
        if True:
            nowfile = basename+'.wz.txt'; print 'Read from  ', nowfile
            Z, W0, W1,W2, W3,W4 = Xsfromdata(np.loadtxt(nowfile), range(6))
            #ax.plot(Z,W0, lw=2, ls='--', c=C1)
            if iplot == 0:
                nowlab = 'CMB+BAO+SNIa+$H_0$'
                C1, C2 = [0,0.7,1],[0,0.4,1]
                alpha = 1
            else:
                nowlab = 'CMB+BAO+SNIa+$H_0$+AP'
                C1, C2 = [1,0.7,1],[1,0.4,1]
                alpha = 0.8
            #ax.plot(Z+reverse_1darray(Z)+[Z[0]],W1+reverse_1darray(W2)+[W1[0]], lw=1, c=C1,fillstyle='bottom' ); #ax.plot(Z,W2, lw=1, c=C1, label=nowlab)
            #ax.fill(Z,W1,'b', meth='fill_between')
            
            ax.fill_between(Z,W3,W4, color=C1, alpha=alpha )
            ax.fill_between(Z,W1,W2, color=C2, alpha=alpha )
            ax.plot([0,0],[1000,1000], color=C2, lw=8,label=nowlab)
            #ax.plot(Z+reverse_1darray(Z),W3+reverse_1darray(W4), lw=2, ls='-',  c=C2, ); #ax.plot(Z,W4, lw=2, c=C1)
            iplot += 1
#ax.plot([0,10], [-1,-1], lw=0.5, c='k', ls='--'); 
#ax.grid()
ax.set_xlabel('$z$', fontsize=28)
ax.set_ylabel('$w(z)$', fontsize=28)
ax.legend(frameon=False)
ax.set_xlim(0.0,0.75); ax.set_ylim(-1.35,-0.65)
fig.savefig('./Draft/figCPL_d.'+figformat, format=figformat)
# Out:
# Write to  base_w_wa_plikHM_TTTEEE_lowTEB_BAO_H070p6_JLA_simple.wz.txt
# Read from   base_w_wa_plikHM_TTTEEE_lowTEB_BAO_H070p6_JLA_simple.wz.txt
# Write to  base_w_wa_plikHM_TTTEEE_lowTEB_BAO_H070p6_JLA_base2omws_om0.2600_w-1.0000_om0.3100_w-1.0000.wz.txt
# Read from   base_w_wa_plikHM_TTTEEE_lowTEB_BAO_H070p6_JLA_base2omws_om0.2600_w-1.0000_om0.3100_w-1.0000.wz.txt

# %%
cosmomcdir = '/home/xiaodongli/software/cosmomcs/12Oct_generic/'

fig, ax = figax()

file1 = cosmomcdir+'plot_data/base_w_wa_plikHM_TTTEEE_lowTEB_BAO_H070p6_JLA___6mu20to25_1mumax0.97to0.97_Ints6.0to40.0_2000covmocks.polyfitdeg3_base2o'
pts = np.loadtxt(file1)
X = Xfromdata(np.loadtxt(file1+'_p1.dat'))
Y = Xfromdata(np.loadtxt(file1+'_p3.dat'))
cnt = np.loadtxt(file1+'_cont')

rlt = ax.contour(X,Y,pts,cnt, label='Approximate 2pCF', lw=5)

file1 = cosmomcdir+'plot_data/base_w_wa_plikHM_TTTEEE_lowTEB_BAO_H070p6_JLA_simple'
pts = np.loadtxt(file1+'_2D_3_1')
X = Xfromdata(np.loadtxt(file1+'_p1.dat'))
Y = Xfromdata(np.loadtxt(file1+'_p3.dat'))
cnt = np.loadtxt(file1+'_2D_3_1_cont')

rlt = ax.contour(X,Y,pts,cnt, label='Approximate 2pCF')

#ax.legend(loc='best')

# %% [markdown]
# ##### Plot w0-wa contour: smaller than precise contour, should be due to small number of samples

# %%
fig, ax = figax()

for file1 in [
              #'/home/xiaodongli/software/cosmomcs/12Oct_generic/plot_data/cpl_ap', 
              #'/home/xiaodongli/software/cosmomcs/12Oct_generic/plot_data/cpl_ap_post_bossdr9_planck', 
              '/home/xiaodongli/software/cosmomcs/12Oct_generic/plot_data/cpl_bossdr9_planck',
              #'/home/xiaodongli/software/cosmomcs/12Oct_generic/plot_data/wcdm_ap_ok',
              ]:
    pts = np.loadtxt(file1+'_2D_4_3')
    X = Xfromdata(np.loadtxt(file1+'_p3.dat'))
    Y = Xfromdata(np.loadtxt(file1+'_p4.dat'))
    cnt = np.loadtxt(file1+'_2D_4_3_cont')
    rlt = ax.contour(X,Y,pts,cnt)

# %%
fig, ax = figax()

for file1 in [
              '/home/xiaodongli/software/cosmomcs/12Oct_generic/plot_data/wcdm_ap', 
              #'/home/xiaodongli/software/cosmomcs/12Oct_generic/plot_data/wcdm_ap_ok',
              ]:
    pts = np.loadtxt(file1+'_2D_3_1')
    X = Xfromdata(np.loadtxt(file1+'_p1.dat'))
    Y = Xfromdata(np.loadtxt(file1+'_p3.dat'))
    cnt = np.loadtxt(file1+'_2D_3_1_cont')
    rlt = ax.contour(X,Y,pts,cnt)

nowfile = '/home/xiaodongli/software/cosmomcs/12Oct_generic/Dense2_PatchyV6CM300omws.sefact.smooth.2Dcon.txt'
FullFileName = nowfile
contours = COSMOMC_load_contours(FullFileName, upper_limit_of_loadin=10, upper_limit_of_loadiny=1.0)
for row in range(len(contours)):
    X, Y = XYfromdata(contours[row])
    if row == 0:
        ax.plot(X,Y,lw=2,ls='--',c='k',label='$\\rm CMB\\ TT,\\ TE,\\ EE,\\ lowP\\ (\\it Planck)\\rm \\ +\\ JLA\\ SNIa\\ +\\ H_0\\ +$\n $\\rm BAO\\ +\\ AP\\ from\\ BOSS\\ DR12\\ galaxies$')
    else:
        ax.plot(X,Y,lw=2,ls='--',c='k')

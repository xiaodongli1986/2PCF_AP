# %% [raw]
# Anyway, firstly ::
#
#     ssh to baekdu, check whether all "python" EXE stops;
#     locally, 1) download the contour using "ssh_contour", 2) download all png figures from the server (on the server, move them to a new folder; compress them; then, download to local)
#
# The do the following checks:
#
#     1. Check files with names of
#         Dense1subscanPatchyV6CMocks_Mapping_170309Debug*.txt
#         How does their contour plot looks like??? ### Checked. Seems no problem...
#     2. Check files with names of
#         Dense1subscanPatchyV6CMocks_MappingTest_DebugScan_New_SMuMapping_Mid*.txt
#         How does their contour plot looks like???
#           ### ------ Even if their contour can successfully reproduce the precise method contour, still we need to do more investigations on the mapping programme, and designed a better strategy! (reduce the errors...)
#
#     3. We shall:
#         Mesh plot to show the difference in chisqs of the two contours
#
# Strange. We can print the covariance matrix, whether they are same in the precise & approx methods. How can there be such a big difference in chisq values?
# Check the

# %%
execfile('/home/xiaodongli/software/pythonlib/stdA.py')
execfile('/home/xiaodongli/software/pythonlib/Tpcftools.py')
execfile('/home/xiaodongli/software/pythonlib/bossdatamock.py')
execfile('/home/xiaodongli/software/pythonlib/Tpcftools_smuximu.py')
execfile('/home/xiaodongli/software/pythonlib/Tpcftools_smuintxi.py')
# %pylab inline
import copy

nummubin = 120
deltamu = 1.0/float(nummubin)
# Out:
# /home/xiaodongli/software/pythonlib/Tpcftools_smuintxi.py:536: SyntaxWarning: name 'oms' is assigned to before global declaration
#   global oms, ws, omws, scanname
# /home/xiaodongli/software/pythonlib/Tpcftools_smuintxi.py:536: SyntaxWarning: name 'ws' is assigned to before global declaration
#   global oms, ws, omws, scanname
# /home/xiaodongli/software/pythonlib/Tpcftools_smuintxi.py:536: SyntaxWarning: name 'omws' is assigned to before global declaration
#   global oms, ws, omws, scanname
# /home/xiaodongli/software/pythonlib/Tpcftools_smuintxi.py:536: SyntaxWarning: name 'scanname' is assigned to before global declaration
#   global oms, ws, omws, scanname
# /home/xiaodongli/software/pythonlib/Tpcftools_smuintxi.py:536: SyntaxWarning: name 'oms' is assigned to before global declaration
#   global oms, ws, omws, scanname
# /home/xiaodongli/software/pythonlib/Tpcftools_smuintxi.py:536: SyntaxWarning: name 'ws' is assigned to before global declaration
#   global oms, ws, omws, scanname
# /home/xiaodongli/software/pythonlib/Tpcftools_smuintxi.py:536: SyntaxWarning: name 'omws' is assigned to before global declaration
#   global oms, ws, omws, scanname
# /home/xiaodongli/software/pythonlib/Tpcftools_smuintxi.py:536: SyntaxWarning: name 'scanname' is assigned to before global declaration
#   global oms, ws, omws, scanname
# /home/xiaodongli/software/pythonlib/Tpcftools_smuintxi.py:536: SyntaxWarning: name 'oms' is assigned to before global declaration
#   global oms, ws, omws, scanname
# Populating the interactive namespace from numpy and matplotlib
# /home/xiaodongli/software/pythonlib/Tpcftools_smuintxi.py:536: SyntaxWarning: name 'ws' is assigned to before global declaration
#   global oms, ws, omws, scanname
# /home/xiaodongli/software/pythonlib/Tpcftools_smuintxi.py:536: SyntaxWarning: name 'omws' is assigned to before global declaration
#   global oms, ws, omws, scanname
# /home/xiaodongli/software/pythonlib/Tpcftools_smuintxi.py:536: SyntaxWarning: name 'scanname' is assigned to before global declaration
#   global oms, ws, omws, scanname
# WARNING: pylab import has clobbered these variables: ['copy', 'product', 'random', 'transpose']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
#for nowmuedge in :
 #for nowmumin in :
if True:
    nummuedges = range(26,27)
    mumins = np.linspace(0.05, 0.06,1)
    conommin, conommax, conwmin, conwmax =  0.08, 0.64, -1.95, -0.0

    covmatrescale_nowfiles1 = sumlist([[[Percival_covmat_scale(2000,nummu,2)[2] , 
                './cov_chisqs/Dense1subscanPatchyV6CMocks_int--xi.'+str(nummu)+'mu%.2f'%mumin+\
                'to1.00.s6.00to40.00.CovMock_2000_PatchyV6C_RSD.txt'] for mumin in mumins] for nummu in nummuedges])
    covmatrescale_nowfiles2 = sumlist([[[Percival_covmat_scale(2000,nummu,2)[2], 
                './cov_chisqs/Dense1subscanPatchyV6CMocks_MappingTest_int--xi.'+str(nummu)+'mu%.2f'%mumin+\
                'to1.00.s6.00to40.00.CovMock_2000_PatchyV6C_RSD.SMU_Mapping.txt'] for mumin in mumins] for nummu in nummuedges])
    plotformat=1       
    #fig, ax = figax(figxsize=14,figysize=11.5)
    fig, ax = figax(figxsize=6,figysize=4)
    fig1, ax1 = figax(16,6)
    fig2, ax2 = figax(16,6)
    for nowfiles in [covmatrescale_nowfiles1, covmatrescale_nowfiles2]:
        #ax.set_title(separate_path_file(nowfile)[1])
        ifile = -1
        nowtab = {}
        for covmatrescale_nowfile in nowfiles:
            ifile += 1; covmatrescale, nowfile = covmatrescale_nowfile; iline=0; covmatrescale*=5.0/4.0
            for nowstr in open(nowfile,'r').readlines():
                iline+=1; 
                if iline==1: continue
                nowstrs = nowstr.split()
                if ifile == 0:
                    nowtab[nowstrs[1]] = [float(nowstrs[2])/covmatrescale, float(nowstrs[3])/covmatrescale]
                else:
                    nowtab[nowstrs[1]][0] += float(nowstrs[2])/covmatrescale
                    nowtab[nowstrs[1]][1] += float(nowstrs[3])/covmatrescale
            #fig, ax = figax()
            #ax.set_title(separate_path_file(nowfile)[1])
            if plotformat == 1:
                nowlab = 'Precise Method'
            else:
                nowlab = 'Approximate Method ($s$,$\\mu$ mapping)'
        plot_contour(ax, Dense1subscan_omlist, Dense1subscan_wlist, 
                         [[nowtab[omwstr(om,w)][1]/float(len(nowfiles)) for om in Dense1subscan_omlist] for w in Dense1subscan_wlist], 
                         show_marg_rlt=False, sigs=[sig1,sig2], label=nowlab, plotformat=plotformat,)
        
        #continue
        X = sumlist([[DA(om, w, 0.7, SixBinRedshift_NS[4])* Hz(om, w, 0.7, SixBinRedshift_NS[4]) / \
                (DA(om, w, 0.7, SixBinRedshift_NS[0])* Hz(om, w, 0.7, SixBinRedshift_NS[0])) for om in Dense1subscan_omlist] \
                        for w in Dense1subscan_wlist])
        Y =  sumlist([[nowtab[omwstr(om,w)][1]/float(len(nowfiles))  for om in Dense1subscan_omlist] for w in Dense1subscan_wlist])

        if plotformat == 1:
                ax1.scatter(X,Y, lw=2, linewidths=0, color='b', label='Precise')
                nowlike0 = [[nowtab[omwstr(om,w)][1]/float(len(nowfiles)) for om in Dense1subscan_omlist] for w in Dense1subscan_wlist]
                Y0 = [xx for xx in Y]
        else:
                ax1.scatter(X,Y, lw=2, linewidths=0, color='r', label='Approx')
                diffY = [Y[row]-Y0[row] for row in range(len(Y))]
                difflike = [[nowtab[omwstr(om,w)][1]/float(len(nowfiles)) for om in Dense1subscan_omlist] for w in Dense1subscan_wlist]
                for row2 in range(len(Dense1subscan_omlist)):
                    for row1 in range(len(Dense1subscan_wlist)):
                        difflike[row1][row2] = (difflike[row1][row2]-nowlike0[row1][row2])
                ax2.scatter(X,diffY, lw=2, linewidths=0, color='r', label='Approx - Precise')
        plotformat += 2
    #figdifflike, axdifflike = figax()
    #plot_contour(axdifflike, Dense1subscan_omlist, Dense1subscan_wlist, 
    #                     difflike, 
    #                     show_marg_rlt=False, sigs=[sig1,sig2], label=nowlab, plotformat=1,)
    difflike_tab = {};
    for iw in range(len(Dense1subscan_wlist)):
        for iom in range(len(Dense1subscan_omlist)):
            om, w = Dense1subscan_omlist[iom], Dense1subscan_wlist[iw]
            difflike_tab[omwstr(om,w)] = difflike[iw][iom]
            #len([[nowtab[omwstr(om,w)][1]/float(len(nowfiles)) for om in Dense1subscan_omlist] for w in Dense1subscan_wlist]
    ax1.set_xlabel('DA H ratio (high-z OVER low-z)', fontsize=20)
    ax1.set_ylabel('$\\chi^2$', fontsize=20)
    ax.grid(); ax1.grid(); ax2.grid()
    ax.set_xlim(conommin, conommax); ax.set_ylim(conwmin, conwmax)
    ax.set_xlabel('$\\Omega_m$', fontsize=26); ax.set_ylabel('$w$', fontsize=26)
    ax.set_xticks(np.arange(0.10, conommax, 0.05)); ax.set_yticks(np.arange(-1.8, conwmax, 0.2))
    #ax.set_title('# of $\\mu$ bins = '+str(nummuedges))
    ax.legend(frameon=False,loc='best'); ax1.legend(frameon=False,loc='best'); ax2.legend(frameon=False,loc='best')
    print difflike_tab[omwstr(0.31,-1.0)], difflike_tab[omwstr(0.31,-1.8)]
    plt.show()
# Out:
# -9.69879993544 -19.0256143657

# %%
difflike_tab = {};
for iw in range(len(Dense1subscan_wlist)):
    for iom in range(len(Dense1subscan_omlist)):
            om, w = Dense1subscan_omlist[iom], Dense1subscan_wlist[iw]
            difflike_tab[omwstr(om,w)] = difflike[iw][iom]
fig,ax=figax(); ax.grid()
ax.contourf(Dense1subscan_omlist, Dense1subscan_wlist, [[abs(difflike_tab[omwstr(om,w)]) for om in Dense1subscan_omlist] 
    for w in Dense1subscan_wlist], levels=[0,10,30,50,100 ] )
# Out:
# <matplotlib.contour.QuadContourSet instance at 0x7f42678cce60>

# %%
for row2 in range(len(Dense1subscan_omlist)):
    for row1 in range(len(Dense1subscan_wlist)):
        print Dense1subscan_omlist[row2],Dense1subscan_wlist[row1], '\t', difflike[row1][row2], '\t', \
            difflike_tab[omwstr(Dense1subscan_omlist[row2],Dense1subscan_wlist[row1])]
# Out:
# 0.06 -2.5 	-23.9256332078 	-23.9256332078
# 0.06 -2.45 	-28.3431802752 	-28.3431802752
# 0.06 -2.4 	-34.1142066262 	-34.1142066262
# 0.06 -2.35 	-36.2470340678 	-36.2470340678
# 0.06 -2.3 	-28.3682047628 	-28.3682047628
# 0.06 -2.25 	-21.9925682286 	-21.9925682286
# 0.06 -2.2 	-28.2985968751 	-28.2985968751
# 0.06 -2.15 	-36.0007134169 	-36.0007134169
# 0.06 -2.1 	-25.6774516492 	-25.6774516492
# 0.06 -2.05 	-19.9156928646 	-19.9156928646
# 0.06 -2.0 	-26.1908367036 	-26.1908367036
# 0.06 -1.95 	-22.9221984468 	-22.9221984468
# 0.06 -1.9 	-18.2188166241 	-18.2188166241
# 0.06 -1.85 	-16.6241873858 	-16.6241873858
# 0.06 -1.8 	-12.4572981944 	-12.4572981944
# 0.06 -1.75 	-18.2121127916 	-18.2121127916
# 0.06 -1.7 	-20.5064713428 	-20.5064713428
# 0.06 -1.65 	-23.3965537986 	-23.3965537986
# 0.06 -1.6 	-24.8954287159 	-24.8954287159
# 0.06 -1.55 	-21.1772859192 	-21.1772859192
# 0.06 -1.5 	-24.7435315386 	-24.7435315386
# 0.06 -1.45 	-26.5800712732 	-26.5800712732
# 0.06 -1.4 	-31.8427556713 	-31.8427556713
# 0.06 -1.35 	-32.6782032127 	-32.6782032127
# 0.06 -1.3 	-36.4426746637 	-36.4426746637
# 0.06 -1.25 	-40.7983234031 	-40.7983234031
# 0.06 -1.2 	-33.1950298969 	-33.1950298969
# 0.06 -1.15 	-32.4972847008 	-32.4972847008
# 0.06 -1.1 	-29.1252167827 	-29.1252167827
# 0.06 -1.05 	-25.414430611 	-25.414430611
# 0.06 -1.0 	-25.2465077858 	-25.2465077858
# 0.06 -0.95 	-16.2274369401 	-16.2274369401
# 0.06 -0.9 	-21.1425946513 	-21.1425946513
# 0.06 -0.85 	-18.0186643683 	-18.0186643683
# 0.06 -0.8 	-25.6264551223 	-25.6264551223
# 0.06 -0.75 	-14.8677937977 	-14.8677937977
# 0.06 -0.7 	-10.7265203765 	-10.7265203765
# 0.06 -0.65 	-6.2829574511 	-6.2829574511
# 0.06 -0.6 	-10.9168479172 	-10.9168479172
# 0.06 -0.55 	-16.2082362776 	-16.2082362776
# 0.06 -0.5 	-11.096882418 	-11.096882418
# 0.06 -0.45 	-12.1683510113 	-12.1683510113
# 0.06 -0.4 	-12.0244808973 	-12.0244808973
# 0.06 -0.35 	-5.34535955632 	-5.34535955632
# 0.06 -0.3 	-10.3891709371 	-10.3891709371
# 0.06 -0.25 	-4.16487572092 	-4.16487572092
# 0.06 -0.2 	4.7107932543 	4.7107932543
# 0.06 -0.15 	3.33467972414 	3.33467972414
# 0.06 -0.1 	5.22188835402 	5.22188835402
# 0.06 -0.05 	-8.32770860686 	-8.32770860686
# 0.06 0.0 	-7.34447058278 	-7.34447058278
# 0.085 -2.5 	-22.8859473011 	-22.8859473011
# 0.085 -2.45 	-23.5932637382 	-23.5932637382
# 0.085 -2.4 	-17.4835255471 	-17.4835255471
# 0.085 -2.35 	-29.3920801444 	-29.3920801444
# 0.085 -2.3 	-21.1313783312 	-21.1313783312
# 0.085 -2.25 	-17.4780617861 	-17.4780617861
# 0.085 -2.2 	-19.4241961966 	-19.4241961966
# 0.085 -2.15 	-20.6367861354 	-20.6367861354
# 0.085 -2.1 	-20.3622592139 	-20.3622592139
# 0.085 -2.05 	-20.7129856201 	-20.7129856201
# 0.085 -2.0 	-19.3591753463 	-19.3591753463
# 0.085 -1.95 	-18.618115086 	-18.618115086
# 0.085 -1.9 	-14.638152846 	-14.638152846
# 0.085 -1.85 	-15.5925060346 	-15.5925060346
# 0.085 -1.8 	-14.0969208144 	-14.0969208144
# 0.085 -1.75 	-18.9368342914 	-18.9368342914
# 0.085 -1.7 	-17.0069861665 	-17.0069861665
# 0.085 -1.65 	-23.030115263 	-23.030115263
# 0.085 -1.6 	-22.4981428812 	-22.4981428812
# 0.085 -1.55 	-22.2767056731 	-22.2767056731
# 0.085 -1.5 	-24.1319259106 	-24.1319259106
# 0.085 -1.45 	-34.6692551941 	-34.6692551941
# 0.085 -1.4 	-34.1557869931 	-34.1557869931
# 0.085 -1.35 	-32.1669966007 	-32.1669966007
# 0.085 -1.3 	-33.8826506771 	-33.8826506771
# 0.085 -1.25 	-25.8401460644 	-25.8401460644
# 0.085 -1.2 	-27.5763178671 	-27.5763178671
# 0.085 -1.15 	-33.4187857931 	-33.4187857931
# 0.085 -1.1 	-25.2090075415 	-25.2090075415
# 0.085 -1.05 	-23.0893832614 	-23.0893832614
# 0.085 -1.0 	-19.1852328407 	-19.1852328407
# 0.085 -0.95 	-20.224204407 	-20.224204407
# 0.085 -0.9 	-21.2895078558 	-21.2895078558
# 0.085 -0.85 	-20.4302790735 	-20.4302790735
# 0.085 -0.8 	-18.0181979005 	-18.0181979005
# 0.085 -0.75 	-9.87595993175 	-9.87595993175
# 0.085 -0.7 	-8.02483203202 	-8.02483203202
# 0.085 -0.65 	-10.8650584976 	-10.8650584976
# 0.085 -0.6 	-12.9636797553 	-12.9636797553
# 0.085 -0.55 	-15.1930169497 	-15.1930169497
# 0.085 -0.5 	-13.6471716222 	-13.6471716222
# 0.085 -0.45 	-13.8881152899 	-13.8881152899
# 0.085 -0.4 	-9.24454884491 	-9.24454884491
# 0.085 -0.35 	-2.38550471342 	-2.38550471342
# 0.085 -0.3 	-7.63633233236 	-7.63633233236
# 0.085 -0.25 	-1.92581540066 	-1.92581540066
# 0.085 -0.2 	6.67593194797 	6.67593194797
# 0.085 -0.15 	4.27764387751 	4.27764387751
# 0.085 -0.1 	4.16118109219 	4.16118109219
# 0.085 -0.05 	-8.72533604486 	-8.72533604486
# 0.085 0.0 	-7.34447058278 	-7.34447058278
# 0.11 -2.5 	-18.6090181435 	-18.6090181435
# 0.11 -2.45 	-16.504980683 	-16.504980683
# 0.11 -2.4 	-16.5625891842 	-16.5625891842
# 0.11 -2.35 	-10.3318328807 	-10.3318328807
# 0.11 -2.3 	-12.7408134775 	-12.7408134775
# 0.11 -2.25 	-16.3617664403 	-16.3617664403
# 0.11 -2.2 	-16.3701464459 	-16.3701464459
# 0.11 -2.15 	-14.4042110469 	-14.4042110469
# 0.11 -2.1 	-11.6027409969 	-11.6027409969
# 0.11 -2.05 	-14.259957431 	-14.259957431
# 0.11 -2.0 	-10.3747713916 	-10.3747713916
# 0.11 -1.95 	-14.3708614072 	-14.3708614072
# 0.11 -1.9 	-13.8192689358 	-13.8192689358
# 0.11 -1.85 	-21.4983232912 	-21.4983232912
# 0.11 -1.8 	-27.0476732053 	-27.0476732053
# 0.11 -1.75 	-30.6939662342 	-30.6939662342
# 0.11 -1.7 	-19.5559368839 	-19.5559368839
# 0.11 -1.65 	-22.070261614 	-22.070261614
# 0.11 -1.6 	-25.7322400019 	-25.7322400019
# 0.11 -1.55 	-28.9761305294 	-28.9761305294
# 0.11 -1.5 	-32.8245527999 	-32.8245527999
# 0.11 -1.45 	-33.6270333858 	-33.6270333858
# 0.11 -1.4 	-25.0587800052 	-25.0587800052
# 0.11 -1.35 	-27.4153760504 	-27.4153760504
# 0.11 -1.3 	-26.8243813734 	-26.8243813734
# 0.11 -1.25 	-31.0846970604 	-31.0846970604
# 0.11 -1.2 	-27.5994122845 	-27.5994122845
# 0.11 -1.15 	-21.6008483785 	-21.6008483785
# 0.11 -1.1 	-23.7360875886 	-23.7360875886
# 0.11 -1.05 	-22.7115121912 	-22.7115121912
# 0.11 -1.0 	-18.580182169 	-18.580182169
# 0.11 -0.95 	-22.1331197943 	-22.1331197943
# 0.11 -0.9 	-17.2297302713 	-17.2297302713
# 0.11 -0.85 	-23.0214017733 	-23.0214017733
# 0.11 -0.8 	-12.2810416233 	-12.2810416233
# 0.11 -0.75 	-9.73083878072 	-9.73083878072
# 0.11 -0.7 	-6.21887934628 	-6.21887934628
# 0.11 -0.65 	-13.2785371661 	-13.2785371661
# 0.11 -0.6 	-14.8320717135 	-14.8320717135
# 0.11 -0.55 	-15.8339981542 	-15.8339981542
# 0.11 -0.5 	-13.389553909 	-13.389553909
# 0.11 -0.45 	-7.68434336528 	-7.68434336528
# 0.11 -0.4 	-7.72703943971 	-7.72703943971
# 0.11 -0.35 	-2.55271142014 	-2.55271142014
# 0.11 -0.3 	-4.43250190909 	-4.43250190909
# 0.11 -0.25 	-3.22507453983 	-3.22507453983
# 0.11 -0.2 	6.70046513144 	6.70046513144
# 0.11 -0.15 	1.62547188646 	1.62547188646
# 0.11 -0.1 	3.60879580581 	3.60879580581
# 0.11 -0.05 	-8.64685521708 	-8.64685521708
# 0.11 0.0 	-7.34447058278 	-7.34447058278
# 0.135 -2.5 	-11.0649170637 	-11.0649170637
# 0.135 -2.45 	-6.94454096763 	-6.94454096763
# 0.135 -2.4 	-8.19695934394 	-8.19695934394
# 0.135 -2.35 	-3.66341270053 	-3.66341270053
# 0.135 -2.3 	-9.65010617663 	-9.65010617663
# 0.135 -2.25 	-9.33798546043 	-9.33798546043
# 0.135 -2.2 	-12.5306789284 	-12.5306789284
# 0.135 -2.15 	-7.91352334904 	-7.91352334904
# 0.135 -2.1 	-9.99796268944 	-9.99796268944
# 0.135 -2.05 	-8.68574418115 	-8.68574418115
# 0.135 -2.0 	-11.5785800063 	-11.5785800063
# 0.135 -1.95 	-15.8253937931 	-15.8253937931
# 0.135 -1.9 	-19.3364282334 	-19.3364282334
# 0.135 -1.85 	-18.74853638 	-18.74853638
# 0.135 -1.8 	-16.7450602117 	-16.7450602117
# 0.135 -1.75 	-16.9695463894 	-16.9695463894
# 0.135 -1.7 	-26.0977712967 	-26.0977712967
# 0.135 -1.65 	-28.0859839134 	-28.0859839134
# 0.135 -1.6 	-37.1159818641 	-37.1159818641
# 0.135 -1.55 	-30.0963785334 	-30.0963785334
# 0.135 -1.5 	-27.8244640897 	-27.8244640897
# 0.135 -1.45 	-23.735832129 	-23.735832129
# 0.135 -1.4 	-24.9472365772 	-24.9472365772
# 0.135 -1.35 	-26.7394725414 	-26.7394725414
# 0.135 -1.3 	-23.8777166277 	-23.8777166277
# 0.135 -1.25 	-24.4007633103 	-24.4007633103
# 0.135 -1.2 	-23.4677254302 	-23.4677254302
# 0.135 -1.15 	-20.9078565489 	-20.9078565489
# 0.135 -1.1 	-21.7134742074 	-21.7134742074
# 0.135 -1.05 	-18.074081391 	-18.074081391
# 0.135 -1.0 	-20.3713132076 	-20.3713132076
# 0.135 -0.95 	-17.7162213394 	-17.7162213394
# 0.135 -0.9 	-26.4714409283 	-26.4714409283
# 0.135 -0.85 	-16.4634022294 	-16.4634022294
# 0.135 -0.8 	-9.47181002927 	-9.47181002927
# 0.135 -0.75 	-7.4182784787 	-7.4182784787
# 0.135 -0.7 	-12.7455398912 	-12.7455398912
# 0.135 -0.65 	-11.7472195126 	-11.7472195126
# 0.135 -0.6 	-16.197242169 	-16.197242169
# 0.135 -0.55 	-14.2155431056 	-14.2155431056
# 0.135 -0.5 	-17.777328483 	-17.777328483
# 0.135 -0.45 	-6.13775729368 	-6.13775729368
# 0.135 -0.4 	-4.22277345745 	-4.22277345745
# 0.135 -0.35 	-7.49282935568 	-7.49282935568
# 0.135 -0.3 	-4.80914949463 	-4.80914949463
# 0.135 -0.25 	4.53589535912 	4.53589535912
# 0.135 -0.2 	0.651485721254 	0.651485721254
# 0.135 -0.15 	5.59370631479 	5.59370631479
# 0.135 -0.1 	4.94475547287 	4.94475547287
# 0.135 -0.05 	-7.41097378122 	-7.41097378122
# 0.135 0.0 	-7.34447058278 	-7.34447058278
# 0.16 -2.5 	-10.5996957372 	-10.5996957372
# 0.16 -2.45 	-12.9582110872 	-12.9582110872
# 0.16 -2.4 	-12.5792126214 	-12.5792126214
# 0.16 -2.35 	-13.2687925903 	-13.2687925903
# 0.16 -2.3 	-12.5314224373 	-12.5314224373
# 0.16 -2.25 	-13.3160416684 	-13.3160416684
# 0.16 -2.2 	-18.5793628546 	-18.5793628546
# 0.16 -2.15 	-15.7701186062 	-15.7701186062
# 0.16 -2.1 	-2.82123775707 	-2.82123775707
# 0.16 -2.05 	-15.7682390532 	-15.7682390532
# 0.16 -2.0 	-17.7235331841 	-17.7235331841
# 0.16 -1.95 	-15.2154213886 	-15.2154213886
# 0.16 -1.9 	-22.1516522635 	-22.1516522635
# 0.16 -1.85 	-18.4038948567 	-18.4038948567
# 0.16 -1.8 	-20.0356111553 	-20.0356111553
# 0.16 -1.75 	-23.9630350619 	-23.9630350619
# 0.16 -1.7 	-32.0983770506 	-32.0983770506
# 0.16 -1.65 	-32.9274779641 	-32.9274779641
# 0.16 -1.6 	-33.0752797118 	-33.0752797118
# 0.16 -1.55 	-30.1117247154 	-30.1117247154
# 0.16 -1.5 	-26.4305984227 	-26.4305984227
# 0.16 -1.45 	-21.7285924827 	-21.7285924827
# 0.16 -1.4 	-21.688961958 	-21.688961958
# 0.16 -1.35 	-26.5918515566 	-26.5918515566
# 0.16 -1.3 	-22.5979781665 	-22.5979781665
# 0.16 -1.25 	-20.0744200924 	-20.0744200924
# 0.16 -1.2 	-22.6302625606 	-22.6302625606
# 0.16 -1.15 	-17.3069791074 	-17.3069791074
# 0.16 -1.1 	-17.0893685223 	-17.0893685223
# 0.16 -1.05 	-21.1050381825 	-21.1050381825
# 0.16 -1.0 	-17.7872693897 	-17.7872693897
# 0.16 -0.95 	-20.4535112034 	-20.4535112034
# 0.16 -0.9 	-17.6746492412 	-17.6746492412
# 0.16 -0.85 	-11.3198075175 	-11.3198075175
# 0.16 -0.8 	-4.59146200693 	-4.59146200693
# 0.16 -0.75 	-9.72910965534 	-9.72910965534
# 0.16 -0.7 	-11.4244190796 	-11.4244190796
# 0.16 -0.65 	-12.0556825248 	-12.0556825248
# 0.16 -0.6 	-15.0810417233 	-15.0810417233
# 0.16 -0.55 	-14.640656206 	-14.640656206
# 0.16 -0.5 	-9.80277760331 	-9.80277760331
# 0.16 -0.45 	-9.36309617164 	-9.36309617164
# 0.16 -0.4 	-5.74986118998 	-5.74986118998
# 0.16 -0.35 	-8.39170323486 	-8.39170323486
# 0.16 -0.3 	-1.48995841218 	-1.48995841218
# 0.16 -0.25 	2.98566373837 	2.98566373837
# 0.16 -0.2 	-0.835281801906 	-0.835281801906
# 0.16 -0.15 	4.55940144493 	4.55940144493
# 0.16 -0.1 	7.32698107961 	7.32698107961
# 0.16 -0.05 	-8.33516391727 	-8.33516391727
# 0.16 0.0 	-7.34447058278 	-7.34447058278
# 0.185 -2.5 	-9.23259261855 	-9.23259261855
# 0.185 -2.45 	-16.5440552297 	-16.5440552297
# 0.185 -2.4 	-18.0435773303 	-18.0435773303
# 0.185 -2.35 	-11.5972313853 	-11.5972313853
# 0.185 -2.3 	-7.39561022916 	-7.39561022916
# 0.185 -2.25 	-14.9628187329 	-14.9628187329
# 0.185 -2.2 	-17.3919524502 	-17.3919524502
# 0.185 -2.15 	-19.1181551416 	-19.1181551416
# 0.185 -2.1 	-23.206315824 	-23.206315824
# 0.185 -2.05 	-22.9029851271 	-22.9029851271
# 0.185 -2.0 	-24.4814294046 	-24.4814294046
# 0.185 -1.95 	-20.9768310492 	-20.9768310492
# 0.185 -1.9 	-22.7912666561 	-22.7912666561
# 0.185 -1.85 	-29.6425035635 	-29.6425035635
# 0.185 -1.8 	-34.1767811982 	-34.1767811982
# 0.185 -1.75 	-34.3526787663 	-34.3526787663
# 0.185 -1.7 	-34.5005769615 	-34.5005769615
# 0.185 -1.65 	-30.2008011676 	-30.2008011676
# 0.185 -1.6 	-21.8203395786 	-21.8203395786
# 0.185 -1.55 	-23.5972365621 	-23.5972365621
# 0.185 -1.5 	-30.0571799177 	-30.0571799177
# 0.185 -1.45 	-22.844855171 	-22.844855171
# 0.185 -1.4 	-24.5632899923 	-24.5632899923
# 0.185 -1.35 	-21.6414436048 	-21.6414436048
# 0.185 -1.3 	-19.0109165951 	-19.0109165951
# 0.185 -1.25 	-24.9266068467 	-24.9266068467
# 0.185 -1.2 	-19.1292078482 	-19.1292078482
# 0.185 -1.15 	-20.8132229142 	-20.8132229142
# 0.185 -1.1 	-24.452459571 	-24.452459571
# 0.185 -1.05 	-16.2288081756 	-16.2288081756
# 0.185 -1.0 	-21.3517796885 	-21.3517796885
# 0.185 -0.95 	-17.2539548622 	-17.2539548622
# 0.185 -0.9 	-14.0943707663 	-14.0943707663
# 0.185 -0.85 	-5.88683160132 	-5.88683160132
# 0.185 -0.8 	-5.99438865521 	-5.99438865521
# 0.185 -0.75 	-15.1217735747 	-15.1217735747
# 0.185 -0.7 	-12.0337586456 	-12.0337586456
# 0.185 -0.65 	-16.1254637675 	-16.1254637675
# 0.185 -0.6 	-16.8493580283 	-16.8493580283
# 0.185 -0.55 	-14.7104757976 	-14.7104757976
# 0.185 -0.5 	-4.158611409 	-4.158611409
# 0.185 -0.45 	-8.53095337618 	-8.53095337618
# 0.185 -0.4 	-1.17046131067 	-1.17046131067
# 0.185 -0.35 	-8.08039441305 	-8.08039441305
# 0.185 -0.3 	-1.42659813907 	-1.42659813907
# 0.185 -0.25 	3.6523583194 	3.6523583194
# 0.185 -0.2 	-2.17980317462 	-2.17980317462
# 0.185 -0.15 	5.04596233353 	5.04596233353
# 0.185 -0.1 	6.03876124888 	6.03876124888
# 0.185 -0.05 	-8.86031891533 	-8.86031891533
# 0.185 0.0 	-7.34447058278 	-7.34447058278
# 0.21 -2.5 	-15.3330782293 	-15.3330782293
# 0.21 -2.45 	-15.2928484639 	-15.2928484639
# 0.21 -2.4 	-15.7303749762 	-15.7303749762
# 0.21 -2.35 	-17.5478201781 	-17.5478201781
# 0.21 -2.3 	-19.3038310641 	-19.3038310641
# 0.21 -2.25 	-20.400502262 	-20.400502262
# 0.21 -2.2 	-23.8659685536 	-23.8659685536
# 0.21 -2.15 	-19.8041928829 	-19.8041928829
# 0.21 -2.1 	-19.3434293006 	-19.3434293006
# 0.21 -2.05 	-13.9798680044 	-13.9798680044
# 0.21 -2.0 	-14.9754937082 	-14.9754937082
# 0.21 -1.95 	-24.3426338742 	-24.3426338742
# 0.21 -1.9 	-29.7919504136 	-29.7919504136
# 0.21 -1.85 	-28.2028819523 	-28.2028819523
# 0.21 -1.8 	-24.5720759121 	-24.5720759121
# 0.21 -1.75 	-30.0918356909 	-30.0918356909
# 0.21 -1.7 	-27.0340938884 	-27.0340938884
# 0.21 -1.65 	-28.2714206193 	-28.2714206193
# 0.21 -1.6 	-25.246426105 	-25.246426105
# 0.21 -1.55 	-18.0256444291 	-18.0256444291
# 0.21 -1.5 	-25.6802836165 	-25.6802836165
# 0.21 -1.45 	-22.1412098829 	-22.1412098829
# 0.21 -1.4 	-20.3417472517 	-20.3417472517
# 0.21 -1.35 	-28.0930178657 	-28.0930178657
# 0.21 -1.3 	-19.9759626273 	-19.9759626273
# 0.21 -1.25 	-16.7408113 	-16.7408113
# 0.21 -1.2 	-20.1673626517 	-20.1673626517
# 0.21 -1.15 	-22.2959893969 	-22.2959893969
# 0.21 -1.1 	-17.6082111199 	-17.6082111199
# 0.21 -1.05 	-17.2175555113 	-17.2175555113
# 0.21 -1.0 	-16.8050118623 	-16.8050118623
# 0.21 -0.95 	-14.0108215755 	-14.0108215755
# 0.21 -0.9 	-3.49844111809 	-3.49844111809
# 0.21 -0.85 	-5.48319523752 	-5.48319523752
# 0.21 -0.8 	-12.5005599356 	-12.5005599356
# 0.21 -0.75 	-12.8491945918 	-12.8491945918
# 0.21 -0.7 	-11.6320389705 	-11.6320389705
# 0.21 -0.65 	-16.8718949879 	-16.8718949879
# 0.21 -0.6 	-17.0071915298 	-17.0071915298
# 0.21 -0.55 	-14.1769148595 	-14.1769148595
# 0.21 -0.5 	-8.16049002221 	-8.16049002221
# 0.21 -0.45 	-5.75453964114 	-5.75453964114
# 0.21 -0.4 	-6.3148151744 	-6.3148151744
# 0.21 -0.35 	-6.6872677251 	-6.6872677251
# 0.21 -0.3 	-2.79588164839 	-2.79588164839
# 0.21 -0.25 	4.53294744331 	4.53294744331
# 0.21 -0.2 	-1.13285772443 	-1.13285772443
# 0.21 -0.15 	4.00678346105 	4.00678346105
# 0.21 -0.1 	4.30898589712 	4.30898589712
# 0.21 -0.05 	-9.20585771367 	-9.20585771367
# 0.21 0.0 	-7.34447058278 	-7.34447058278
# 0.235 -2.5 	-18.8218135042 	-18.8218135042
# 0.235 -2.45 	-18.6518820476 	-18.6518820476
# 0.235 -2.4 	-23.2340293975 	-23.2340293975
# 0.235 -2.35 	-24.0705341991 	-24.0705341991
# 0.235 -2.3 	-21.1133516531 	-21.1133516531
# 0.235 -2.25 	-11.772872395 	-11.772872395
# 0.235 -2.2 	-14.7033237767 	-14.7033237767
# 0.235 -2.15 	-24.1739195701 	-24.1739195701
# 0.235 -2.1 	-21.2787637752 	-21.2787637752
# 0.235 -2.05 	-26.3192653409 	-26.3192653409
# 0.235 -2.0 	-31.3501845214 	-31.3501845214
# 0.235 -1.95 	-25.7613827889 	-25.7613827889
# 0.235 -1.9 	-29.7896792596 	-29.7896792596
# 0.235 -1.85 	-30.5254119014 	-30.5254119014
# 0.235 -1.8 	-30.5315226712 	-30.5315226712
# 0.235 -1.75 	-27.7342435841 	-27.7342435841
# 0.235 -1.7 	-29.071542068 	-29.071542068
# 0.235 -1.65 	-22.8319312979 	-22.8319312979
# 0.235 -1.6 	-26.8519267329 	-26.8519267329
# 0.235 -1.55 	-22.6515621283 	-22.6515621283
# 0.235 -1.5 	-17.1973503103 	-17.1973503103
# 0.235 -1.45 	-24.1743047129 	-24.1743047129
# 0.235 -1.4 	-19.5563346985 	-19.5563346985
# 0.235 -1.35 	-24.7427535989 	-24.7427535989
# 0.235 -1.3 	-20.2262502388 	-20.2262502388
# 0.235 -1.25 	-26.4926496743 	-26.4926496743
# 0.235 -1.2 	-19.0534251802 	-19.0534251802
# 0.235 -1.15 	-14.9914400887 	-14.9914400887
# 0.235 -1.1 	-17.7937943266 	-17.7937943266
# 0.235 -1.05 	-17.9987211048 	-17.9987211048
# 0.235 -1.0 	-14.5040326147 	-14.5040326147
# 0.235 -0.95 	-2.1996907723 	-2.1996907723
# 0.235 -0.9 	-4.01002991788 	-4.01002991788
# 0.235 -0.85 	-10.7603315475 	-10.7603315475
# 0.235 -0.8 	-13.1146805796 	-13.1146805796
# 0.235 -0.75 	-10.638660602 	-10.638660602
# 0.235 -0.7 	-15.7579204981 	-15.7579204981
# 0.235 -0.65 	-17.945590346 	-17.945590346
# 0.235 -0.6 	-13.5144828105 	-13.5144828105
# 0.235 -0.55 	-6.59723002013 	-6.59723002013
# 0.235 -0.5 	-6.94503441681 	-6.94503441681
# 0.235 -0.45 	-3.8071249106 	-3.8071249106
# 0.235 -0.4 	-6.7384647269 	-6.7384647269
# 0.235 -0.35 	-2.6321909033 	-2.6321909033
# 0.235 -0.3 	-2.14485811972 	-2.14485811972
# 0.235 -0.25 	6.26123580298 	6.26123580298
# 0.235 -0.2 	0.699817234618 	0.699817234618
# 0.235 -0.15 	5.50496085352 	5.50496085352
# 0.235 -0.1 	4.59173390889 	4.59173390889
# 0.235 -0.05 	-10.9047994287 	-10.9047994287
# 0.235 0.0 	-7.34447058278 	-7.34447058278
# 0.26 -2.5 	-11.1052017973 	-11.1052017973
# 0.26 -2.45 	-7.68179688375 	-7.68179688375
# 0.26 -2.4 	-15.0473077456 	-15.0473077456
# 0.26 -2.35 	-10.330237143 	-10.330237143
# 0.26 -2.3 	-13.2407135325 	-13.2407135325
# 0.26 -2.25 	-10.9293089778 	-10.9293089778
# 0.26 -2.2 	-17.8306133486 	-17.8306133486
# 0.26 -2.15 	-20.2799171097 	-20.2799171097
# 0.26 -2.1 	-25.7260750771 	-25.7260750771
# 0.26 -2.05 	-27.9221278896 	-27.9221278896
# 0.26 -2.0 	-31.9544821253 	-31.9544821253
# 0.26 -1.95 	-32.0134803875 	-32.0134803875
# 0.26 -1.9 	-27.2430410402 	-27.2430410402
# 0.26 -1.85 	-26.1955994134 	-26.1955994134
# 0.26 -1.8 	-24.8406741006 	-24.8406741006
# 0.26 -1.75 	-31.5166938193 	-31.5166938193
# 0.26 -1.7 	-27.7057905828 	-27.7057905828
# 0.26 -1.65 	-21.1291920093 	-21.1291920093
# 0.26 -1.6 	-21.3604809578 	-21.3604809578
# 0.26 -1.55 	-21.4674971325 	-21.4674971325
# 0.26 -1.5 	-23.694206169 	-23.694206169
# 0.26 -1.45 	-27.5074914959 	-27.5074914959
# 0.26 -1.4 	-22.8991484911 	-22.8991484911
# 0.26 -1.35 	-22.2329544558 	-22.2329544558
# 0.26 -1.3 	-20.8152237783 	-20.8152237783
# 0.26 -1.25 	-16.3043019284 	-16.3043019284
# 0.26 -1.2 	-16.9137105029 	-16.9137105029
# 0.26 -1.15 	-18.6791647238 	-18.6791647238
# 0.26 -1.1 	-19.5985988468 	-19.5985988468
# 0.26 -1.05 	-14.2144757003 	-14.2144757003
# 0.26 -1.0 	0.0409766730593 	0.0409766730593
# 0.26 -0.95 	-7.13296299857 	-7.13296299857
# 0.26 -0.9 	-10.0538795034 	-10.0538795034
# 0.26 -0.85 	-15.7332641003 	-15.7332641003
# 0.26 -0.8 	-11.1694635181 	-11.1694635181
# 0.26 -0.75 	-16.7208621279 	-16.7208621279
# 0.26 -0.7 	-17.3442542637 	-17.3442542637
# 0.26 -0.65 	-16.6098366377 	-16.6098366377
# 0.26 -0.6 	-14.431069272 	-14.431069272
# 0.26 -0.55 	-9.14690374486 	-9.14690374486
# 0.26 -0.5 	-7.11464578906 	-7.11464578906
# 0.26 -0.45 	-4.0374154148 	-4.0374154148
# 0.26 -0.4 	-6.17906160839 	-6.17906160839
# 0.26 -0.35 	-1.76937876871 	-1.76937876871
# 0.26 -0.3 	1.47814409693 	1.47814409693
# 0.26 -0.25 	4.37899152051 	4.37899152051
# 0.26 -0.2 	1.56054484421 	1.56054484421
# 0.26 -0.15 	5.37563729786 	5.37563729786
# 0.26 -0.1 	3.62103366127 	3.62103366127
# 0.26 -0.05 	-10.6284396162 	-10.6284396162
# 0.26 0.0 	-7.34447058278 	-7.34447058278
# 0.285 -2.5 	-27.0582249119 	-27.0582249119
# 0.285 -2.45 	-26.3485385376 	-26.3485385376
# 0.285 -2.4 	-25.7477423739 	-25.7477423739
# 0.285 -2.35 	-28.3382082798 	-28.3382082798
# 0.285 -2.3 	-28.4843989547 	-28.4843989547
# 0.285 -2.25 	-42.2618227481 	-42.2618227481
# 0.285 -2.2 	-38.7364613396 	-38.7364613396
# 0.285 -2.15 	-38.1769395949 	-38.1769395949
# 0.285 -2.1 	-33.6621797691 	-33.6621797691
# 0.285 -2.05 	-31.4576706053 	-31.4576706053
# 0.285 -2.0 	-36.7648458659 	-36.7648458659
# 0.285 -1.95 	-35.6502397653 	-35.6502397653
# 0.285 -1.9 	-35.7723929596 	-35.7723929596
# 0.285 -1.85 	-38.2052352128 	-38.2052352128
# 0.285 -1.8 	-27.0361377852 	-27.0361377852
# 0.285 -1.75 	-22.684201668 	-22.684201668
# 0.285 -1.7 	-22.3813678264 	-22.3813678264
# 0.285 -1.65 	-22.1077490731 	-22.1077490731
# 0.285 -1.6 	-24.5536450376 	-24.5536450376
# 0.285 -1.55 	-26.4153550509 	-26.4153550509
# 0.285 -1.5 	-22.714706922 	-22.714706922
# 0.285 -1.45 	-22.7667969482 	-22.7667969482
# 0.285 -1.4 	-19.2031595051 	-19.2031595051
# 0.285 -1.35 	-17.4125488685 	-17.4125488685
# 0.285 -1.3 	-15.8517796058 	-15.8517796058
# 0.285 -1.25 	-22.3678929638 	-22.3678929638
# 0.285 -1.2 	-22.6479540602 	-22.6479540602
# 0.285 -1.15 	-20.0901245297 	-20.0901245297
# 0.285 -1.1 	-8.63765219875 	-8.63765219875
# 0.285 -1.05 	-4.44547759635 	-4.44547759635
# 0.285 -1.0 	-4.81336531896 	-4.81336531896
# 0.285 -0.95 	-10.7514923502 	-10.7514923502
# 0.285 -0.9 	-13.3736945968 	-13.3736945968
# 0.285 -0.85 	-11.9201970018 	-11.9201970018
# 0.285 -0.8 	-15.4174577772 	-15.4174577772
# 0.285 -0.75 	-18.6387067608 	-18.6387067608
# 0.285 -0.7 	-18.516470688 	-18.516470688
# 0.285 -0.65 	-13.4941510695 	-13.4941510695
# 0.285 -0.6 	-8.98429935791 	-8.98429935791
# 0.285 -0.55 	-9.1244732511 	-9.1244732511
# 0.285 -0.5 	-7.9227056722 	-7.9227056722
# 0.285 -0.45 	-5.95845937229 	-5.95845937229
# 0.285 -0.4 	-5.02040166508 	-5.02040166508
# 0.285 -0.35 	-1.18005570748 	-1.18005570748
# 0.285 -0.3 	1.58866390686 	1.58866390686
# 0.285 -0.25 	1.08495805836 	1.08495805836
# 0.285 -0.2 	3.21029485123 	3.21029485123
# 0.285 -0.15 	5.97770311309 	5.97770311309
# 0.285 -0.1 	1.83577175501 	1.83577175501
# 0.285 -0.05 	-9.94036853627 	-9.94036853627
# 0.285 0.0 	-7.34447058278 	-7.34447058278
# 0.31 -2.5 	-30.8186505447 	-30.8186505447
# 0.31 -2.45 	-34.3809289845 	-34.3809289845
# 0.31 -2.4 	-35.8457731391 	-35.8457731391
# 0.31 -2.35 	-32.0770500405 	-32.0770500405
# 0.31 -2.3 	-29.1597580984 	-29.1597580984
# 0.31 -2.25 	-31.1872899342 	-31.1872899342
# 0.31 -2.2 	-40.0472782358 	-40.0472782358
# 0.31 -2.15 	-39.1417817325 	-39.1417817325
# 0.31 -2.1 	-37.8252612757 	-37.8252612757
# 0.31 -2.05 	-32.5737245053 	-32.5737245053
# 0.31 -2.0 	-29.5964235025 	-29.5964235025
# 0.31 -1.95 	-25.9288750753 	-25.9288750753
# 0.31 -1.9 	-23.0546644449 	-23.0546644449
# 0.31 -1.85 	-22.6874238101 	-22.6874238101
# 0.31 -1.8 	-19.0256143657 	-19.0256143657
# 0.31 -1.75 	-18.0916998053 	-18.0916998053
# 0.31 -1.7 	-18.1477769744 	-18.1477769744
# 0.31 -1.65 	-16.2794199712 	-16.2794199712
# 0.31 -1.6 	-21.5341025447 	-21.5341025447
# 0.31 -1.55 	-16.4716715672 	-16.4716715672
# 0.31 -1.5 	-16.736026672 	-16.736026672
# 0.31 -1.45 	-15.9227692614 	-15.9227692614
# 0.31 -1.4 	-18.0893422446 	-18.0893422446
# 0.31 -1.35 	-19.089909041 	-19.089909041
# 0.31 -1.3 	-20.3750506868 	-20.3750506868
# 0.31 -1.25 	-24.3964919255 	-24.3964919255
# 0.31 -1.2 	-16.6268469852 	-16.6268469852
# 0.31 -1.15 	-11.6412412062 	-11.6412412062
# 0.31 -1.1 	-1.35116189218 	-1.35116189218
# 0.31 -1.05 	-5.22990981628 	-5.22990981628
# 0.31 -1.0 	-9.69879993544 	-9.69879993544
# 0.31 -0.95 	-12.8041459196 	-12.8041459196
# 0.31 -0.9 	-12.1386409179 	-12.1386409179
# 0.31 -0.85 	-15.2691145514 	-15.2691145514
# 0.31 -0.8 	-17.3033577411 	-17.3033577411
# 0.31 -0.75 	-18.1120090695 	-18.1120090695
# 0.31 -0.7 	-10.1219323603 	-10.1219323603
# 0.31 -0.65 	-14.3170998312 	-14.3170998312
# 0.31 -0.6 	-4.66812629082 	-4.66812629082
# 0.31 -0.55 	-11.4299910246 	-11.4299910246
# 0.31 -0.5 	-3.33889999101 	-3.33889999101
# 0.31 -0.45 	-5.49323524477 	-5.49323524477
# 0.31 -0.4 	-4.26732119204 	-4.26732119204
# 0.31 -0.35 	-3.28114349598 	-3.28114349598
# 0.31 -0.3 	5.6936695595 	5.6936695595
# 0.31 -0.25 	1.1677829768 	1.1677829768
# 0.31 -0.2 	4.42734024151 	4.42734024151
# 0.31 -0.15 	6.24783458729 	6.24783458729
# 0.31 -0.1 	-0.119797429516 	-0.119797429516
# 0.31 -0.05 	-8.91458907484 	-8.91458907484
# 0.31 0.0 	-7.34447058278 	-7.34447058278
# 0.335 -2.5 	-25.1586874023 	-25.1586874023
# 0.335 -2.45 	-26.7754584641 	-26.7754584641
# 0.335 -2.4 	-28.9527944553 	-28.9527944553
# 0.335 -2.35 	-22.8520461688 	-22.8520461688
# 0.335 -2.3 	-27.3281478461 	-27.3281478461
# 0.335 -2.25 	-25.6310494664 	-25.6310494664
# 0.335 -2.2 	-19.5658959959 	-19.5658959959
# 0.335 -2.15 	-20.8429989254 	-20.8429989254
# 0.335 -2.1 	-21.6878464258 	-21.6878464258
# 0.335 -2.05 	-20.7417632406 	-20.7417632406
# 0.335 -2.0 	-16.5731951082 	-16.5731951082
# 0.335 -1.95 	-14.9878825502 	-14.9878825502
# 0.335 -1.9 	-17.0870794265 	-17.0870794265
# 0.335 -1.85 	-15.9345564869 	-15.9345564869
# 0.335 -1.8 	-17.3583275567 	-17.3583275567
# 0.335 -1.75 	-18.1043313909 	-18.1043313909
# 0.335 -1.7 	-22.0225374236 	-22.0225374236
# 0.335 -1.65 	-22.0440983758 	-22.0440983758
# 0.335 -1.6 	-21.4517074107 	-21.4517074107
# 0.335 -1.55 	-20.2850802231 	-20.2850802231
# 0.335 -1.5 	-22.8908276895 	-22.8908276895
# 0.335 -1.45 	-19.966767491 	-19.966767491
# 0.335 -1.4 	-18.0108250481 	-18.0108250481
# 0.335 -1.35 	-20.6321741824 	-20.6321741824
# 0.335 -1.3 	-13.7426536446 	-13.7426536446
# 0.335 -1.25 	-10.3171194863 	-10.3171194863
# 0.335 -1.2 	-7.16714829614 	-7.16714829614
# 0.335 -1.15 	-2.5682249395 	-2.5682249395
# 0.335 -1.1 	-5.28450749484 	-5.28450749484
# 0.335 -1.05 	-10.767047287 	-10.767047287
# 0.335 -1.0 	-13.9140898465 	-13.9140898465
# 0.335 -0.95 	-13.8374824236 	-13.8374824236
# 0.335 -0.9 	-12.7233679813 	-12.7233679813
# 0.335 -0.85 	-18.2494886474 	-18.2494886474
# 0.335 -0.8 	-20.9328243234 	-20.9328243234
# 0.335 -0.75 	-11.6523046673 	-11.6523046673
# 0.335 -0.7 	-17.399328308 	-17.399328308
# 0.335 -0.65 	-6.7495584465 	-6.7495584465
# 0.335 -0.6 	-7.20312671837 	-7.20312671837
# 0.335 -0.55 	-7.29073616688 	-7.29073616688
# 0.335 -0.5 	-2.08742438743 	-2.08742438743
# 0.335 -0.45 	-7.93867545081 	-7.93867545081
# 0.335 -0.4 	-3.43265705824 	-3.43265705824
# 0.335 -0.35 	-1.46893439037 	-1.46893439037
# 0.335 -0.3 	4.94331951022 	4.94331951022
# 0.335 -0.25 	-0.42860485568 	-0.42860485568
# 0.335 -0.2 	5.4954191596 	5.4954191596
# 0.335 -0.15 	4.98834158332 	4.98834158332
# 0.335 -0.1 	-0.952353906859 	-0.952353906859
# 0.335 -0.05 	-9.00958469083 	-9.00958469083
# 0.335 0.0 	-7.34447058278 	-7.34447058278
# 0.36 -2.5 	-29.7420421678 	-29.7420421678
# 0.36 -2.45 	-27.2206750872 	-27.2206750872
# 0.36 -2.4 	-25.4260693484 	-25.4260693484
# 0.36 -2.35 	-26.7861020171 	-26.7861020171
# 0.36 -2.3 	-30.6489213975 	-30.6489213975
# 0.36 -2.25 	-24.7500015951 	-24.7500015951
# 0.36 -2.2 	-22.8724415562 	-22.8724415562
# 0.36 -2.15 	-24.7280837318 	-24.7280837318
# 0.36 -2.1 	-21.0460407683 	-21.0460407683
# 0.36 -2.05 	-21.218192053 	-21.218192053
# 0.36 -2.0 	-19.8488070892 	-19.8488070892
# 0.36 -1.95 	-18.9551043072 	-18.9551043072
# 0.36 -1.9 	-21.056098281 	-21.056098281
# 0.36 -1.85 	-20.4738684162 	-20.4738684162
# 0.36 -1.8 	-23.0527702535 	-23.0527702535
# 0.36 -1.75 	-14.3253597152 	-14.3253597152
# 0.36 -1.7 	-14.1386539381 	-14.1386539381
# 0.36 -1.65 	-18.5185262201 	-18.5185262201
# 0.36 -1.6 	-18.2327317488 	-18.2327317488
# 0.36 -1.55 	-15.2849383892 	-15.2849383892
# 0.36 -1.5 	-17.5862360645 	-17.5862360645
# 0.36 -1.45 	-18.6305441276 	-18.6305441276
# 0.36 -1.4 	-16.5372453929 	-16.5372453929
# 0.36 -1.35 	-14.0665493129 	-14.0665493129
# 0.36 -1.3 	-10.9588759718 	-10.9588759718
# 0.36 -1.25 	-5.36440089571 	-5.36440089571
# 0.36 -1.2 	-2.05109589848 	-2.05109589848
# 0.36 -1.15 	-8.62155485457 	-8.62155485457
# 0.36 -1.1 	-13.3871116666 	-13.3871116666
# 0.36 -1.05 	-13.5799143478 	-13.5799143478
# 0.36 -1.0 	-15.6981843233 	-15.6981843233
# 0.36 -0.95 	-12.9249674538 	-12.9249674538
# 0.36 -0.9 	-18.4527760423 	-18.4527760423
# 0.36 -0.85 	-16.4716649873 	-16.4716649873
# 0.36 -0.8 	-17.4659388383 	-17.4659388383
# 0.36 -0.75 	-16.658226849 	-16.658226849
# 0.36 -0.7 	-5.26169354383 	-5.26169354383
# 0.36 -0.65 	-5.90077884357 	-5.90077884357
# 0.36 -0.6 	-6.22220685543 	-6.22220685543
# 0.36 -0.55 	-4.90356592623 	-4.90356592623
# 0.36 -0.5 	-6.16745206765 	-6.16745206765
# 0.36 -0.45 	-4.08008594148 	-4.08008594148
# 0.36 -0.4 	-1.05626756474 	-1.05626756474
# 0.36 -0.35 	-0.327352156132 	-0.327352156132
# 0.36 -0.3 	6.16917018923 	6.16917018923
# 0.36 -0.25 	0.646093064752 	0.646093064752
# 0.36 -0.2 	4.58124902212 	4.58124902212
# 0.36 -0.15 	4.4357063918 	4.4357063918
# 0.36 -0.1 	-0.707728972313 	-0.707728972313
# 0.36 -0.05 	-11.3807783763 	-11.3807783763
# 0.36 0.0 	-7.34447058278 	-7.34447058278
# 0.385 -2.5 	-26.4434009131 	-26.4434009131
# 0.385 -2.45 	-26.4824952514 	-26.4824952514
# 0.385 -2.4 	-29.2338344221 	-29.2338344221
# 0.385 -2.35 	-25.5040721464 	-25.5040721464
# 0.385 -2.3 	-24.0015533731 	-24.0015533731
# 0.385 -2.25 	-19.897435626 	-19.897435626
# 0.385 -2.2 	-19.0042238551 	-19.0042238551
# 0.385 -2.15 	-17.3844619301 	-17.3844619301
# 0.385 -2.1 	-20.1977290668 	-20.1977290668
# 0.385 -2.05 	-20.1516472028 	-20.1516472028
# 0.385 -2.0 	-22.8335071776 	-22.8335071776
# 0.385 -1.95 	-18.6225556902 	-18.6225556902
# 0.385 -1.9 	-19.9739877998 	-19.9739877998
# 0.385 -1.85 	-17.9607394662 	-17.9607394662
# 0.385 -1.8 	-23.8456252834 	-23.8456252834
# 0.385 -1.75 	-23.3636957643 	-23.3636957643
# 0.385 -1.7 	-21.5244396091 	-21.5244396091
# 0.385 -1.65 	-21.982704673 	-21.982704673
# 0.385 -1.6 	-17.8616411724 	-17.8616411724
# 0.385 -1.55 	-21.3915806015 	-21.3915806015
# 0.385 -1.5 	-20.0051974479 	-20.0051974479
# 0.385 -1.45 	-15.7266077866 	-15.7266077866
# 0.385 -1.4 	-9.31232069129 	-9.31232069129
# 0.385 -1.35 	-8.14496914205 	-8.14496914205
# 0.385 -1.3 	-6.90825189579 	-6.90825189579
# 0.385 -1.25 	-6.00447218407 	-6.00447218407
# 0.385 -1.2 	-9.13683228744 	-9.13683228744
# 0.385 -1.15 	-16.9572269172 	-16.9572269172
# 0.385 -1.1 	-15.3749232964 	-15.3749232964
# 0.385 -1.05 	-15.3569912374 	-15.3569912374
# 0.385 -1.0 	-15.3704673461 	-15.3704673461
# 0.385 -0.95 	-16.8652144227 	-16.8652144227
# 0.385 -0.9 	-17.1011224565 	-17.1011224565
# 0.385 -0.85 	-18.3098658283 	-18.3098658283
# 0.385 -0.8 	-12.6433789752 	-12.6433789752
# 0.385 -0.75 	-7.83539884609 	-7.83539884609
# 0.385 -0.7 	-7.63494624813 	-7.63494624813
# 0.385 -0.65 	-11.6482525827 	-11.6482525827
# 0.385 -0.6 	-6.20796325794 	-6.20796325794
# 0.385 -0.55 	-2.56257103296 	-2.56257103296
# 0.385 -0.5 	-5.40723678551 	-5.40723678551
# 0.385 -0.45 	-0.357050604732 	-0.357050604732
# 0.385 -0.4 	-1.05760367762 	-1.05760367762
# 0.385 -0.35 	4.071738912 	4.071738912
# 0.385 -0.3 	2.99038385535 	2.99038385535
# 0.385 -0.25 	0.48157433274 	0.48157433274
# 0.385 -0.2 	5.92583163048 	5.92583163048
# 0.385 -0.15 	3.90290718738 	3.90290718738
# 0.385 -0.1 	-2.66589965136 	-2.66589965136
# 0.385 -0.05 	-8.86133036166 	-8.86133036166
# 0.385 0.0 	-7.34447058278 	-7.34447058278
# 0.41 -2.5 	-21.767094217 	-21.767094217
# 0.41 -2.45 	-18.2586881666 	-18.2586881666
# 0.41 -2.4 	-15.1474623703 	-15.1474623703
# 0.41 -2.35 	-11.2181375504 	-11.2181375504
# 0.41 -2.3 	-12.267214111 	-12.267214111
# 0.41 -2.25 	-16.8363673587 	-16.8363673587
# 0.41 -2.2 	-13.7591395321 	-13.7591395321
# 0.41 -2.15 	-10.7703277352 	-10.7703277352
# 0.41 -2.1 	-16.8944744627 	-16.8944744627
# 0.41 -2.05 	-19.5221577958 	-19.5221577958
# 0.41 -2.0 	-20.1581809867 	-20.1581809867
# 0.41 -1.95 	-21.1743270355 	-21.1743270355
# 0.41 -1.9 	-20.634143155 	-20.634143155
# 0.41 -1.85 	-16.7763649639 	-16.7763649639
# 0.41 -1.8 	-17.8751295724 	-17.8751295724
# 0.41 -1.75 	-18.4019925087 	-18.4019925087
# 0.41 -1.7 	-20.156446873 	-20.156446873
# 0.41 -1.65 	-17.4089207507 	-17.4089207507
# 0.41 -1.6 	-18.1098467342 	-18.1098467342
# 0.41 -1.55 	-11.7040520486 	-11.7040520486
# 0.41 -1.5 	-8.56212874546 	-8.56212874546
# 0.41 -1.45 	-9.55193633974 	-9.55193633974
# 0.41 -1.4 	-3.8663425687 	-3.8663425687
# 0.41 -1.35 	-2.92944547314 	-2.92944547314
# 0.41 -1.3 	-6.2037578177 	-6.2037578177
# 0.41 -1.25 	-15.0850915744 	-15.0850915744
# 0.41 -1.2 	-15.3568568905 	-15.3568568905
# 0.41 -1.15 	-14.1842531044 	-14.1842531044
# 0.41 -1.1 	-13.2999501872 	-13.2999501872
# 0.41 -1.05 	-15.1457002238 	-15.1457002238
# 0.41 -1.0 	-16.7000171696 	-16.7000171696
# 0.41 -0.95 	-17.1167840337 	-17.1167840337
# 0.41 -0.9 	-16.9056283303 	-16.9056283303
# 0.41 -0.85 	-9.83127752823 	-9.83127752823
# 0.41 -0.8 	-8.08488309351 	-8.08488309351
# 0.41 -0.75 	-6.60392685543 	-6.60392685543
# 0.41 -0.7 	-11.7462248613 	-11.7462248613
# 0.41 -0.65 	-8.36716728783 	-8.36716728783
# 0.41 -0.6 	-1.9904097629 	-1.9904097629
# 0.41 -0.55 	-6.7811239432 	-6.7811239432
# 0.41 -0.5 	-3.45313998423 	-3.45313998423
# 0.41 -0.45 	-0.761886929191 	-0.761886929191
# 0.41 -0.4 	-4.86957855277 	-4.86957855277
# 0.41 -0.35 	3.19254005319 	3.19254005319
# 0.41 -0.3 	0.702397338279 	0.702397338279
# 0.41 -0.25 	2.4828993382 	2.4828993382
# 0.41 -0.2 	5.03427156095 	5.03427156095
# 0.41 -0.15 	4.71696896233 	4.71696896233
# 0.41 -0.1 	-4.15674744853 	-4.15674744853
# 0.41 -0.05 	-11.646440878 	-11.646440878
# 0.41 0.0 	-7.34447058278 	-7.34447058278
# 0.435 -2.5 	-16.4237075953 	-16.4237075953
# 0.435 -2.45 	-18.1117591585 	-18.1117591585
# 0.435 -2.4 	-17.0158804265 	-17.0158804265
# 0.435 -2.35 	-16.9076451659 	-16.9076451659
# 0.435 -2.3 	-20.8331119775 	-20.8331119775
# 0.435 -2.25 	-21.5878072341 	-21.5878072341
# 0.435 -2.2 	-24.378730853 	-24.378730853
# 0.435 -2.15 	-24.2327869857 	-24.2327869857
# 0.435 -2.1 	-22.8788930249 	-22.8788930249
# 0.435 -2.05 	-21.5658602433 	-21.5658602433
# 0.435 -2.0 	-22.7070178214 	-22.7070178214
# 0.435 -1.95 	-20.094729415 	-20.094729415
# 0.435 -1.9 	-21.1670617772 	-21.1670617772
# 0.435 -1.85 	-21.8773213307 	-21.8773213307
# 0.435 -1.8 	-19.6056610876 	-19.6056610876
# 0.435 -1.75 	-15.757854929 	-15.757854929
# 0.435 -1.7 	-11.9918798474 	-11.9918798474
# 0.435 -1.65 	-10.4144649084 	-10.4144649084
# 0.435 -1.6 	-5.75115804248 	-5.75115804248
# 0.435 -1.55 	-4.12763922561 	-4.12763922561
# 0.435 -1.5 	-5.36625962869 	-5.36625962869
# 0.435 -1.45 	-7.05698758287 	-7.05698758287
# 0.435 -1.4 	-10.1733013282 	-10.1733013282
# 0.435 -1.35 	-15.3671808059 	-15.3671808059
# 0.435 -1.3 	-13.6187115268 	-13.6187115268
# 0.435 -1.25 	-16.7858553935 	-16.7858553935
# 0.435 -1.2 	-12.4465465549 	-12.4465465549
# 0.435 -1.15 	-19.1788931422 	-19.1788931422
# 0.435 -1.1 	-12.9023709491 	-12.9023709491
# 0.435 -1.05 	-15.849501604 	-15.849501604
# 0.435 -1.0 	-16.6168156246 	-16.6168156246
# 0.435 -0.95 	-12.8744883449 	-12.8744883449
# 0.435 -0.9 	-11.6705123677 	-11.6705123677
# 0.435 -0.85 	-9.88597535025 	-9.88597535025
# 0.435 -0.8 	-4.01301948796 	-4.01301948796
# 0.435 -0.75 	-13.0146643299 	-13.0146643299
# 0.435 -0.7 	-5.73384836182 	-5.73384836182
# 0.435 -0.65 	-1.83230073112 	-1.83230073112
# 0.435 -0.6 	-6.74952790083 	-6.74952790083
# 0.435 -0.55 	-4.09539987438 	-4.09539987438
# 0.435 -0.5 	-2.16955014277 	-2.16955014277
# 0.435 -0.45 	-2.1192446086 	-2.1192446086
# 0.435 -0.4 	2.73037542174 	2.73037542174
# 0.435 -0.35 	4.09213914589 	4.09213914589
# 0.435 -0.3 	0.847561546522 	0.847561546522
# 0.435 -0.25 	5.90517148672 	5.90517148672
# 0.435 -0.2 	6.43045703358 	6.43045703358
# 0.435 -0.15 	5.46599273713 	5.46599273713
# 0.435 -0.1 	-3.86362810277 	-3.86362810277
# 0.435 -0.05 	-10.2224207576 	-10.2224207576
# 0.435 0.0 	-7.34447058278 	-7.34447058278
# 0.46 -2.5 	-19.8779190137 	-19.8779190137
# 0.46 -2.45 	-22.5479144373 	-22.5479144373
# 0.46 -2.4 	-23.8008421203 	-23.8008421203
# 0.46 -2.35 	-20.8405368739 	-20.8405368739
# 0.46 -2.3 	-18.6533946185 	-18.6533946185
# 0.46 -2.25 	-16.1656949232 	-16.1656949232
# 0.46 -2.2 	-15.6955394337 	-15.6955394337
# 0.46 -2.15 	-13.9994579635 	-13.9994579635
# 0.46 -2.1 	-15.8151103348 	-15.8151103348
# 0.46 -2.05 	-13.9077162885 	-13.9077162885
# 0.46 -2.0 	-12.6556603229 	-12.6556603229
# 0.46 -1.95 	-8.4415595901 	-8.4415595901
# 0.46 -1.9 	-7.80894468424 	-7.80894468424
# 0.46 -1.85 	-8.69365520035 	-8.69365520035
# 0.46 -1.8 	-6.51324616582 	-6.51324616582
# 0.46 -1.75 	-2.64400093773 	-2.64400093773
# 0.46 -1.7 	-2.73925006704 	-2.73925006704
# 0.46 -1.65 	-6.48488805267 	-6.48488805267
# 0.46 -1.6 	-6.16452973481 	-6.16452973481
# 0.46 -1.55 	-6.55979617241 	-6.55979617241
# 0.46 -1.5 	-11.4130016222 	-11.4130016222
# 0.46 -1.45 	-15.3717104375 	-15.3717104375
# 0.46 -1.4 	-15.8386500144 	-15.8386500144
# 0.46 -1.35 	-16.1921744951 	-16.1921744951
# 0.46 -1.3 	-12.8637214079 	-12.8637214079
# 0.46 -1.25 	-17.7697852444 	-17.7697852444
# 0.46 -1.2 	-12.3315562352 	-12.3315562352
# 0.46 -1.15 	-15.6875435655 	-15.6875435655
# 0.46 -1.1 	-15.3253384328 	-15.3253384328
# 0.46 -1.05 	-14.7967135217 	-14.7967135217
# 0.46 -1.0 	-12.8712532877 	-12.8712532877
# 0.46 -0.95 	-11.7162611483 	-11.7162611483
# 0.46 -0.9 	-10.7725753376 	-10.7725753376
# 0.46 -0.85 	-8.12618419167 	-8.12618419167
# 0.46 -0.8 	-11.6720167503 	-11.6720167503
# 0.46 -0.75 	-6.25464358039 	-6.25464358039
# 0.46 -0.7 	-4.39540355797 	-4.39540355797
# 0.46 -0.65 	-4.50905872722 	-4.50905872722
# 0.46 -0.6 	-1.8306541334 	-1.8306541334
# 0.46 -0.55 	-6.09947653828 	-6.09947653828
# 0.46 -0.5 	-3.23714518693 	-3.23714518693
# 0.46 -0.45 	-5.06345381937 	-5.06345381937
# 0.46 -0.4 	3.53174625536 	3.53174625536
# 0.46 -0.35 	3.9644920163 	3.9644920163
# 0.46 -0.3 	-2.27020498065 	-2.27020498065
# 0.46 -0.25 	6.2408447328 	6.2408447328
# 0.46 -0.2 	7.00431793458 	7.00431793458
# 0.46 -0.15 	5.02143173714 	5.02143173714
# 0.46 -0.1 	-4.61392564594 	-4.61392564594
# 0.46 -0.05 	-11.5874741382 	-11.5874741382
# 0.46 0.0 	-7.34447058278 	-7.34447058278
# 0.485 -2.5 	-13.972466202 	-13.972466202
# 0.485 -2.45 	-14.2089454144 	-14.2089454144
# 0.485 -2.4 	-17.6060808228 	-17.6060808228
# 0.485 -2.35 	-12.907471096 	-12.907471096
# 0.485 -2.3 	-14.6427026725 	-14.6427026725
# 0.485 -2.25 	-11.1054320866 	-11.1054320866
# 0.485 -2.2 	-7.90421139305 	-7.90421139305
# 0.485 -2.15 	-10.1756354167 	-10.1756354167
# 0.485 -2.1 	-9.96035336056 	-9.96035336056
# 0.485 -2.05 	-8.79785869726 	-8.79785869726
# 0.485 -2.0 	-7.74872099081 	-7.74872099081
# 0.485 -1.95 	-5.62924316854 	-5.62924316854
# 0.485 -1.9 	-6.68298092816 	-6.68298092816
# 0.485 -1.85
#  	-7.68360065152 	-7.68360065152
# 0.485 -1.8 	-11.3036917517 	-11.3036917517
# 0.485 -1.75 	-13.229797715 	-13.229797715
# 0.485 -1.7 	-9.21953948199 	-9.21953948199
# 0.485 -1.65 	-14.7379381404 	-14.7379381404
# 0.485 -1.6 	-15.7986600312 	-15.7986600312
# 0.485 -1.55 	-17.2752230532 	-17.2752230532
# 0.485 -1.5 	-21.1594121526 	-21.1594121526
# 0.485 -1.45 	-14.579630967 	-14.579630967
# 0.485 -1.4 	-10.4735306883 	-10.4735306883
# 0.485 -1.35 	-15.8285615709 	-15.8285615709
# 0.485 -1.3 	-18.7918201459 	-18.7918201459
# 0.485 -1.25 	-16.522573009 	-16.522573009
# 0.485 -1.2 	-15.2795418559 	-15.2795418559
# 0.485 -1.15 	-13.512870356 	-13.512870356
# 0.485 -1.1 	-16.2837261316 	-16.2837261316
# 0.485 -1.05 	-15.111632344 	-15.111632344
# 0.485 -1.0 	-13.2547268423 	-13.2547268423
# 0.485 -0.95 	-12.5371851065 	-12.5371851065
# 0.485 -0.9 	-6.06465668076 	-6.06465668076
# 0.485 -0.85 	-11.493877602 	-11.493877602
# 0.485 -0.8 	-4.59434372455 	-4.59434372455
# 0.485 -0.75 	-4.41696885832 	-4.41696885832
# 0.485 -0.7 	-2.29561786611 	-2.29561786611
# 0.485 -0.65 	-2.12585737321 	-2.12585737321
# 0.485 -0.6 	-3.25695835649 	-3.25695835649
# 0.485 -0.55 	-3.29059242825 	-3.29059242825
# 0.485 -0.5 	-2.66660214416 	-2.66660214416
# 0.485 -0.45 	2.11517760811 	2.11517760811
# 0.485 -0.4 	1.79598536593 	1.79598536593
# 0.485 -0.35 	0.483447736953 	0.483447736953
# 0.485 -0.3 	2.50682891111 	2.50682891111
# 0.485 -0.25 	4.85877536212 	4.85877536212
# 0.485 -0.2 	5.53661484089 	5.53661484089
# 0.485 -0.15 	3.98189749361 	3.98189749361
# 0.485 -0.1 	-4.38240893255 	-4.38240893255
# 0.485 -0.05 	-9.01112467709 	-9.01112467709
# 0.485 0.0 	-7.34447058278 	-7.34447058278
# 0.51 -2.5 	-6.93116262025 	-6.93116262025
# 0.51 -2.45 	-7.30199973299 	-7.30199973299
# 0.51 -2.4 	-10.3844426559 	-10.3844426559
# 0.51 -2.35 	-14.4156925564 	-14.4156925564
# 0.51 -2.3 	-13.1154817783 	-13.1154817783
# 0.51 -2.25 	-14.6933135189 	-14.6933135189
# 0.51 -2.2 	-12.663616982 	-12.663616982
# 0.51 -2.15 	-13.1987972465 	-13.1987972465
# 0.51 -2.1 	-13.7197691651 	-13.7197691651
# 0.51 -2.05 	-14.2104828995 	-14.2104828995
# 0.51 -2.0 	-16.7709565416 	-16.7709565416
# 0.51 -1.95 	-14.7940651455 	-14.7940651455
# 0.51 -1.9 	-14.624868997 	-14.624868997
# 0.51 -1.85 	-17.8053221231 	-17.8053221231
# 0.51 -1.8 	-16.5295510531 	-16.5295510531
# 0.51 -1.75 	-16.2893968669 	-16.2893968669
# 0.51 -1.7 	-19.686080962 	-19.686080962
# 0.51 -1.65 	-17.5490122227 	-17.5490122227
# 0.51 -1.6 	-13.5171542207 	-13.5171542207
# 0.51 -1.55 	-12.3023025782 	-12.3023025782
# 0.51 -1.5 	-19.3826976707 	-19.3826976707
# 0.51 -1.45 	-18.4251080501 	-18.4251080501
# 0.51 -1.4 	-20.1485790567 	-20.1485790567
# 0.51 -1.35 	-19.5040386418 	-19.5040386418
# 0.51 -1.3 	-14.0772165396 	-14.0772165396
# 0.51 -1.25 	-17.2772109131 	-17.2772109131
# 0.51 -1.2 	-17.6962184655 	-17.6962184655
# 0.51 -1.15 	-14.8386668597 	-14.8386668597
# 0.51 -1.1 	-14.9855341754 	-14.9855341754
# 0.51 -1.05 	-11.8187354748 	-11.8187354748
# 0.51 -1.0 	-11.399623987 	-11.399623987
# 0.51 -0.95 	-8.94544942652 	-8.94544942652
# 0.51 -0.9 	-5.87756297077 	-5.87756297077
# 0.51 -0.85 	-1.1446452162 	-1.1446452162
# 0.51 -0.8 	-3.49381479235 	-3.49381479235
# 0.51 -0.75 	-1.96412990626 	-1.96412990626
# 0.51 -0.7 	0.16506577585 	0.16506577585
# 0.51 -0.65 	-2.74157360022 	-2.74157360022
# 0.51 -0.6 	-6.05496504703 	-6.05496504703
# 0.51 -0.55 	-2.947882622 	-2.947882622
# 0.51 -0.5 	-5.38942898784 	-5.38942898784
# 0.51 -0.45 	2.33811448441 	2.33811448441
# 0.51 -0.4 	5.28924782939 	5.28924782939
# 0.51 -0.35 	0.550376409083 	0.550376409083
# 0.51 -0.3 	4.6522908085 	4.6522908085
# 0.51 -0.25 	4.03152694304 	4.03152694304
# 0.51 -0.2 	3.52969562088 	3.52969562088
# 0.51 -0.15 	1.77700580334 	1.77700580334
# 0.51 -0.1 	-7.15903805438 	-7.15903805438
# 0.51 -0.05 	-10.4131848177 	-10.4131848177
# 0.51 0.0 	-7.34447058278 	-7.34447058278
# 0.535 -2.5 	-9.64253232826 	-9.64253232826
# 0.535 -2.45 	-12.514192413 	-12.514192413
# 0.535 -2.4 	-10.2872633289 	-10.2872633289
# 0.535 -2.35 	-12.8354098108 	-12.8354098108
# 0.535 -2.3 	-15.4490139802 	-15.4490139802
# 0.535 -2.25 	-14.2349706236 	-14.2349706236
# 0.535 -2.2 	-14.0697613229 	-14.0697613229
# 0.535 -2.15 	-11.1769804199 	-11.1769804199
# 0.535 -2.1 	-10.4638716188 	-10.4638716188
# 0.535 -2.05 	-12.608021906 	-12.608021906
# 0.535 -2.0 	-11.2301684448 	-11.2301684448
# 0.535 -1.95 	-11.4561813064 	-11.4561813064
# 0.535 -1.9 	-12.6376736575 	-12.6376736575
# 0.535 -1.85 	-18.5161634584 	-18.5161634584
# 0.535 -1.8 	-19.1655946618 	-19.1655946618
# 0.535 -1.75 	-21.4842419013 	-21.4842419013
# 0.535 -1.7 	-19.3002242571 	-19.3002242571
# 0.535 -1.65 	-20.5225489292 	-20.5225489292
# 0.535 -1.6 	-19.4328427668 	-19.4328427668
# 0.535 -1.55 	-23.7714492088 	-23.7714492088
# 0.535 -1.5 	-21.3879719461 	-21.3879719461
# 0.535 -1.45 	-15.1354957335 	-15.1354957335
# 0.535 -1.4 	-15.4785320578 	-15.4785320578
# 0.535 -1.35 	-16.7627726341 	-16.7627726341
# 0.535 -1.3 	-17.6298074016 	-17.6298074016
# 0.535 -1.25 	-14.1613547948 	-14.1613547948
# 0.535 -1.2 	-14.5670338509 	-14.5670338509
# 0.535 -1.15 	-9.93310806905 	-9.93310806905
# 0.535 -1.1 	-9.98291726945 	-9.98291726945
# 0.535 -1.05 	-8.78879078742 	-8.78879078742
# 0.535 -1.0 	-6.99966130611 	-6.99966130611
# 0.535 -0.95 	-5.92590725477 	-5.92590725477
# 0.535 -0.9 	-2.57578813095 	-2.57578813095
# 0.535 -0.85 	-4.80401682375 	-4.80401682375
# 0.535 -0.8 	1.69967271414 	1.69967271414
# 0.535 -0.75 	0.76650248922 	0.76650248922
# 0.535 -0.7 	-3.93771640062 	-3.93771640062
# 0.535 -0.65 	-6.80846813648 	-6.80846813648
# 0.535 -0.6 	-4.1899576732 	-4.1899576732
# 0.535 -0.55 	-3.6089451131 	-3.6089451131
# 0.535 -0.5 	2.23444597138 	2.23444597138
# 0.535 -0.45 	1.88439759822 	1.88439759822
# 0.535 -0.4 	2.52559976194 	2.52559976194
# 0.535 -0.35 	0.725930767646 	0.725930767646
# 0.535 -0.3 	6.05740452609 	6.05740452609
# 0.535 -0.25 	6.26617089287 	6.26617089287
# 0.535 -0.2 	5.70860759728 	5.70860759728
# 0.535 -0.15 	0.514635629636 	0.514635629636
# 0.535 -0.1 	-9.51201829058 	-9.51201829058
# 0.535 -0.05 	-12.2613762267 	-12.2613762267
# 0.535 0.0 	-7.34447058278 	-7.34447058278
# 0.56 -2.5 	-1.46082538092 	-1.46082538092
# 0.56 -2.45 	-2.91913871489 	-2.91913871489
# 0.56 -2.4 	-5.05985823375 	-5.05985823375
# 0.56 -2.35 	-4.21346446727 	-4.21346446727
# 0.56 -2.3 	-4.49070587932 	-4.49070587932
# 0.56 -2.25 	-6.23714819168 	-6.23714819168
# 0.56 -2.2 	-5.55852259329 	-5.55852259329
# 0.56 -2.15 	-6.0382863411 	-6.0382863411
# 0.56 -2.1 	-9.50123784563 	-9.50123784563
# 0.56 -2.05 	-10.717573213 	-10.717573213
# 0.56 -2.0 	-12.5878579132 	-12.5878579132
# 0.56 -1.95 	-15.4700566371 	-15.4700566371
# 0.56 -1.9 	-13.8090183442 	-13.8090183442
# 0.56 -1.85 	-12.697161614 	-12.697161614
# 0.56 -1.8 	-14.1873383304 	-14.1873383304
# 0.56 -1.75 	-13.6431116242 	-13.6431116242
# 0.56 -1.7 	-9.05791382952 	-9.05791382952
# 0.56 -1.65 	-10.4310188126 	-10.4310188126
# 0.56 -1.6 	-9.40005389309 	-9.40005389309
# 0.56 -1.55 	-7.62774396017 	-7.62774396017
# 0.56 -1.5 	-11.3934760224 	-11.3934760224
# 0.56 -1.45 	-10.5926118771 	-10.5926118771
# 0.56 -1.4 	-9.13468821936 	-9.13468821936
# 0.56 -1.35 	-8.72405029376 	-8.72405029376
# 0.56 -1.3 	-10.0317667745 	-10.0317667745
# 0.56 -1.25 	-5.68256398884 	-5.68256398884
# 0.56 -1.2 	-4.60621373115 	-4.60621373115
# 0.56 -1.15 	-7.19827361778 	-7.19827361778
# 0.56 -1.1 	-4.46581012111 	-4.46581012111
# 0.56 -1.05 	-3.60506336025 	-3.60506336025
# 0.56 -1.0 	-4.26879797325 	-4.26879797325
# 0.56 -0.95 	-2.11830346949 	-2.11830346949
# 0.56 -0.9 	-2.7955041626 	-2.7955041626
# 0.56 -0.85 	1.34149356037 	1.34149356037
# 0.56 -0.8 	-1.7689367566 	-1.7689367566
# 0.56 -0.75 	-5.48200231211 	-5.48200231211
# 0.56 -0.7 	-9.15451718003 	-9.15451718003
# 0.56 -0.65 	-7.06520911034 	-7.06520911034
# 0.56 -0.6 	-3.75272409062 	-3.75272409062
# 0.56 -0.55 	0.601434968867 	0.601434968867
# 0.56 -0.5 	-0.330401844258 	-0.330401844258
# 0.56 -0.45 	4.09609004712 	4.09609004712
# 0.56 -0.4 	-0.843238516389 	-0.843238516389
# 0.56 -0.35 	3.20467128156 	3.20467128156
# 0.56 -0.3 	5.03599849641 	5.03599849641
# 0.56 -0.25 	7.19863646427 	7.19863646427
# 0.56 -0.2 	4.88621977921 	4.88621977921
# 0.56 -0.15 	-1.46003456972 	-1.46003456972
# 0.56 -0.1 	-8.88116340169 	-8.88116340169
# 0.56 -0.05 	-13.5827390515 	-13.5827390515
# 0.56 0.0 	-7.34447058278 	-7.34447058278
# 0.585 -2.5 	-7.66020747114 	-7.66020747114
# 0.585 -2.45 	-10.138322783 	-10.138322783
# 0.585 -2.4 	-8.02894566477 	-8.02894566477
# 0.585 -2.35 	-6.82865451725 	-6.82865451725
# 0.585 -2.3 	-8.85857551876 	-8.85857551876
# 0.585 -2.25 	-11.5025644418 	-11.5025644418
# 0.585 -2.2 	-13.2616640977 	-13.2616640977
# 0.585 -2.15 	-8.53666922101 	-8.53666922101
# 0.585 -2.1 	-10.0177006587 	-10.0177006587
# 0.585 -2.05 	-6.01740878259 	-6.01740878259
# 0.585 -2.0 	-9.0443702955 	-9.0443702955
# 0.585 -1.95 	-7.85934935351 	-7.85934935351
# 0.585 -1.9 	-5.25099799535 	-5.25099799535
# 0.585 -1.85 	-4.68314872616 	-4.68314872616
# 0.585 -1.8 	-7.62821363522 	-7.62821363522
# 0.585 -1.75 	-8.16261428566 	-8.16261428566
# 0.585 -1.7 	-6.5556911031 	-6.5556911031
# 0.585 -1.65 	-7.28138702346 	-7.28138702346
# 0.585 -1.6 	-6.72919931729 	-6.72919931729
# 0.585 -1.55 	-6.57384419213 	-6.57384419213
# 0.585 -1.5 	-5.39746000534 	-5.39746000534
# 0.585 -1.45 	-6.8066555884 	-6.8066555884
# 0.585 -1.4 	-8.55232756443 	-8.55232756443
# 0.585 -1.35 	-3.5412998547 	-3.5412998547
# 0.585 -1.3 	-4.26220301131 	-4.26220301131
# 0.585 -1.25 	-4.72024893658 	-4.72024893658
# 0.585 -1.2 	-5.15969134899 	-5.15969134899
# 0.585 -1.15 	-3.05153260613 	-3.05153260613
# 0.585 -1.1 	-4.64520363197 	-4.64520363197
# 0.585 -1.05 	0.231171810137 	0.231171810137
# 0.585 -1.0 	-1.46176154422 	-1.46176154422
# 0.585 -0.95 	1.76809297232 	1.76809297232
# 0.585 -0.9 	1.30410882104 	1.30410882104
# 0.585 -0.85 	-5.81200858912 	-5.81200858912
# 0.585 -0.8 	-8.59423672405 	-8.59423672405
# 0.585 -0.75 	-9.08639243473 	-9.08639243473
# 0.585 -0.7 	-2.89046336268 	-2.89046336268
# 0.585 -0.65 	-6.09101856262 	-6.09101856262
# 0.585 -0.6 	-0.832004518598 	-0.832004518598
# 0.585 -0.55 	1.69719561034 	1.69719561034
# 0.585 -0.5 	2.79035131046 	2.79035131046
# 0.585 -0.45 	2.14827679055 	2.14827679055
# 0.585 -0.4 	2.37428511364 	2.37428511364
# 0.585 -0.35 	6.29498863682 	6.29498863682
# 0.585 -0.3 	3.86846622828 	3.86846622828
# 0.585 -0.25 	5.26030705425 	5.26030705425
# 0.585 -0.2 	6.52301901624 	6.52301901624
# 0.585 -0.15 	-2.87888362609 	-2.87888362609
# 0.585 -0.1 	-8.68985934757 	-8.68985934757
# 0.585 -0.05 	-13.493926031 	-13.493926031
# 0.585 0.0 	-7.34447058278 	-7.34447058278
# 0.61 -2.5 	-6.41298271868 	-6.41298271868
# 0.61 -2.45 	-6.35805902881 	-6.35805902881
# 0.61 -2.4 	-4.88224404185 	-4.88224404185
# 0.61 -2.35 	-6.38348963964 	-6.38348963964
# 0.61 -2.3 	-5.38154634055 	-5.38154634055
# 0.61 -2.25 	-5.26370485507 	-5.26370485507
# 0.61 -2.2 	-4.37553867569 	-4.37553867569
# 0.61 -2.15 	-6.11127323202 	-6.11127323202
# 0.61 -2.1 	-4.48526891369 	-4.48526891369
# 0.61 -2.05 	-5.41671636685 	-5.41671636685
# 0.61 -2.0 	-4.96349554658 	-4.96349554658
# 0.61 -1.95 	-5.19321221156 	-5.19321221156
# 0.61 -1.9 	-4.24928900864 	-4.24928900864
# 0.61 -1.85 	-1.76670341627 	-1.76670341627
# 0.61 -1.8 	-2.7093847251 	-2.7093847251
# 0.61 -1.75 	-1.50195504675 	-1.50195504675
# 0.61 -1.7 	-1.39722973577 	-1.39722973577
# 0.61 -1.65 	-3.05417078129 	-3.05417078129
# 0.61 -1.6 	-5.32673082392 	-5.32673082392
# 0.61 -1.55 	-4.51928433898 	-4.51928433898
# 0.61 -1.5 	-2.70838724728 	-2.70838724728
# 0.61 -1.45 	-2.31005352449 	-2.31005352449
# 0.61 -1.4 	-4.490452108 	-4.490452108
# 0.61 -1.35 	-4.78114299225 	-4.78114299225
# 0.61 -1.3 	-4.0311288012 	-4.0311288012
# 0.61 -1.25 	-2.22207095457 	-2.22207095457
# 0.61 -1.2 	-0.857797701044 	-0.857797701044
# 0.61 -1.15 	-0.19401809486 	-0.19401809486
# 0.61 -1.1 	-2.45041322053 	-2.45041322053
# 0.61 -1.05 	2.24167578798 	2.24167578798
# 0.61 -1.0 	0.911351790449 	0.911351790449
# 0.61 -0.95 	-4.49033827254 	-4.49033827254
# 0.61 -0.9 	-6.5230807298 	-6.5230807298
# 0.61 -0.85 	-9.72272702411 	-9.72272702411
# 0.61 -0.8 	-6.19554942632 	-6.19554942632
# 0.61 -0.75 	-3.62665646411 	-3.62665646411
# 0.61 -0.7 	-7.08012952739 	-7.08012952739
# 0.61 -0.65 	-3.88930832981 	-3.88930832981
# 0.61 -0.6 	2.39335380597 	2.39335380597
# 0.61 -0.55 	3.4449871826 	3.4449871826
# 0.61 -0.5 	3.87712056674 	3.87712056674
# 0.61 -0.45 	-1.74904732711 	-1.74904732711
# 0.61 -0.4 	3.82504722154 	3.82504722154
# 0.61 -0.35 	3.94411009266 	3.94411009266
# 0.61 -0.3 	6.95583751141 	6.95583751141
# 0.61 -0.25 	7.59158210188 	7.59158210188
# 0.61 -0.2 	2.09895931434 	2.09895931434
# 0.61 -0.15 	-3.26626372101 	-3.26626372101
# 0.61 -0.1 	-9.89576991279 	-9.89576991279
# 0.61 -0.05 	-12.1607389447 	-12.1607389447
# 0.61 0.0 	-7.34447058278 	-7.34447058278
# 0.635 -2.5 	-5.46684302464 	-5.46684302464
# 0.635 -2.45 	-5.85096897005 	-5.85096897005
# 0.635 -2.4 	-3.61432219401 	-3.61432219401
# 0.635 -2.35 	-4.00058154331 	-4.00058154331
# 0.635 -2.3 	-5.17480717537 	-5.17480717537
# 0.635 -2.25 	-5.11960295785 	-5.11960295785
# 0.635 -2.2 	-5.60324854909 	-5.60324854909
# 0.635 -2.15 	-8.47105680145 	-8.47105680145
# 0.635 -2.1 	-8.57303652695 	-8.57303652695
# 0.635 -2.05 	-9.94414655365 	-9.94414655365
# 0.635 -2.0 	-9.6809022394 	-9.6809022394
# 0.635 -1.95 	-6.67528241887 	-6.67528241887
# 0.635 -1.9 	-6.49916031983 	-6.49916031983
# 0.635 -1.85 	-6.79488306704 	-6.79488306704
# 0.635 -1.8 	-5.49310450855 	-5.49310450855
# 0.635 -1.75 	-3.41185977966 	-3.41185977966
# 0.635 -1.7 	-0.857995735722 	-0.857995735722
# 0.635 -1.65 	-3.73089197188 	-3.73089197188
# 0.635 -1.6 	-5.95552447934 	-5.95552447934
# 0.635 -1.55 	-4.58656591222 	-4.58656591222
# 0.635 -1.5 	-4.62684041232 	-4.62684041232
# 0.635 -1.45 	-4.22697315184 	-4.22697315184
# 0.635 -1.4 	-1.09589910848 	-1.09589910848
# 0.635 -1.35 	-1.9152590736 	-1.9152590736
# 0.635 -1.3 	-0.990121356126 	-0.990121356126
# 0.635 -1.25 	-4.55060859183 	-4.55060859183
# 0.635 -1.2 	-1.83130762628 	-1.83130762628
# 0.635 -1.15 	0.245857620415 	0.245857620415
# 0.635 -1.1 	-0.54426251847 	-0.54426251847
# 0.635 -1.05 	-6.07354645919 	-6.07354645919
# 0.635 -1.0 	-7.50810346331 	-7.50810346331
# 0.635 -0.95 	-13.5297060922 	-13.5297060922
# 0.635 -0.9 	-5.61129399506 	-5.61129399506
# 0.635 -0.85 	-3.18346422358 	-3.18346422358
# 0.635 -0.8 	-8.32348738105 	-8.32348738105
# 0.635 -0.75 	-5.88650555439 	-5.88650555439
# 0.635 -0.7 	-2.85947270974 	-2.85947270974
# 0.635 -0.65 	3.85597565648 	3.85597565648
# 0.635 -0.6 	4.64140569102 	4.64140569102
# 0.635 -0.55 	4.55634701681 	4.55634701681
# 0.635 -0.5 	-0.987752332652 	-0.987752332652
# 0.635 -0.45 	4.30397574595 	4.30397574595
# 0.635 -0.4 	5.35918674467 	5.35918674467
# 0.635 -0.35 	3.72705566748 	3.72705566748
# 0.635 -0.3 	5.27914587198 	5.27914587198
# 0.635 -0.25 	3.50097242915 	3.50097242915
# 0.635 -0.2 	-0.235623901482 	-0.235623901482
# 0.635 -0.15 	-3.49277228699 	-3.49277228699
# 0.635 -0.1 	-9.94719133077 	-9.94719133077
# 0.635 -0.05 	-13.3945550459 	-13.3945550459
# 0.635 0.0 	-7.34447058278 	-7.34447058278
# 0.66 -2.5 	-4.50053617762 	-4.50053617762
# 0.66 -2.45 	-4.33179918796 	-4.33179918796
# 0.66 -2.4 	-6.54469092963 	-6.54469092963
# 0.66 -2.35 	-5.82639492507 	-5.82639492507
# 0.66 -2.3 	-3.39246677375 	-3.39246677375
# 0.66 -2.25 	-5.60808669256 	-5.60808669256
# 0.66 -2.2 	-2.81388709186 	-2.81388709186
# 0.66 -2.15 	-2.80565559784 	-2.80565559784
# 0.66 -2.1 	-2.38551585669 	-2.38551585669
# 0.66 -2.05 	-4.31409890603 	-4.31409890603
# 0.66 -2.0 	-4.43966793966 	-4.43966793966
# 0.66 -1.95 	-6.21684394528 	-6.21684394528
# 0.66 -1.9 	-7.14718764103 	-7.14718764103
# 0.66 -1.85 	-8.40798857955 	-8.40798857955
# 0.66 -1.8 	-7.48220483291 	-7.48220483291
# 0.66 -1.75 	-5.36317038852 	-5.36317038852
# 0.66 -1.7 	-4.16626784921 	-4.16626784921
# 0.66 -1.65 	-3.79935347265 	-3.79935347265
# 0.66 -1.6 	-2.99523110788 	-2.99523110788
# 0.66 -1.55 	-3.84024066348 	-3.84024066348
# 0.66 -1.5 	-5.06583503094 	-5.06583503094
# 0.66 -1.45 	-4.27205736954 	-4.27205736954
# 0.66 -1.4 	-6.15961473997 	-6.15961473997
# 0.66 -1.35 	-5.76705911515 	-5.76705911515
# 0.66 -1.3 	-5.21742501477 	-5.21742501477
# 0.66 -1.25 	-4.46219113463 	-4.46219113463
# 0.66 -1.2 	-7.91703899284 	-7.91703899284
# 0.66 -1.15 	-9.80711052252 	-9.80711052252
# 0.66 -1.1 	-11.3223904438 	-11.3223904438
# 0.66 -1.05 	-12.7793937575 	-12.7793937575
# 0.66 -1.0 	-3.842347778 	-3.842347778
# 0.66 -0.95 	-6.18073019045 	-6.18073019045
# 0.66 -0.9 	-6.64143763316 	-6.64143763316
# 0.66 -0.85 	-8.42281280763 	-8.42281280763
# 0.66 -0.8 	-5.82533955927 	-5.82533955927
# 0.66 -0.75 	-0.340657260156 	-0.340657260156
# 0.66 -0.7 	3.12706754137 	3.12706754137
# 0.66 -0.65 	3.74985783536 	3.74985783536
# 0.66 -0.6 	2.98285496971 	2.98285496971
# 0.66 -0.55 	-2.19254776371 	-2.19254776371
# 0.66 -0.5 	4.19844089028 	4.19844089028
# 0.66 -0.45 	5.44849343382 	5.44849343382
# 0.66 -0.4 	4.67718303632 	4.67718303632
# 0.66 -0.35 	6.82299672595 	6.82299672595
# 0.66 -0.3 	5.68482230586 	5.68482230586
# 0.66 -0.25 	5.39777546835 	5.39777546835
# 0.66 -0.2 	-1.28321763447 	-1.28321763447
# 0.66 -0.15 	-6.13826641472 	-6.13826641472
# 0.66 -0.1 	-9.67411648708 	-9.67411648708
# 0.66 -0.05 	-12.4216062853 	-12.4216062853
# 0.66 0.0 	-7.34447058278 	-7.34447058278

# %% [markdown]
# ### Checking code: Does the approximate method really result in contours significantly different from the precise method contours?

# %%
#for nowmuedge in range(6,14):
 #for nowmumin in :
#for polyfit_deg in [3,4,6,8,10,12,15,20]:
#    print '##########################\nPolyfit deg = ', polyfit_deg
if True:
#for nownummuedge in [20,26]:
    #nummuedges = [nownummuedge]#[nowmuedge]#range(13,14)
    #mumins = np.linspace(0.05, 0.06,1)
    nummuedges = range(20,31)
    mumins = np.linspace(0.01, 0.05, 5)
    conommin, conommax, conwmin, conwmax =  0.08, 0.64, -1.95, -0.0

    covmatrescale_nowfiles1 = sumlist([[[Percival_covmat_scale(2000,nummu,2)[2] , 
                './cov_chisqs/Dense1subscanPatchyV6CMocks_int--xi.'+str(nummu)+'mu%.2f'%mumin+\
                'to1.00.s6.00to40.00.CovMock_2000_PatchyV6C_RSD.txt'] for mumin in mumins] for nummu in nummuedges])
    covmatrescale_nowfiles2 = sumlist([[[Percival_covmat_scale(2000,nummu,2)[2], 
                './cov_chisqs/Dense1subscanPatchyV6CMocks_MappingTest_int--xi.'+str(nummu)+'mu%.2f'%mumin+\
                'to1.00.s6.00to40.00.CovMock_2000_PatchyV6C_RSD.SMU_Mapping.txt'] for mumin in mumins] for nummu in nummuedges])

    ### Debug Scan : for purpose of checking the correctness of code. Done. (No error found at all)
    # Computation done for mumin=0.05, s<=38
    #covmatrescale_nowfiles3 = sumlist([[[Percival_covmat_scale(2000,nummu,2)[2], 
    #            './cov_chisqs/Dense1subscanPatchyV6CMocks_MappingTest_DebugScan_int--xi.'+str(nummu)+'mu%.2f'%mumin+\
    #            'to1.00.s6.00to40.00.CovMock_2000_PatchyV6C_RSD.txt'] for mumin in mumins] for nummu in nummuedges])
    #covmatrescale_nowfiles4 = sumlist([[[Percival_covmat_scale(2000,nummu,2)[2], 
    #            './cov_chisqs/Dense1subscanPatchyV6CMocks_Mapping_170309Debug_int--xi.'+str(nummu)+'mu%.2f'%mumin+\
    #            'to1.00.s6.00to40.00.CovMock_2000_PatchyV6C_RSD.SMU_Mapping.txt'] for mumin in mumins] for nummu in nummuedges])
    
    ### Debug Scan : using alternative mapping of (s,mu) [mapping the center rather than the edge]. Almost no change at all.
    # Computation done for mumin=0.05, s<=27
    #covmatrescale_nowfiles3 = sumlist([[[Percival_covmat_scale(2000,nummu,2)[2], 
    #            './cov_chisqs/Dense1subscanPatchyV6CMocks_MappingTest_DebugScan_New_SMuMapping_Mid_int--xi.'+str(nummu)+'mu%.2f'%mumin+\
    #            'to1.00.s6.00to40.00.CovMock_2000_PatchyV6C_RSD.SMU_Mapping.txt'] for mumin in mumins] for nummu in nummuedges])
    #covmatrescale_nowfiles4 = sumlist([[[Percival_covmat_scale(2000,nummu,2)[2], 
    #            './cov_chisqs/Dense1subscanPatchyV6CMocks_MappingTest_DebugScan_New_SMuMapping_Mid_int--xi.'+str(nummu)+'mu%.2f'%mumin+\
    #            'to1.00.s6.00to40.00.CovMock_2000_PatchyV6C_RSD.SMU_Mapping.txt'] for mumin in mumins] for nummu in nummuedges])
    
    ### Debug Scan : using polyfit curve. Not working: even using 20th polynomial the contour still much larger than original one
    #covmatrescale_nowfiles3 = sumlist([[[Percival_covmat_scale(2000,nummu,2)[2], 
    #            './cov_chisqs/Dense1subscanPatchyV6CMocks_Mapping_170314Debug_int--xi.'+str(nummu)+'mu%.2f'%mumin+\
    #            'to1.00.s6.00to40.00.CovMock_2000_PatchyV6C_RSD.polyfit_dxi_deg'+str(polyfit_deg)+'.txt'] for mumin in mumins] for nummu in nummuedges])
    #covmatrescale_nowfiles4 = sumlist([[[Percival_covmat_scale(2000,nummu,2)[2], 
    #            './cov_chisqs/Dense1subscanPatchyV6CMocks_Mapping_170314Debug_int--xi.'+str(nummu)+'mu%.2f'%mumin+\
    #            'to1.00.s6.00to40.00.CovMock_2000_PatchyV6C_RSD.SMU_Mapping.polyfit_dxi_deg'+str(polyfit_deg)+'.txt'] for mumin in mumins] for nummu in nummuedges])
    
    ### Debug Scan : "simple replacement" method: Actually this method works better than all other methods...
    #covmatrescale_nowfiles3 = sumlist([[[Percival_covmat_scale(2000,nummu,2)[2], 
    #            './cov_chisqs/Dense1subscanPatchyV6CMocks_Mapping_170314Debug_int--xi.'+str(nummu)+'mu%.2f'%mumin+\
    #            'to1.00.s6.00to40.00.CovMock_2000_PatchyV6C_RSD.SMU_Mapping.simple_replacement.txt'] for mumin in mumins] for nummu in nummuedges])
    
    ### Debug Scan : "Dense Mapping" method
    covmatrescale_nowfiles3 = sumlist([[[Percival_covmat_scale(2000,nummu,2)[2], 
                #'./cov_chisqs/Dense1subscanPatchyV6CMocks_Mapping_170314Debug_int--xi.'+str(nummu)+'mu%.2f'%mumin+\
                #'to1.00.s6.00to40.00.CovMock_2000_PatchyV6C_RSD.SMU_Mapping.DenseMapping.divided_pixel.txt'] for mumin in mumins] for nummu in nummuedges])    
                './cov_chisqs/Dense1subscanPatchyV6CMocks_Mapping_DenseMappingScan_int--xi.'+str(nummu)+'mu%.2f'%mumin+\
                'to1.00.s6.00to40.00.CovMock_2000_PatchyV6C_RSD.SMU_Mapping.DenseMapping.divided_pixel.txt'] for mumin in mumins] for nummu in nummuedges])    
    
    plotformat=1       
    #fig, ax = figax(figxsize=14,figysize=11.5)
    fig, ax = figax(figxsize=12,figysize=8)
    fig1, ax1 = figax(16,6)
    fig2, ax2 = figax(16,6)
    for nowfiles in [covmatrescale_nowfiles1, covmatrescale_nowfiles3]:#,covmatrescale_nowfiles4]:#,covmatrescale_nowfiles4]:#, covmatrescale_nowfiles3]:
        #ax.set_title(separate_path_file(nowfile)[1])
        ifile = -1
        nowtab = {}
        for covmatrescale_nowfile in nowfiles:
            ifile += 1; covmatrescale, nowfile = covmatrescale_nowfile; iline=0; covmatrescale*=5.0/4.0
            for nowstr in open(nowfile,'r').readlines():
                iline+=1; 
                if iline==1: continue
                nowstrs = nowstr.split()
                if ifile == 0:
                    nowtab[nowstrs[1]] = [float(nowstrs[2])/covmatrescale, float(nowstrs[3])/covmatrescale]
                else:
                    nowtab[nowstrs[1]][0] += float(nowstrs[2])/covmatrescale
                    nowtab[nowstrs[1]][1] += float(nowstrs[3])/covmatrescale
            if plotformat == 1:
                nowlab = 'Precise Method'
            else:
                nowlab = 'Approximate Method ($s$,$\\mu$ mapping)'
        nowtab[omwstr(0.26,-1)][1] = (nowtab[omwstr(0.235,-1)][1]+nowtab[omwstr(0.285,-1)][1])/2.0
        plot_contour(ax, Dense1subscan_omlist, Dense1subscan_wlist, 
                         [[nowtab[omwstr(om,w)][1]/float(len(nowfiles)) for om in Dense1subscan_omlist] for w in Dense1subscan_wlist], 
                         show_marg_rlt=False, sigs=[sig1,sig2,sig3], label=nowlab, plotformat=plotformat,)
        
        X = sumlist([[DA(om, w, 0.7, SixBinRedshift_NS[4])* Hz(om, w, 0.7, SixBinRedshift_NS[4]) / \
                (DA(om, w, 0.7, SixBinRedshift_NS[0])* Hz(om, w, 0.7, SixBinRedshift_NS[0])) for om in Dense1subscan_omlist] \
                        for w in Dense1subscan_wlist])
        Y =  sumlist([[nowtab[omwstr(om,w)][1]/float(len(nowfiles))  for om in Dense1subscan_omlist] for w in Dense1subscan_wlist])

        if plotformat == 1:
                ax1.scatter(X,Y, lw=2, linewidths=0, color='b', label='Precise')
                nowlike0 = [[nowtab[omwstr(om,w)][1]/float(len(nowfiles)) for om in Dense1subscan_omlist] for w in Dense1subscan_wlist]
                Y0 = [xx for xx in Y]
        else:
                ax1.scatter(X,Y, lw=2, linewidths=0, color='r', label='Approx')
                diffY = [Y[row]-Y0[row] for row in range(len(Y))]
                difflike = [[nowtab[omwstr(om,w)][1]/float(len(nowfiles)) for om in Dense1subscan_omlist] for w in Dense1subscan_wlist]
                for row2 in range(len(Dense1subscan_omlist)):
                    for row1 in range(len(Dense1subscan_wlist)):
                        difflike[row1][row2] = (difflike[row1][row2]-nowlike0[row1][row2])
                ax2.scatter(X,diffY, lw=2, linewidths=0, color='r', label='Approx - Precise')
        plotformat += 2
    ax1.set_xlabel('DA H ratio (high-z OVER low-z)', fontsize=20)
    ax1.set_ylabel('$\\chi^2$', fontsize=20)
    ax.grid(); ax1.grid(); ax2.grid()
    ax.set_xlim(conommin, conommax); ax.set_ylim(conwmin, conwmax)
    ax.set_xlabel('$\\Omega_m$', fontsize=26); ax.set_ylabel('$w$', fontsize=26)
    ax.set_xticks(np.arange(0.10, conommax, 0.05)); ax.set_yticks(np.arange(-1.8, conwmax, 0.2))
    #ax.set_title('# of $\\mu$ bins = '+str(nummuedges))
    ax.legend(frameon=False,loc='best'); ax1.legend(frameon=False,loc='best'); ax2.legend(frameon=False,loc='best')
    fig.savefig('Comp_contour.png', format='png')
    plt.show()

# %%
for z in SixBinRedshift_NS:
    print DA(0.26,-1.5, 0.7, z)
# Out:
# 532.612151875
# 715.176362897
# 824.435159857
# 943.245218677
# 1011.59232822
# 1084.88177653

# %%
#for nowmuedge in range(6,14):
 #for nowmumin in :
#for polyfit_deg in [3,4,6,8,10,12,15,20]:
#    print '##########################\nPolyfit deg = ', polyfit_deg
if True:
#for nownummuedge in [20,26]:
    #nummuedges = [nownummuedge]#[nowmuedge]#range(13,14)
    #mumins = np.linspace(0.05, 0.06,1)
    nummuedges = range(25+1,35+1+1) ## Number of bins 25-35; Number of edges 26-36
    mumins = np.linspace(0.01, 0.15,15)
    conommin, conommax, conwmin, conwmax =  0.08, 0.64, -1.95, -0.0

    covmatrescale_nowfiles1 = sumlist([[[Percival_covmat_scale(2000,nummu-1,2)[2] , 
                './cov_chisqs/Dense1subscanPatchyV6CMocks_int--xi.'+str(nummu)+'mu%.2f'%mumin+\
                'to1.00.s6.00to40.00.CovMock_2000_PatchyV6C_RSD.txt'] for mumin in mumins] for nummu in nummuedges])
    covmatrescale_nowfiles2 = sumlist([[[Percival_covmat_scale(2000,nummu-1,2)[2], 
                './cov_chisqs/Dense1subscanPatchyV6CMocks_MappingTest_int--xi.'+str(nummu)+'mu%.2f'%mumin+\
                'to1.00.s6.00to40.00.CovMock_2000_PatchyV6C_RSD.SMU_Mapping.txt'] for mumin in mumins] for nummu in nummuedges])

    ### Debug Scan : for purpose of checking the correctness of code. Done. (No error found at all)
    # Computation done for mumin=0.05, s<=38
    #covmatrescale_nowfiles3 = sumlist([[[Percival_covmat_scale(2000,nummu-1,2)[2], 
    #            './cov_chisqs/Dense1subscanPatchyV6CMocks_MappingTest_DebugScan_int--xi.'+str(nummu)+'mu%.2f'%mumin+\
    #            'to1.00.s6.00to40.00.CovMock_2000_PatchyV6C_RSD.txt'] for mumin in mumins] for nummu in nummuedges])
    #covmatrescale_nowfiles4 = sumlist([[[Percival_covmat_scale(2000,nummu-1,2)[2], 
    #            './cov_chisqs/Dense1subscanPatchyV6CMocks_Mapping_170309Debug_int--xi.'+str(nummu)+'mu%.2f'%mumin+\
    #            'to1.00.s6.00to40.00.CovMock_2000_PatchyV6C_RSD.SMU_Mapping.txt'] for mumin in mumins] for nummu in nummuedges])
    
    ### Debug Scan : using alternative mapping of (s,mu) [mapping the center rather than the edge]. Almost no change at all.
    # Computation done for mumin=0.05, s<=27
    #covmatrescale_nowfiles3 = sumlist([[[Percival_covmat_scale(2000,nummu-1,2)[2], 
    #            './cov_chisqs/Dense1subscanPatchyV6CMocks_MappingTest_DebugScan_New_SMuMapping_Mid_int--xi.'+str(nummu)+'mu%.2f'%mumin+\
    #            'to1.00.s6.00to40.00.CovMock_2000_PatchyV6C_RSD.SMU_Mapping.txt'] for mumin in mumins] for nummu in nummuedges])
    #covmatrescale_nowfiles4 = sumlist([[[Percival_covmat_scale(2000,nummu-1,2)[2], 
    #            './cov_chisqs/Dense1subscanPatchyV6CMocks_MappingTest_DebugScan_New_SMuMapping_Mid_int--xi.'+str(nummu)+'mu%.2f'%mumin+\
    #            'to1.00.s6.00to40.00.CovMock_2000_PatchyV6C_RSD.SMU_Mapping.txt'] for mumin in mumins] for nummu in nummuedges])
    
    ### Debug Scan : using polyfit curve. Not working: even using 20th polynomial the contour still much larger than original one
    #covmatrescale_nowfiles3 = sumlist([[[Percival_covmat_scale(2000,nummu-1,2)[2], 
    #            './cov_chisqs/Dense1subscanPatchyV6CMocks_Mapping_170314Debug_int--xi.'+str(nummu)+'mu%.2f'%mumin+\
    #            'to1.00.s6.00to40.00.CovMock_2000_PatchyV6C_RSD.polyfit_dxi_deg'+str(polyfit_deg)+'.txt'] for mumin in mumins] for nummu in nummuedges])
    #covmatrescale_nowfiles4 = sumlist([[[Percival_covmat_scale(2000,nummu-1,2)[2], 
    #            './cov_chisqs/Dense1subscanPatchyV6CMocks_Mapping_170314Debug_int--xi.'+str(nummu)+'mu%.2f'%mumin+\
    #            'to1.00.s6.00to40.00.CovMock_2000_PatchyV6C_RSD.SMU_Mapping.polyfit_dxi_deg'+str(polyfit_deg)+'.txt'] for mumin in mumins] for nummu in nummuedges])
    
    ### Debug Scan : "simple replacement" method: Actually this method works better than all other methods...
    #covmatrescale_nowfiles3 = sumlist([[[Percival_covmat_scale(2000,nummu-1,2)[2], 
    #            './cov_chisqs/Dense1subscanPatchyV6CMocks_Mapping_170314Debug_int--xi.'+str(nummu)+'mu%.2f'%mumin+\
    #            'to1.00.s6.00to40.00.CovMock_2000_PatchyV6C_RSD.SMU_Mapping.simple_replacement.txt'] for mumin in mumins] for nummu in nummuedges])
    
    ### Debug Scan : "Dense Mapping" method
    covmatrescale_nowfiles3 = sumlist([[[Percival_covmat_scale(2000,nummu-1,2)[2], 
                #'./cov_chisqs/Dense1subscanPatchyV6CMocks_Mapping_170314Debug_int--xi.'+str(nummu)+'mu%.2f'%mumin+\
                #'to1.00.s6.00to40.00.CovMock_2000_PatchyV6C_RSD.SMU_Mapping.DenseMapping.divided_pixel.txt'] for mumin in mumins] for nummu in nummuedges])    
                './cov_chisqs/Dense1subscanPatchyV6CMocks_Mapping_DenseMappingScan_int--xi.'+str(nummu)+'mu%.2f'%mumin+\
                'to1.00.s6.00to40.00.CovMock_2000_PatchyV6C_RSD.SMU_Mapping.DenseMapping.divided_pixel.txt'] for mumin in mumins] for nummu in nummuedges])    

    ### Result from Fortran code. We find: applying ploy fit to sys_cor of intxi is not plausible
    covmatrescale_nowfiles4 = sumlist([[ [Percival_covmat_scale(2000,nummu-1,2)[2]/(5.0/4.0), 
                #'./cov_chisqs/Dense1subscanPatchyV6CMocks_Mapping_170314Debug_int--xi.'+str(nummu)+'mu%.2f'%mumin+\
                #'to1.00.s6.00to40.00.CovMock_2000_PatchyV6C_RSD.SMU_Mapping.DenseMapping.divided_pixel.txt'] for mumin in mumins] for nummu in nummuedges])    
                ##'./chisqs/TestScan_170410.newmumids.CovMock_2000__'+str(nummu-1)+'mubins.mumax%.2f'%(1-mumin)+'.CovMock_2000.s6.0to40.0.polyfitdeg3.txt']
                ##'./chisqs/TestScan_170410.oldmumids.CovMock_2000__'+str(nummu-1)+'mubins.mumax%.2f'%(1-mumin)+'.CovMock_2000.s6.0to40.0.polyfitdeg3.txt']
                #'./chisqs/TestScan_170410.nopolyfit.CovMock_2000__'+str(nummu-1)+'mubins.mumax%.2f'%(1-mumin)+'.CovMock_2000.s6.0to40.0.baseline_nbins600_mubins480.txt']
                #'./chisqs/TestScan_170410.nopolyfit.CovMock_2000__'+str(nummu-1)+'mubins.mumax%.2f'%(1-mumin)+'.CovMock_2000.s6.0to40.0.baseline_nbins1200_mubins960.txt']
                #'./chisqs/TestScan_170410.nopolyfit.CovMock_2000__'+str(nummu-1)+'mubins.mumax%.2f'%(1-mumin)+'.CovMock_2000.s6.0to40.0.baseline_nbins750_mubins600.txt']
                './chisqs/TestScan_170417.nopolyfit.CovMock_2000__'+str(nummu-1)+'mubins.mumax%.2f'%(1-mumin)+'.CovMock_2000.s6.0to40.0.baseline_om0.2600_w-1.0000_nbins750_mubins600.txt']
                #'./chisqs/TestScan_170410.nopolyfit.CovMock_2000__'+str(nummu-1)+'mubins.mumax%.2f'%(1-mumin)+'.CovMock_2000.s6.0to40.0.baseline_om0.1100_w-2.0000_nbins750_mubins600.txt']
                 for mumin in mumins] for nummu in nummuedges])    
    
    ### Fortran code, Single file 
    #covmatrescale_nowfiles5 = [[ 1.0/(5.0/4.0), 
                #'./chisqs/TestScan_170410.nopolyfit.CovMock_2000__25mubins.mumax0.99.CovMock_2000.s6.0to40.0.baseline_om0.2600_w-1.0000_nbins750_mubins600.txt.165schemes'] ]
                #'./chisqs/TestScan_170417.nopolyfit.CovMock_2000__25mubins.mumax0.99.CovMock_2000.s6.0to40.0.baseline_om0.1100_w-2.0000_nbins750_mubins600.txt.165schemes'] ]
    

    
    plotformat=1       
    #fig, ax = figax(figxsize=14,figysize=11.5)
    fig, ax = figax(figxsize=12,figysize=8)
    fig1, ax1 = figax(16,6)
    fig2, ax2 = figax(16,6)
    for nowfiles in [ covmatrescale_nowfiles1, covmatrescale_nowfiles4]:#, covmatrescale_nowfiles5]:#,covmatrescale_nowfiles4]:#,covmatrescale_nowfiles4]:#, covmatrescale_nowfiles3]:
        #ax.set_title(separate_path_file(nowfile)[1])
        ifile = -1
        nowtab = {}
        for covmatrescale_nowfile in nowfiles:
            ifile += 1; covmatrescale, nowfile = covmatrescale_nowfile; iline=0; covmatrescale*=5.0/4.0
            for nowstr in open(nowfile,'r').readlines():
                iline+=1; 
                if iline==1: continue
                nowstrs = nowstr.split()
                if ifile == 0:
                    nowtab[nowstrs[1]] = [float(nowstrs[2])/covmatrescale, float(nowstrs[3])/covmatrescale]
                else:
                    nowtab[nowstrs[1]][0] += float(nowstrs[2])/covmatrescale
                    nowtab[nowstrs[1]][1] += float(nowstrs[3])/covmatrescale
            if plotformat == 1:
                nowlab = 'Precise Method'
            elif plotformat == 3:
                nowlab = 'Approximate Method ($s$,$\\mu$ mapping, Fortran code)'
            #elif plotformat == 5:
            #    nowlab = 'Approximate Method ($s$,$\\mu$ mapping, Fortran code)'
        nowtab[omwstr(0.26,-1)][1] = (nowtab[omwstr(0.235,-1)][1]+nowtab[omwstr(0.285,-1)][1])/2.0
        plot_contour(ax, Dense1subscan_omlist, Dense1subscan_wlist, 
                         [[nowtab[omwstr(om,w)][1]/float(len(nowfiles)) for om in Dense1subscan_omlist] for w in Dense1subscan_wlist], 
                         show_marg_rlt=False, sigs=[sig1,sig2,sig3], label=nowlab, plotformat=plotformat,)
        
        X = sumlist([[DA(om, w, 0.7, SixBinRedshift_NS[4])* Hz(om, w, 0.7, SixBinRedshift_NS[4]) / \
                (DA(om, w, 0.7, SixBinRedshift_NS[0])* Hz(om, w, 0.7, SixBinRedshift_NS[0])) for om in Dense1subscan_omlist] \
                        for w in Dense1subscan_wlist])
        Y =  sumlist([[nowtab[omwstr(om,w)][1]/float(len(nowfiles))  for om in Dense1subscan_omlist] for w in Dense1subscan_wlist])

        if plotformat == 1:
                ax1.scatter(X,Y, lw=2, linewidths=0, color='b', label='Precise')
                nowlike0 = [[nowtab[omwstr(om,w)][1]/float(len(nowfiles)) for om in Dense1subscan_omlist] for w in Dense1subscan_wlist]
                Y0 = [xx for xx in Y]
        else:
                ax1.scatter(X,Y, lw=2, linewidths=0, color='r', label='Approx')
                diffY = [Y[row]-Y0[row] for row in range(len(Y))]
                difflike = [[nowtab[omwstr(om,w)][1]/float(len(nowfiles)) for om in Dense1subscan_omlist] for w in Dense1subscan_wlist]
                for row2 in range(len(Dense1subscan_omlist)):
                    for row1 in range(len(Dense1subscan_wlist)):
                        difflike[row1][row2] = (difflike[row1][row2]-nowlike0[row1][row2])
                ax2.scatter(X,diffY, lw=2, linewidths=0, color='r', label='Approx - Precise')
        plotformat += 2
    ax1.set_xlabel('DA H ratio (high-z OVER low-z)', fontsize=20)
    ax1.set_ylabel('$\\chi^2$', fontsize=20)
    ax.grid(); ax1.grid(); ax2.grid()
    ax.set_xlim(conommin, conommax); ax.set_ylim(conwmin, conwmax)
    ax.set_xlabel('$\\Omega_m$', fontsize=26); ax.set_ylabel('$w$', fontsize=26)
    ax.set_xticks(np.arange(0.10, conommax, 0.05)); ax.set_yticks(np.arange(-1.8, conwmax, 0.2))
    #ax.set_title('# of $\\mu$ bins = '+str(nummuedges))
    ax.legend(frameon=False,loc='best'); ax1.legend(frameon=False,loc='best'); ax2.legend(frameon=False,loc='best')
    #fig.savefig('Comp_contour_nbins1200_mubins960.png', format='png')
    plt.show()

# %%
comov_r_dft(3.0)*3.26*10**6 / 10**9
# Out:
# 13.91414185101272

# %%
Dense1subscan_omlist
# Out:
# array([ 0.06 ,  0.085,  0.11 ,  0.135,  0.16 ,  0.185,  0.21 ,  0.235,
#         0.26 ,  0.285,  0.31 ,  0.335,  0.36 ,  0.385,  0.41 ,  0.435,
#         0.46 ,  0.485,  0.51 ,  0.535,  0.56 ,  0.585,  0.61 ,  0.635,
#         0.66 ])

# %%
X = np.linspace(-2,0,11)
array_to_str_fmtted(X,' ','%.4f')
# Out:
# '-2.0000 -1.8000 -1.6000 -1.4000 -1.2000 -1.0000 -0.8000 -0.6000 -0.4000 -0.2000 0.0000 '

# %%
X3D = sumlist([[om for om in Dense1subscan_omlist] for w in Dense1subscan_wlist])
Y3D = sumlist([[w  for om in Dense1subscan_omlist] for w in Dense1subscan_wlist])
Z3D = sumlist(difflike)
fig=plt.figure(figsize=(12,12)); ax=fig.add_subplot(111,projection='3d')
ax.scatter3D(X3D,Y3D,Z3D)

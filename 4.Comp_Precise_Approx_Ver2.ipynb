# %%
execfile('/home/xiaodongli/software/pythonlib/stdA.py')
execfile('/home/xiaodongli/software/pythonlib/Tpcftools.py')
execfile('/home/xiaodongli/software/pythonlib/bossdatamock.py')
execfile('/home/xiaodongli/software/pythonlib/Tpcftools_smuximu.py')
execfile('/home/xiaodongli/software/pythonlib/Tpcftools_smuintxi.py')
# %pylab inline
import copy

nummubin = 120
deltamu = 1.0/float(nummubin)
# Out:
# /home/xiaodongli/software/pythonlib/Tpcftools_smuintxi.py:536: SyntaxWarning: name 'oms' is assigned to before global declaration
#   global oms, ws, omws, scanname
# /home/xiaodongli/software/pythonlib/Tpcftools_smuintxi.py:536: SyntaxWarning: name 'ws' is assigned to before global declaration
#   global oms, ws, omws, scanname
# /home/xiaodongli/software/pythonlib/Tpcftools_smuintxi.py:536: SyntaxWarning: name 'omws' is assigned to before global declaration
#   global oms, ws, omws, scanname
# /home/xiaodongli/software/pythonlib/Tpcftools_smuintxi.py:536: SyntaxWarning: name 'scanname' is assigned to before global declaration
#   global oms, ws, omws, scanname
# /home/xiaodongli/software/pythonlib/Tpcftools_smuintxi.py:536: SyntaxWarning: name 'oms' is assigned to before global declaration
#   global oms, ws, omws, scanname
# /home/xiaodongli/software/pythonlib/Tpcftools_smuintxi.py:536: SyntaxWarning: name 'ws' is assigned to before global declaration
#   global oms, ws, omws, scanname
# /home/xiaodongli/software/pythonlib/Tpcftools_smuintxi.py:536: SyntaxWarning: name 'omws' is assigned to before global declaration
#   global oms, ws, omws, scanname
# /home/xiaodongli/software/pythonlib/Tpcftools_smuintxi.py:536: SyntaxWarning: name 'scanname' is assigned to before global declaration
#   global oms, ws, omws, scanname
# /home/xiaodongli/software/pythonlib/Tpcftools_smuintxi.py:536: SyntaxWarning: name 'oms' is assigned to before global declaration
#   global oms, ws, omws, scanname
# /home/xiaodongli/software/pythonlib/Tpcftools_smuintxi.py:536: SyntaxWarning: name 'ws' is assigned to before global declaration
#   global oms, ws, omws, scanname
# /home/xiaodongli/software/pythonlib/Tpcftools_smuintxi.py:536: SyntaxWarning: name 'omws' is assigned to before global declaration
#   global oms, ws, omws, scanname
# /home/xiaodongli/software/pythonlib/Tpcftools_smuintxi.py:536: SyntaxWarning: name 'scanname' is assigned to before global declaration
#   global oms, ws, omws, scanname
# WARNING:
# Populating the interactive namespace from numpy and matplotlib
# pylab import has clobbered these variables: ['product', 'transpose', 'copy', 'random']
# `%matplotlib` prevents importing * from pylab and numpy

# %% [markdown]
# ### Checking code: Does the approximate method really result in contours significantly different from the precise method contours?

# %%
#for nowmuedge in range(6,14):
 #for nowmumin in :
#for polyfit_deg in [3,4,6,8,10,12,15,20]:
#    print '##########################\nPolyfit deg = ', polyfit_deg
if True:
#for nownummuedge in [20,26]:
    #nummuedges = [nownummuedge]#[nowmuedge]#range(13,14)
    #mumins = np.linspace(0.05, 0.06,1)
    nummuedges = range(20+1,25+1+1) ## Number of bins 25-35; Number of edges 26-36
    mumins = np.linspace(0.03, 0.03,1)
    #nummuedges = [26]; mumins = [0.01]
    conommin, conommax, conwmin, conwmax =  0.08, 0.64, -1.95, -0.0

    covmatrescale_nowfiles1 = sumlist([[[Percival_covmat_scale(2000,nummu-1,2)[2] , 
                './cov_chisqs/Dense1subscanPatchyV6CMocks_int--xi.'+str(nummu)+'mu%.2f'%mumin+\
                'to1.00.s6.00to40.00.CovMock_2000_PatchyV6C_RSD.txt'] for mumin in mumins] for nummu in nummuedges])
    #covmatrescale_nowfiles2 = sumlist([[[Percival_covmat_scale(2000,nummu-1,2)[2], 
    #            './cov_chisqs/Dense1subscanPatchyV6CMocks_MappingTest_int--xi.'+str(nummu)+'mu%.2f'%mumin+\
    #            'to1.00.s6.00to40.00.CovMock_2000_PatchyV6C_RSD.SMU_Mapping.txt'] for mumin in mumins] for nummu in nummuedges])

    ### Debug Scan : for purpose of checking the correctness of code. Done. (No error found at all)
    # Computation done for mumin=0.05, s<=38
    #covmatrescale_nowfiles3 = sumlist([[[Percival_covmat_scale(2000,nummu-1,2)[2], 
    #            './cov_chisqs/Dense1subscanPatchyV6CMocks_MappingTest_DebugScan_int--xi.'+str(nummu)+'mu%.2f'%mumin+\
    #            'to1.00.s6.00to40.00.CovMock_2000_PatchyV6C_RSD.txt'] for mumin in mumins] for nummu in nummuedges])
    #covmatrescale_nowfiles4 = sumlist([[[Percival_covmat_scale(2000,nummu-1,2)[2], 
    #            './cov_chisqs/Dense1subscanPatchyV6CMocks_Mapping_170309Debug_int--xi.'+str(nummu)+'mu%.2f'%mumin+\
    #            'to1.00.s6.00to40.00.CovMock_2000_PatchyV6C_RSD.SMU_Mapping.txt'] for mumin in mumins] for nummu in nummuedges])
    
    ### Debug Scan : "Dense Mapping" method
    #covmatrescale_nowfiles3 = sumlist([[[Percival_covmat_scale(2000,nummu-1,2)[2], 
                #'./cov_chisqs/Dense1subscanPatchyV6CMocks_Mapping_170314Debug_int--xi.'+str(nummu)+'mu%.2f'%mumin+\
                #'to1.00.s6.00to40.00.CovMock_2000_PatchyV6C_RSD.SMU_Mapping.DenseMapping.divided_pixel.txt'] for mumin in mumins] for nummu in nummuedges])    
    #            './cov_chisqs/Dense1subscanPatchyV6CMocks_Mapping_DenseMappingScan_int--xi.'+str(nummu)+'mu%.2f'%mumin+\
    #            'to1.00.s6.00to40.00.CovMock_2000_PatchyV6C_RSD.SMU_Mapping.DenseMapping.divided_pixel.txt'] for mumin in mumins] for nummu in nummuedges])    

    ### Result from Fortran code. We find: applying ploy fit to sys_cor of intxi is not plausible
    covmatrescale_nowfiles2 = sumlist([[ [Percival_covmat_scale(2000,nummu-1,2)[2], 
                './chisqs/Scan_170418.CovMock_2000__'+str(nummu-1)+'mubins.mumax%.2f'%(1-mumin)+'.CovMock_2000.s6.0to40.0.'+\
                #'./cov_chisqs/Dense1subscanPatchyV6CMocks_Mapping_170314Debug_int--xi.'+str(nummu)+'mu%.2f'%mumin+\
                #'to1.00.s6.00to40.00.CovMock_2000_PatchyV6C_RSD.SMU_Mapping.DenseMapping.divided_pixel.txt'] for mumin in mumins] for nummu in nummuedges])    
                #baseline_om0.2600_w-1.0000_nbins750_mubins600.txt']
                #'baseline_om0.2600_w-1.0000_nbins1200_mubins960.txt']
                #'polyfitdeg3.baseline_om0.2600_w-1.0000_nbins1200_mubins960.txt']
                #'polyfitdeg3.baseline_om0.1100_w-2.0000_nbins750_mubins600.txt']
                'polyfitdeg3.baseline_om0.3100_w-1.0000_nbins750_mubins600.txt']
                #'polyfitdeg3.baseline_om0.1100_w-2.0000_nbins750_mubins600.txt']
                 for mumin in mumins] for nummu in nummuedges])
    
    covmatrescale_nowfiles3 = sumlist([[ [Percival_covmat_scale(2000,nummu-1,2)[2], 
                './chisqs/Scan_170418.CovMock_2000__'+str(nummu-1)+'mubins.mumax%.2f'%(1-mumin)+'.CovMock_2000.s6.0to40.0.'+\
                'polyfitdeg3.baseline_om0.3100_w-1.0000_nbins750_mubins600.txt']
                 for mumin in mumins] for nummu in nummuedges]) 
    
    covmatrescale_nowfiles3 = sumlist([[ [Percival_covmat_scale(2000,nummu-1,2)[2], 
                './chisqs/Scan_170418.CovMock_2000__'+str(nummu-1)+'mubins.mumax%.2f'%(1-mumin)+'.CovMock_2000.s6.0to40.0.'+\
                'polyfitdeg3.baseline_om0.3100_w-1.0000_nbins750_mubins600.txt']
                 for mumin in mumins] for nummu in nummuedges]) 
    
    ### Fortran code, Single file 
    #covmatrescale_nowfiles5 = [[ 1.0/(5.0/4.0), 
                #'./chisqs/TestScan_170410.nopolyfit.CovMock_2000__25mubins.mumax0.99.CovMock_2000.s6.0to40.0.baseline_om0.2600_w-1.0000_nbins750_mubins600.txt.165schemes'] ]
                #'./chisqs/TestScan_170417.nopolyfit.CovMock_2000__25mubins.mumax0.99.CovMock_2000.s6.0to40.0.baseline_om0.1100_w-2.0000_nbins750_mubins600.txt.165schemes'] ]
    
    
    plotformat=1       
    #fig, ax = figax(figxsize=14,figysize=11.5)
    fig, ax = figax(figxsize=12,figysize=8)
    fig1, ax1 = figax(16,6)
    fig2, ax2 = figax(16,6)
    for nowfiles in [ covmatrescale_nowfiles1, covmatrescale_nowfiles2+covmatrescale_nowfiles3]:#, covmatrescale_nowfiles5]:#,covmatrescale_nowfiles4]:#,covmatrescale_nowfiles4]:#, covmatrescale_nowfiles3]:
        #ax.set_title(separate_path_file(nowfile)[1])
        ifile = -1
        nowtab = {}
        for covmatrescale_nowfile in nowfiles:
            ifile += 1; covmatrescale, nowfile = covmatrescale_nowfile; iline=0; covmatrescale*=5.0/4.0
            for nowstr in open(nowfile,'r').readlines():
                iline+=1; 
                if iline==1: continue
                nowstrs = nowstr.split()
                if ifile == 0:
                    nowtab[nowstrs[1]] = [float(nowstrs[2])/covmatrescale, float(nowstrs[3])/covmatrescale]
                else:
                    nowtab[nowstrs[1]][0] += float(nowstrs[2])/covmatrescale
                    nowtab[nowstrs[1]][1] += float(nowstrs[3])/covmatrescale
            if plotformat == 1:
                nowlab = 'Precise Method'
            elif plotformat == 3:
                nowlab = 'Approximate Method ($s$,$\\mu$ mapping, Fortran code)'
            #elif plotformat == 5:
            #    nowlab = 'Approximate Method ($s$,$\\mu$ mapping, Fortran code)'
        nowtab[omwstr(0.26,-1)][1] = (nowtab[omwstr(0.235,-1)][1]+nowtab[omwstr(0.285,-1)][1])/2.0
        plot_contour(ax, Dense1subscan_omlist, Dense1subscan_wlist, 
                         [[nowtab[omwstr(om,w)][1]/float(len(nowfiles)) for om in Dense1subscan_omlist] for w in Dense1subscan_wlist], 
                         show_marg_rlt=False, sigs=[sig1,sig2,sig3], label=nowlab, plotformat=plotformat,)
        
        X = sumlist([[DA(om, w, 0.7, SixBinRedshift_NS[4])* Hz(om, w, 0.7, SixBinRedshift_NS[4]) / \
                (DA(om, w, 0.7, SixBinRedshift_NS[0])* Hz(om, w, 0.7, SixBinRedshift_NS[0])) for om in Dense1subscan_omlist] \
                        for w in Dense1subscan_wlist])
        Y =  sumlist([[nowtab[omwstr(om,w)][1]/float(len(nowfiles))  for om in Dense1subscan_omlist] for w in Dense1subscan_wlist])

        if plotformat == 1:
                ax1.scatter(X,Y, lw=2, linewidths=0, color='b', label='Precise')
                nowlike0 = [[nowtab[omwstr(om,w)][1]/float(len(nowfiles)) for om in Dense1subscan_omlist] for w in Dense1subscan_wlist]
                Y0 = [xx for xx in Y]
        else:
                ax1.scatter(X,Y, lw=2, linewidths=0, color='r', label='Approx')
                diffY = [Y[row]-Y0[row] for row in range(len(Y))]
                difflike = [[nowtab[omwstr(om,w)][1]/float(len(nowfiles)) for om in Dense1subscan_omlist] for w in Dense1subscan_wlist]
                for row2 in range(len(Dense1subscan_omlist)):
                    for row1 in range(len(Dense1subscan_wlist)):
                        difflike[row1][row2] = (difflike[row1][row2]-nowlike0[row1][row2])
                ax2.scatter(X,diffY, lw=2, linewidths=0, color='r', label='Approx - Precise')
        plotformat += 2
    ax1.set_xlabel('DA H ratio (high-z OVER low-z)', fontsize=20)
    ax1.set_ylabel('$\\chi^2$', fontsize=20)
    ax.grid(); ax1.grid(); ax2.grid()
    ax.set_xlim(conommin, conommax); ax.set_ylim(conwmin, conwmax)
    ax.set_xlabel('$\\Omega_m$', fontsize=26); ax.set_ylabel('$w$', fontsize=26)
    ax.set_xticks(np.arange(0.10, conommax, 0.05)); ax.set_yticks(np.arange(-1.8, conwmax, 0.2))
    #ax.set_title('# of $\\mu$ bins = '+str(nummuedges))
    ax.legend(frameon=False,loc='best'); ax1.legend(frameon=False,loc='best'); ax2.legend(frameon=False,loc='best')
    #fig.savefig('FortranCode_CompContour__polyfitdeg3.baseline_om0.3100_w-0.6000_nbins750_mubins600.png', format='png')
    plt.show()

# %%
nowstr1 = ' 57.6999283       58.0684853       94.4243164       71.5192184       124.971275'
nowstr2 = '57.0650482       57.1510963       88.9845963       74.6637115       84.70170593'
nowstr3 = '53.4352379       58.6054306       98.2970505       72.0406799       116.730476'
nowstr4 = '52.7991486       57.6732254       92.7996445       75.3272781       77.2228928'
print sum( [ float(xx) for xx in nowstr1.split()])    
print sum( [ float(xx) for xx in nowstr2.split()])    
print sum( [ float(xx) for xx in nowstr3.split()])    
print sum( [ float(xx) for xx in nowstr4.split()])
# Out:
# 406.6832234
# 362.56615823
# 399.1088749
# 355.8221894

# %%
#for nowmuedge in range(6,14):
 #for nowmumin in :
#for polyfit_deg in [3,4,6,8,10,12,15,20]:
#    print '##########################\nPolyfit deg = ', polyfit_deg
averaged_over_all_omws = True
#all_omws = [[0.26,-1.0], [0.26,-1.4], [0.26,-0.6]]
all_omws = [[0.26,-1.0]]#, [0.31,-1.0]]
#all_omws = [[0.26,-0.6], [0.31,-0.6]]
#all_omws = [[0.26,-1.0], [0.26,-1.4]]
#all_omws = [[0.31,-1.0], [0.31,-1.4], [0.31,-0.6]]
#all_omws = [[0.26,-1.0], [0.26,-1.4], [0.26,-0.6], [0.31,-1.0], [0.31,-1.4], [0.31,-0.6]]
for omwstds in all_omws:
#for nownummuedge in [20,26]:
    #nummuedges = [nownummuedge]#[nowmuedge]#range(13,14)
    #mumins = np.linspace(0.05, 0.06,1)
    nummuedges = range(20+1,25+1+1) ## Number of bins 25-35; Number of edges 26-36
    mumins = np.linspace(0.03, 0.03,1)
    #nummuedges = [26]; mumins = [0.01]
    conommin, conommax, conwmin, conwmax =  0.08, 0.64, -1.95, -0.0

    covmatrescale_nowfiles1 = sumlist([[[Percival_covmat_scale(2000,nummu-1,2)[2] , 
                './cov_chisqs/Dense2subscanPatchyV6CMocks_int--xi.'+str(nummu)+'mu%.2f'%mumin+\
                'to1.00.s6.00to40.00.CovMock_2000_PatchyV6C_RSD.txt'] for mumin in mumins] for nummu in nummuedges])
    
    ### Result from Fortran code. We find: applying ploy fit to sys_cor of intxi is not plausible
    covmatrescale_nowfiles2 = sumlist([[ [Percival_covmat_scale(2000,nummu-1,2)[2], 
                './chisqs/Dense2Scan_170420.CovMock_2000__'+str(nummu-1)+'mubins.mumax%.2f'%(1-mumin)+'.CovMock_2000.s6.0to40.0.'+\
                'polyfitdeg3.baseline_om0.2600_w-1.0000_nbins750_mubins600.txt']
                 for mumin in mumins] for nummu in nummuedges])
    
    nowomwstr = omwstr(omwstds[0],omwstds[1])
    covmatrescale_nowfiles2 = sumlist([[ [Percival_covmat_scale(2000,nummu-1,2)[2], 
                './chisqs/Dense2Scan_170420.CovMock_2000__'+str(nummu-1)+'mubins.mumax%.2f'%(1-mumin)+'.CovMock_2000.s6.0to40.0.'+\
                'polyfitdeg3.baseline_1omws__'+nowomwstr+'__nbins750_mubins600.txt']
                 for mumin in mumins] for nummu in nummuedges])
    if averaged_over_all_omws:
        covmatrescale_nowfiles2 = [];
        for nowomw in all_omws:
            covmatrescale_nowfiles2 += sumlist([[ [Percival_covmat_scale(2000,nummu-1,2)[2], 
                './chisqs/Dense2Scan_170420.CovMock_2000__'+str(nummu-1)+'mubins.mumax%.2f'%(1-mumin)+'.CovMock_2000.s6.0to40.0.'+\
                'polyfitdeg3.baseline_1omws__'+omwstr(nowomw[0],nowomw[1])+'__nbins750_mubins600.txt']
                 for mumin in mumins] for nummu in nummuedges])
    
    
    plotformat=1       
    fig, ax = figax(figxsize=12,figysize=8)
    #fig1, ax1 = figax(16,6)
    #fig2, ax2 = figax(16,6)
    for nowfiles in [ covmatrescale_nowfiles1, covmatrescale_nowfiles2,   ]:#, covmatrescale_nowfiles5]:#,covmatrescale_nowfiles4]:#,covmatrescale_nowfiles4]:#, covmatrescale_nowfiles3]:
        ifile = -1
        nowtab = {}
        for covmatrescale_nowfile in nowfiles:
            ifile += 1; covmatrescale, nowfile = covmatrescale_nowfile; iline=0; covmatrescale*=5.0/4.0
            for nowstr in open(nowfile,'r').readlines():
                iline+=1; 
                if iline==1: continue
                nowstrs = nowstr.split()
                if ifile == 0:
                    nowtab[nowstrs[1]] = [float(nowstrs[2])/covmatrescale, float(nowstrs[3])/covmatrescale]
                else:
                    nowtab[nowstrs[1]][0] += float(nowstrs[2])/covmatrescale
                    nowtab[nowstrs[1]][1] += float(nowstrs[3])/covmatrescale
            if plotformat == 1:
                nowlab = 'precise method\n'
                nowlab += ('mubins = '+array_to_str_fmtted([xx -1 for xx in nummuedges], ' ', fmt='%i')+'\n')
                nowlab += ('mumins = '+array_to_str_fmtted(mumins, ' ', fmt='%.2f'))
            elif plotformat == 2:
                nowlab = 'baseline = '+omwstr(0.26,-1)
            elif plotformat == 3:
                if averaged_over_all_omws:
                    nowlab = '\n\nAveraged over '+str(len(all_omws))+' omws:'
                    for omwval in all_omws:
                        nowlab += ('\n '+omwstr(omwval[0], omwval[1]))
                    nowlab += '\n\n'
                else:
                    nowlab = 'baseline = '+nowomwstr
            #elif plotformat == 5:
            #    nowlab = 'Approximate Method ($s$,$\\mu$ mapping, Fortran code)'
        nowtab[omwstr(0.26,-1)][1] = (nowtab[omwstr(0.235,-1)][1]+nowtab[omwstr(0.285,-1)][1])/2.0
        plot_contour(ax, Dense2subscan_omlist, Dense2subscan_wlist, 
                         [[nowtab[omwstr(om,w)][1]/float(len(nowfiles)) for om in Dense2subscan_omlist] for w in Dense2subscan_wlist], 
                         show_marg_rlt=False, sigs=[sig1,sig2,sig3], label=nowlab, plotformat=plotformat,)
        
        X = sumlist([[DA(om, w, 0.7, SixBinRedshift_NS[4])* Hz(om, w, 0.7, SixBinRedshift_NS[4]) / \
                (DA(om, w, 0.7, SixBinRedshift_NS[0])* Hz(om, w, 0.7, SixBinRedshift_NS[0])) for om in Dense2subscan_omlist] \
                        for w in Dense2subscan_wlist])
        Y =  sumlist([[nowtab[omwstr(om,w)][1]/float(len(nowfiles))  for om in Dense2subscan_omlist] for w in Dense2subscan_wlist])

        if plotformat == 1:
                ax1.scatter(X,Y, lw=2, linewidths=0, color='b', label='Precise')
                nowlike0 = [[nowtab[omwstr(om,w)][1]/float(len(nowfiles)) for om in Dense2subscan_omlist] for w in Dense2subscan_wlist]
                Y0 = [xx for xx in Y]
        else:
          if False:
                ax1.scatter(X,Y, lw=2, linewidths=0, color='r', label='Approx')
                diffY = [Y[row]-Y0[row] for row in range(len(Y))]
                difflike = [[nowtab[omwstr(om,w)][1]/float(len(nowfiles)) for om in Dense2subscan_omlist] for w in Dense2subscan_wlist]
                for row2 in range(len(Dense2subscan_omlist)):
                    for row1 in range(len(Dense2subscan_wlist)):
                        difflike[row1][row2] = (difflike[row1][row2]-nowlike0[row1][row2])
                ax2.scatter(X,diffY, lw=2, linewidths=0, color='r', label='Approx - Precise')
        plotformat += 2
    #ax1.set_xlabel('DA H ratio (high-z OVER low-z)', fontsize=20)
    #ax1.set_ylabel('$\\chi^2$', fontsize=20)
    ax.grid(); ax1.grid(); ax2.grid()
    ax.set_xlim(conommin, conommax); ax.set_ylim(conwmin, conwmax)
    ax.set_xlabel('$\\Omega_m$', fontsize=26); ax.set_ylabel('$w$', fontsize=26)
    ax.set_xticks(np.arange(0.10, conommax, 0.05)); ax.set_yticks(np.arange(-1.8, conwmax, 0.2))
    #ax.set_title('# of $\\mu$ bins = '+str(nummuedges))
    ax.legend(frameon=False,loc='best'); ax1.legend(frameon=False,loc='best'); ax2.legend(frameon=False,loc='best')
    #fig.savefig('CompContour__polyfitdeg3.baseline_'+nowomwstr+'_nbins750_mubins600.png', format='png')
    omwstrs = array_to_str([omwstr(X[0],X[1]) for X in all_omws])
    #fig.savefig('CompContour__polyfitdeg3.baseline_AveragedOver'+str(len(all_omws))+'OMWs_'+omwstrs+'_nbins750_mubins600.png', format='png')
    plt.show()
    if averaged_over_all_omws: break

# %%
if True:
    #nummuedges = [nownummuedge]#[nowmuedge]#range(13,14)
    mumins = np.linspace(0.01, 0.15,15)
    nummuedges = range(21+1,25+1+1) ## Number of bins 25-35; Number of edges 26-36
#for nowmumin in np.linspace(0.01,0.15,15):
    #print '* nowmumin = ', nowmumin
#    mumins = [nowmumin] #np.linspace(0.05, 0.05,1)
    #nummuedges = [26]; mumins = [0.01]
    conommin, conommax, conwmin, conwmax =  0.08, 0.64, -1.95, -0.0

    covmatrescale_nowfiles1 = sumlist([[[Percival_covmat_scale(2000,nummu-1,2)[2] , 
                './cov_chisqs/Dense2subscanPatchyV6CMocks_int--xi.'+str(nummu)+'mu%.2f'%mumin+\
                'to1.00.s6.00to40.00.CovMock_2000_PatchyV6C_RSD.txt'] for mumin in mumins] for nummu in nummuedges])
    
    ### Result from Fortran code. We find: applying ploy fit to sys_cor of intxi is not plausible
    covmatrescale_nowfiles2 = sumlist([[ [Percival_covmat_scale(2000,nummu-1,2)[2], 
                './chisqs/Dense2Scan_170420.CovMock_2000__'+str(nummu-1)+'mubins.mumax%.2f'%(1-mumin)+'.CovMock_2000.s6.0to40.0.'+\
                'polyfitdeg3.baseline_om0.2600_w-1.0000_nbins750_mubins600.txt']
                 for mumin in mumins] for nummu in nummuedges])
    
    covmatrescale_nowfiles3 = sumlist([[ [Percival_covmat_scale(2000,nummu-1,2)[2], 
                './chisqs/Dense2Scan_170420.CovMock_2000__'+str(nummu-1)+'mubins.mumax%.2f'%(1-mumin)+'.CovMock_2000.s6.0to40.0.'+\
                #'polyfitdeg3.baseline_6omws__om0.2600_w-1.0000_om0.2600_w-1.4000_om0.2600_w-0.6000_om0.3100_w-1.0000_om0.3100_w-1.4000_om0.3100_w-0.6000__nbins750_mubins600.txt']
                'polyfitdeg3.baseline_2omws__om0.2600_w-1.0000_om0.3100_w-1.0000__nbins750_mubins600.txt']
                 for mumin in mumins] for nummu in nummuedges])

    covmatrescale_nowfiles4 = sumlist([[ [Percival_covmat_scale(2000,nummu-1,2)[2], 
                './chisqs/Dense2Scan_170420.CovMock_2000__'+str(nummu-1)+'mubins.mumax%.2f'%(1-mumin)+'.CovMock_2000.s6.0to40.0.'+\
                #'polyfitdeg3.baseline_6omws__om0.2600_w-1.0000__nbins750_mubins600.weightedstds.txt']
                #'polyfitdeg3.baseline_2omws__om0.2600_w-1.0000_om0.3100_w-1.0000__nbins750_mubins600.txt']
                'polyfitdeg3.baseline_2omws__om0.2600_w-1.0000__nbins750_mubins600.avg_counts.txt']
                #'polyfitdeg3.baseline_2omws__om0.2600_w-1.0000__nbins750_mubins600.weightedstds.avg_counts.txt']
     #           'polyfitdeg3.baseline_6omws__om0.2600_w-1.0000__nbins750_mubins600.avg_counts.txt']
                #'polyfitdeg3.baseline_6omws__om0.2600_w-1.0000__nbins750_mubins600.weightedstds.avg_counts.txt']
                 for mumin in mumins] for nummu in nummuedges])
    
    
    
    plotformat=1       
    fig, ax = figax(figxsize=12,figysize=8)
    #fig1, ax1 = figax(16,6)
    #fig2, ax2 = figax(16,6)
    for nowfiles in [ covmatrescale_nowfiles1, covmatrescale_nowfiles4]:#, covmatrescale_nowfiles5]:#,covmatrescale_nowfiles4]:#,covmatrescale_nowfiles4]:#, covmatrescale_nowfiles3]:
        ifile = -1
        nowtab = {}
        for covmatrescale_nowfile in nowfiles:
            ifile += 1; covmatrescale, nowfile = covmatrescale_nowfile; iline=0; covmatrescale*=5.0/4.0
            for nowstr in open(nowfile,'r').readlines():
                iline+=1; 
                if iline==1: continue
                nowstrs = nowstr.split()
                if ifile == 0:
                    nowtab[nowstrs[1]] = [float(nowstrs[2])/covmatrescale, float(nowstrs[3])/covmatrescale]
                else:
                    nowtab[nowstrs[1]][0] += float(nowstrs[2])/covmatrescale
                    nowtab[nowstrs[1]][1] += float(nowstrs[3])/covmatrescale
            if plotformat == 1:
                nowlab = 'precise method'
            elif plotformat == 2:
                nowlab = 'baseline = '+omwstr(0.26,-1)
            elif plotformat == 3:
                    #nowlab = '6 cosmologies (weightedstds)'
                    #nowlab = '6 cosmologies, avg_counts'
                    nowlab = '2 cosmologies'
            #elif plotformat == 5:
            #    nowlab = 'Approximate Method ($s$,$\\mu$ mapping, Fortran code)'
        nowtab[omwstr(0.26,-1)][1] = (nowtab[omwstr(0.235,-1)][1]+nowtab[omwstr(0.285,-1)][1])/2.0
        plot_contour(ax, Dense2subscan_omlist, Dense2subscan_wlist, 
                         [[nowtab[omwstr(om,w)][1]/float(len(nowfiles)) for om in Dense2subscan_omlist] for w in Dense2subscan_wlist], 
                         show_marg_rlt=False, sigs=[sig1,sig2,sig3], label=nowlab, plotformat=plotformat,)
        
        X = sumlist([[DA(om, w, 0.7, SixBinRedshift_NS[4])* Hz(om, w, 0.7, SixBinRedshift_NS[4]) / \
                (DA(om, w, 0.7, SixBinRedshift_NS[0])* Hz(om, w, 0.7, SixBinRedshift_NS[0])) for om in Dense2subscan_omlist] \
                        for w in Dense2subscan_wlist])
        Y =  sumlist([[nowtab[omwstr(om,w)][1]/float(len(nowfiles))  for om in Dense2subscan_omlist] for w in Dense2subscan_wlist])

        if plotformat == 1:
                ax1.scatter(X,Y, lw=2, linewidths=0, color='b', label='Precise')
                nowlike0 = [[nowtab[omwstr(om,w)][1]/float(len(nowfiles)) for om in Dense2subscan_omlist] for w in Dense2subscan_wlist]
                Y0 = [xx for xx in Y]
        else:
          if False:
                ax1.scatter(X,Y, lw=2, linewidths=0, color='r', label='Approx')
                diffY = [Y[row]-Y0[row] for row in range(len(Y))]
                difflike = [[nowtab[omwstr(om,w)][1]/float(len(nowfiles)) for om in Dense2subscan_omlist] for w in Dense2subscan_wlist]
                for row2 in range(len(Dense2subscan_omlist)):
                    for row1 in range(len(Dense2subscan_wlist)):
                        difflike[row1][row2] = (difflike[row1][row2]-nowlike0[row1][row2])
                ax2.scatter(X,diffY, lw=2, linewidths=0, color='r', label='Approx - Precise')
        plotformat += 2
    #ax1.set_xlabel('DA H ratio (high-z OVER low-z)', fontsize=20)
    #ax1.set_ylabel('$\\chi^2$', fontsize=20)
    ax.grid(); ax1.grid(); ax2.grid()
    ax.set_xlim(conommin, conommax); ax.set_ylim(conwmin, conwmax)
    ax.set_xlabel('$\\Omega_m$', fontsize=26); ax.set_ylabel('$w$', fontsize=26)
    ax.set_xticks(np.arange(0.10, conommax, 0.05)); ax.set_yticks(np.arange(-1.8, conwmax, 0.2))
    #ax.set_title('# of $\\mu$ bins = '+str(nummuedges))
    ax.legend(frameon=False,loc='best'); ax1.legend(frameon=False,loc='best'); ax2.legend(frameon=False,loc='best')
    #fig.savefig('CompContour__polyfitdeg3.baseline_'+nowomwstr+'_nbins750_mubins600.png', format='png')
    #fig.savefig('CompContour__polyfitdeg3.baseline_AveragedOver'+str(len(all_omws))+'OMWs_nbins750_mubins600.png', format='png')
    #fig.savefig('CompContour__polyfitdeg3.baseline_SixOMWs_Weighted_nbins750_mubins600.png', format='png')
    #fig.savefig('CompContour__polyfitdeg3.baseline_TwoOMWs_AVG_counts_nbins750_mubins600.png', format='png')
    #fig.savefig('CompContour__polyfitdeg3.baseline_SixOMWs_AVG_counts_nbins750_mubins600.png', format='png')
    plt.show()

# %%
def sumstr(nowstr):
    return sum([float(xx) for xx in nowstr.split()])

# %%
sumstr(' 36.2399254       32.9512520       33.1987801       32.0915489       44.5231667')
# Out:
# 179.00467309999996

# %%
Tpcfrltfilename(binsplittedfilename(mockfile('DR12v4-CMASS', 'J08', 0), 1,3), )
# Out:
# '/home/xiaodongli/SparseFilaments/data/local_input/boss2pcf/data/DR12v4-CMASS//xyzw.binsplitted/J08.RSD.000.xyzw.1of3.rmax150.150rbins.120mubins.2pcf'

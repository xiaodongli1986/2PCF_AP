# %%
execfile('/home/xiaodongli/software/pythonlib/stdA.py')
execfile('/home/xiaodongli/software/pythonlib/Tpcftools.py')
execfile('/home/xiaodongli/software/pythonlib/bossdatamock.py')
execfile('/home/xiaodongli/software/pythonlib/Tpcftools_smuximu.py')
execfile('/home/xiaodongli/software/pythonlib/Tpcftools_smuintxi.py')
# %pylab inline
import copy

nummubin = 120
deltamu = 1.0/float(nummubin)
# Out:
# /home/xiaodongli/software/pythonlib/Tpcftools_smuintxi.py:536: SyntaxWarning: name 'oms' is assigned to before global declaration
#   global oms, ws, omws, scanname
# /home/xiaodongli/software/pythonlib/Tpcftools_smuintxi.py:536: SyntaxWarning: name 'ws' is assigned to before global declaration
#   global oms, ws, omws, scanname
# /home/xiaodongli/software/pythonlib/Tpcftools_smuintxi.py:536: SyntaxWarning: name 'omws' is assigned to before global declaration
#   global oms, ws, omws, scanname
# /home/xiaodongli/software/pythonlib/Tpcftools_smuintxi.py:536: SyntaxWarning: name 'scanname' is assigned to before global declaration
#   global oms, ws, omws, scanname
# /home/xiaodongli/software/pythonlib/Tpcftools_smuintxi.py:536: SyntaxWarning: name 'oms' is assigned to before global declaration
#   global oms, ws, omws, scanname
# /home/xiaodongli/software/pythonlib/Tpcftools_smuintxi.py:536: SyntaxWarning: name 'ws' is assigned to before global declaration
# ...

# %% [markdown]
# ### Checking code: Does the approximate method really result in contours significantly different from the precise method contours?

# %%
if True:
    #nummuedges = [nownummuedge]#[nowmuedge]#range(13,14)
    mumins = np.linspace(0.03, 0.03,1)
    nummuedges = range(20+1,25+1+1) ## Number of bins 25-35; Number of edges 26-36
#for nowmumin in np.linspace(0.01,0.15,15):
    #print '* nowmumin = ', nowmumin
#    mumins = [nowmumin] #np.linspace(0.05, 0.05,1)
    #nummuedges = [26]; mumins = [0.01]
    conommin, conommax, conwmin, conwmax =  0.08, 0.64, -1.95, -0.0

    covmatrescale_nowfiles1 = sumlist([[[Percival_covmat_scale(2000,nummu-1,2)[2] , 
                './cov_chisqs/Dense2subscanPatchyV6CMocks_int--xi.'+str(nummu)+'mu%.2f'%mumin+\
                'to1.00.s6.00to40.00.CovMock_2000_PatchyV6C_RSD.txt'] for mumin in mumins] for nummu in nummuedges])
    
    ### Result from Fortran code. We find: applying ploy fit to sys_cor of intxi is not plausible
    covmatrescale_nowfiles2 = sumlist([[ [Percival_covmat_scale(2000,nummu-1,2)[2], 
                './chisqs/Dense2Scan_170420.CovMock_2000__'+str(nummu-1)+'mubins.mumax%.2f'%(1-mumin)+'.CovMock_2000.s6.0to40.0.'+\
                'polyfitdeg3.baseline_om0.2600_w-1.0000_nbins750_mubins600.txt']
                 for mumin in mumins] for nummu in nummuedges])
    
    covmatrescale_nowfiles3 = sumlist([[ [Percival_covmat_scale(2000,nummu-1,2)[2], 
                './chisqs/Dense2Scan_170420.CovMock_2000__'+str(nummu-1)+'mubins.mumax%.2f'%(1-mumin)+'.CovMock_2000.s6.0to40.0.'+\
                #'polyfitdeg3.baseline_6omws__om0.2600_w-1.0000_om0.2600_w-1.4000_om0.2600_w-0.6000_om0.3100_w-1.0000_om0.3100_w-1.4000_om0.3100_w-0.6000__nbins750_mubins600.txt']
                'polyfitdeg3.baseline_2omws__om0.2600_w-1.0000_om0.3100_w-1.0000__nbins750_mubins600.txt']
                 for mumin in mumins] for nummu in nummuedges])

    covmatrescale_nowfiles4 = sumlist([[ [Percival_covmat_scale(2000,nummu-1,2)[2], 
                './chisqs/Dense2Scan_170420.CovMock_2000__'+str(nummu-1)+'mubins.mumax%.2f'%(1-mumin)+'.CovMock_2000.s6.0to40.0.'+\
                #'polyfitdeg3.baseline_6omws__om0.2600_w-1.0000__nbins750_mubins600.weightedstds.txt']
                #'polyfitdeg3.baseline_2omws__om0.2600_w-1.0000_om0.3100_w-1.0000__nbins750_mubins600.txt']
                'polyfitdeg3.baseline_2omws__om0.2600_w-1.0000__nbins750_mubins600.avg_counts.txt']
                #'polyfitdeg3.baseline_2omws__om0.2600_w-1.0000__nbins750_mubins600.weightedstds.avg_counts.txt']
     #           'polyfitdeg3.baseline_6omws__om0.2600_w-1.0000__nbins750_mubins600.avg_counts.txt']
                #'polyfitdeg3.baseline_6omws__om0.2600_w-1.0000__nbins750_mubins600.weightedstds.avg_counts.txt']
                 for mumin in mumins] for nummu in nummuedges])
    
   
    covmatrescale_nowfiles_mock000 = sumlist([[ [Percival_covmat_scale(2000,nummu-1,2)[2], 
                './chisqs/Dense2ScanIOTest_170420_000.CovMock_2000__'+str(nummu-1)+'mubins.mumax%.2f'%(1-mumin)+'.CovMock_2000.s6.0to40.0.'+\
                'polyfitdeg3.baseline_1omws__om0.2600_w-1.0000__nbins750_mubins600.txt']
                 for mumin in mumins] for nummu in nummuedges])
    
    covmatrescale_nowfiles_mock001 = sumlist([[ [Percival_covmat_scale(2000,nummu-1,2)[2], 
                './chisqs/Dense2ScanIOTest_170420_001.CovMock_2000__'+str(nummu-1)+'mubins.mumax%.2f'%(1-mumin)+'.CovMock_2000.s6.0to40.0.'+\
                'polyfitdeg3.baseline_1omws__om0.2600_w-1.0000__nbins750_mubins600.txt']
                 for mumin in mumins] for nummu in nummuedges])
    
    covmatrescale_nowfiles_mock002 = sumlist([[ [Percival_covmat_scale(2000,nummu-1,2)[2], 
                './chisqs/Dense2ScanIOTest_170420_002.CovMock_2000__'+str(nummu-1)+'mubins.mumax%.2f'%(1-mumin)+'.CovMock_2000.s6.0to40.0.'+\
                'polyfitdeg3.baseline_1omws__om0.2600_w-1.0000__nbins750_mubins600.txt']
                 for mumin in mumins] for nummu in nummuedges])
    
    covmatrescale_nowfiles_mock003 = sumlist([[ [Percival_covmat_scale(2000,nummu-1,2)[2], 
                './chisqs/Dense2ScanIOTest_170420_003.CovMock_2000__'+str(nummu-1)+'mubins.mumax%.2f'%(1-mumin)+'.CovMock_2000.s6.0to40.0.'+\
                'polyfitdeg3.baseline_1omws__om0.2600_w-1.0000__nbins750_mubins600.txt']
                 for mumin in mumins] for nummu in nummuedges])
    
    covmatrescale_nowfiles_mock002_SelfIO_smin5 = sumlist([[ [Percival_covmat_scale(2000,nummu-1,2)[2], 
                './chisqs/Dense2ScanIOTest_170420_002.CovMock_2000__'+str(nummu-1)+'mubins.mumax%.2f'%(1-mumin)+'.CovMock_2000.s5.0to40.0.'+\
                'polyfitdeg1.baseline_1omws__om0.2600_w-1.0000__nbins750_mubins600.txt']
                 for mumin in mumins] for nummu in nummuedges])
    
    covmatrescale_nowfiles_mock002_SelfIO_smin6 = sumlist([[ [Percival_covmat_scale(2000,nummu-1,2)[2], 
                './chisqs/Dense2ScanIOTest_170420_002.CovMock_2000__'+str(nummu-1)+'mubins.mumax%.2f'%(1-mumin)+'.CovMock_2000.s6.0to40.0.'+\
                'polyfitdeg1.baseline_1omws__om0.2600_w-1.0000__nbins750_mubins600.txt']
                 for mumin in mumins] for nummu in nummuedges])
    covmatrescale_nowfiles_mock002_SelfIO_smin7 = sumlist([[ [Percival_covmat_scale(2000,nummu-1,2)[2], 
                './chisqs/Dense2ScanIOTest_170420_002.CovMock_2000__'+str(nummu-1)+'mubins.mumax%.2f'%(1-mumin)+'.CovMock_2000.s7.0to40.0.'+\
                'polyfitdeg1.baseline_1omws__om0.2600_w-1.0000__nbins750_mubins600.txt']
                 for mumin in mumins] for nummu in nummuedges])
    covmatrescale_nowfiles_mock002_SelfIO_smin8 = sumlist([[ [Percival_covmat_scale(2000,nummu-1,2)[2], 
                './chisqs/Dense2ScanIOTest_170420_002.CovMock_2000__'+str(nummu-1)+'mubins.mumax%.2f'%(1-mumin)+'.CovMock_2000.s8.0to40.0.'+\
                'polyfitdeg1.baseline_1omws__om0.2600_w-1.0000__nbins750_mubins600.txt']
                 for mumin in mumins] for nummu in nummuedges])
    
    plotformat=1       
    fig, ax = figax(); #figax(figxsize=12,figysize=8)
    for nowfiles in [ #covmatrescale_nowfiles1, 
                     #covmatrescale_nowfiles_mock000,covmatrescale_nowfiles_mock001,covmatrescale_nowfiles_mock002,covmatrescale_nowfiles_mock003,]:#, covmatrescale_nowfiles5]:#,covmatrescale_nowfiles4]:#,covmatrescale_nowfiles4]:#, covmatrescale_nowfiles3]:
                     covmatrescale_nowfiles_mock000+covmatrescale_nowfiles_mock001+covmatrescale_nowfiles_mock002+covmatrescale_nowfiles_mock003,
                     #covmatrescale_nowfiles_mock002_SelfIO_smin8,
                     covmatrescale_nowfiles_mock002_SelfIO_smin5+covmatrescale_nowfiles_mock002_SelfIO_smin6+\
                        covmatrescale_nowfiles_mock002_SelfIO_smin7+covmatrescale_nowfiles_mock002_SelfIO_smin8,
                     #covmatrescale_nowfiles_mock002_SelfIO_smin7,
                     #covmatrescale_nowfiles_mock002_SelfIO_smin7,
                    ]:#, covmatrescale_nowfiles5]:#,covmatrescale_nowfiles4]:#,covmatrescale_nowfiles4]:#, covmatrescale_nowfiles3]:
        ifile = -1
        nowtab = {}
        for covmatrescale_nowfile in nowfiles:
            ifile += 1; covmatrescale, nowfile = covmatrescale_nowfile; iline=0; covmatrescale*=5.0/4.0
            for nowstr in open(nowfile,'r').readlines():
                iline+=1; 
                if iline==1: continue
                nowstrs = nowstr.split()
                if ifile == 0:
                    nowtab[nowstrs[1]] = [float(nowstrs[2])/covmatrescale, float(nowstrs[3])/covmatrescale]
                else:
                    nowtab[nowstrs[1]][0] += float(nowstrs[2])/covmatrescale
                    nowtab[nowstrs[1]][1] += float(nowstrs[3])/covmatrescale
            if plotformat == 1:
                nowlab = 'Likelihood contour from 4 realisations'
            else:
                nowlab = 'I-O Test, baseline = '+omwstr(0.26,-1)
            #    nowlab = 'Approximate Method ($s$,$\\mu$ mapping, Fortran code)'
        nowtab[omwstr(0.26,-1)][1] = (nowtab[omwstr(0.235,-1)][1]+nowtab[omwstr(0.285,-1)][1])/2.0
        plot_contour(ax, Dense2subscan_omlist, Dense2subscan_wlist, 
                         [[nowtab[omwstr(om,w)][1]/float(len(nowfiles)) for om in Dense2subscan_omlist] for w in Dense2subscan_wlist], 
                          scatter_WMAP5=False, smsigma=0.5, show_marg_rlt=False, sigs=[sig1,sig2,sig3], label=nowlab, plotformat=plotformat,)
        
        X = sumlist([[DA(om, w, 0.7, SixBinRedshift_NS[4])* Hz(om, w, 0.7, SixBinRedshift_NS[4]) / \
                (DA(om, w, 0.7, SixBinRedshift_NS[0])* Hz(om, w, 0.7, SixBinRedshift_NS[0])) for om in Dense2subscan_omlist] \
                        for w in Dense2subscan_wlist])
        Y =  sumlist([[nowtab[omwstr(om,w)][1]/float(len(nowfiles))  for om in Dense2subscan_omlist] for w in Dense2subscan_wlist])

        
        plotformat += 1
    #ax1.set_xlabel('DA H ratio (high-z OVER low-z)', fontsize=20)
    #ax1.set_ylabel('$\\chi^2$', fontsize=20)
    ax.grid(); 
    ax.set_xlim(conommin, conommax); ax.set_ylim(conwmin, conwmax)
    ax.set_xlabel('$\\Omega_m$', fontsize=28); ax.set_ylabel('$w$', fontsize=28)
    ax.set_xticks(np.arange(0.10, conommax, 0.05)); ax.set_yticks(np.arange(-1.8, conwmax, 0.2))
    #ax.set_title('# of $\\mu$ bins = '+str(nummuedges))
    ax.scatter([0.26],[-1], marker='+', linewidth=3, s=150, c='g', label='Input Cosmology')
    ax.legend(frameon=False,loc='best', scatterpoints=1); 
    ax.set_xlim(0.06,0.41); ax.set_ylim(-1.18,-0.42);
    #fig.savefig('CompContour__polyfitdeg3.baseline_'+nowomwstr+'_nbins750_mubins600.png', format='png')
    plt.show()

# %%
execfile('/home/xiaodongli/software/pythonlib/stdA.py')
if True:
    mumins = np.linspace(0.03, 0.03,1)
    nummuedges = range(20+1,25+1+1) ## Number of bins 25-35; Number of edges 26-36
    conommin, conommax, conwmin, conwmax =  0.08, 0.64, -1.95, -0.0
   
    covmatrescale_nowfiles_mock000 = sumlist([[ [Percival_covmat_scale(2000,nummu-1,2)[2], 
                './chisqs/Dense2ScanIOTest_170420_000.CovMock_2000__'+str(nummu-1)+'mubins.mumax%.2f'%(1-mumin)+'.CovMock_2000.s6.0to40.0.'+\
                'polyfitdeg3.baseline_1omws__om0.2600_w-1.0000__nbins750_mubins600.txt']
                 for mumin in mumins] for nummu in nummuedges])
    
    covmatrescale_nowfiles_mock001 = sumlist([[ [Percival_covmat_scale(2000,nummu-1,2)[2], 
                './chisqs/Dense2ScanIOTest_170420_001.CovMock_2000__'+str(nummu-1)+'mubins.mumax%.2f'%(1-mumin)+'.CovMock_2000.s6.0to40.0.'+\
                'polyfitdeg3.baseline_1omws__om0.2600_w-1.0000__nbins750_mubins600.txt']
                 for mumin in mumins] for nummu in nummuedges])

    covmatrescale_nowfiles_mock001_nsys1 = sumlist([[ [Percival_covmat_scale(2000,nummu-1,2)[2], 
                './chisqs/Dense2ScanIOTest_170420_001_nsys1.CovMock_2000__'+str(nummu-1)+'mubins.mumax%.2f'%(1-mumin)+'.CovMock_2000.s6.0to40.0.'+\
                'polyfitdeg3.baseline_1omws__om0.2600_w-1.0000__nbins750_mubins600.txt']
                 for mumin in mumins] for nummu in nummuedges])
    
    covmatrescale_nowfiles_mock002 = sumlist([[ [Percival_covmat_scale(2000,nummu-1,2)[2], 
                './chisqs/Dense2ScanIOTest_170420_002.CovMock_2000__'+str(nummu-1)+'mubins.mumax%.2f'%(1-mumin)+'.CovMock_2000.s6.0to40.0.'+\
                'polyfitdeg3.baseline_1omws__om0.2600_w-1.0000__nbins750_mubins600.txt']
                 for mumin in mumins] for nummu in nummuedges])
    
    covmatrescale_nowfiles_mock002_nsys1 = sumlist([[ [Percival_covmat_scale(2000,nummu-1,2)[2], 
                './chisqs/Dense2ScanIOTest_170420_002_nsys1.CovMock_2000__'+str(nummu-1)+'mubins.mumax%.2f'%(1-mumin)+'.CovMock_2000.s6.0to40.0.'+\
                'polyfitdeg3.baseline_1omws__om0.2600_w-1.0000__nbins750_mubins600.txt']
                 for mumin in mumins] for nummu in nummuedges])
    
    covmatrescale_nowfiles_mock003 = sumlist([[ [Percival_covmat_scale(2000,nummu-1,2)[2], 
                './chisqs/Dense2ScanIOTest_170420_003.CovMock_2000__'+str(nummu-1)+'mubins.mumax%.2f'%(1-mumin)+'.CovMock_2000.s6.0to40.0.'+\
                'polyfitdeg3.baseline_1omws__om0.2600_w-1.0000__nbins750_mubins600.txt']
                 for mumin in mumins] for nummu in nummuedges])
    
    plotformat=1       
    fig, ax = figax(10, 8,labelfontsize=26, tfs=20); #figax(figxsize=12,figysize=8)
    for nowfiles in [ #covmatrescale_nowfiles1, 
                     covmatrescale_nowfiles_mock000+covmatrescale_nowfiles_mock001+covmatrescale_nowfiles_mock002+covmatrescale_nowfiles_mock003,]:#, covmatrescale_nowfiles5]:#,covmatrescale_nowfiles4]:#,covmatrescale_nowfiles4]:#, covmatrescale_nowfiles3]:
        ifile = -1
        nowtab = {}
        for covmatrescale_nowfile in nowfiles:
            ifile += 1; covmatrescale, nowfile = covmatrescale_nowfile; iline=0; covmatrescale*=5.0/4.0
            for nowstr in open(nowfile,'r').readlines():
                iline+=1; 
                if iline==1: continue
                nowstrs = nowstr.split()
                if ifile == 0:
                    nowtab[nowstrs[1]] = [float(nowstrs[2])/covmatrescale, float(nowstrs[3])/covmatrescale]
                else:
                    nowtab[nowstrs[1]][0] += float(nowstrs[2])/covmatrescale
                    nowtab[nowstrs[1]][1] += float(nowstrs[3])/covmatrescale
            if plotformat == 1:
                nowlab = 'Inferred constraints from 4 sets of HR4 mocks'
            else:
                nowlab = 'I-O Test, baseline = '+omwstr(0.26,-1)
            #    nowlab = 'Approximate Method ($s$,$\\mu$ mapping, Fortran code)'
        nowtab[omwstr(0.26,-1)][1] = (nowtab[omwstr(0.235,-1)][1]+nowtab[omwstr(0.285,-1)][1])/2.0

        plot_contour(ax, Dense2subscan_omlist, Dense2subscan_wlist, 
                         [[nowtab[omwstr(om,w)][1]/float(len(nowfiles)) for om in Dense2subscan_omlist] for w in Dense2subscan_wlist], 
                          plotformat=0, colorlist=[[0.1,0.5,0.5],[0.1,0.7,0.7],[0.1,0.8,0.8],[0.1,0.9,0.9]],
                          #plotformat=1, #colorlist=[[0,0.7,1],[0,0.4,1]],
                          scatter_WMAP5=False, smsigma=2.5, show_marg_rlt=False, sigs=[sig1/0.5,sig1**0.75,sig2**0.9,sig3**0.9], label=nowlab, )
        #plot_contour(ax, Dense2subscan_omlist, Dense2subscan_wlist, 
        #                 [[nowtab[omwstr(om,w)][1]/float(len(nowfiles)) for om in Dense2subscan_omlist] for w in Dense2subscan_wlist], 
        #                  plotformat=2, 
        #                  scatter_WMAP5=False, smsigma=1.5, show_marg_rlt=False, sigs=[sig1/0.5,sig1*0.5], label=nowlab, )
        
    #ax.grid();#
    ax.set_xlim(conommin, conommax); ax.set_ylim(conwmin, conwmax)
    ax.set_xlabel('$\\Omega_m$', fontsize=28); ax.set_ylabel('$w$', fontsize=28)
    ax.set_xticks(np.arange(0.10, conommax, 0.05)); ax.set_yticks(np.arange(-1.8, conwmax, 0.2))
    ax.scatter([0.26],[-1], marker='+', linewidth=4, s=300, c='k', label='Input Cosmology $\\Omega_{\\rm m}=0.26,\\ w=-1$')
    ax.legend(frameon=False,loc='best', fontsize=17, scatterpoints=1); 
    ax.set_xlim(0.11,0.41); ax.set_ylim(-1.5,-0.3);
    #ax.set_xlim(0.10,0.63); ax.set_ylim(-1.95,-0.525)
    fig.savefig('./Draft/fig_IO.eps', format='eps')
    plt.show()

# %%
sig1
# Out:
# 0.683
